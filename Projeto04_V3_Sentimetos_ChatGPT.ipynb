# %% [markdown]
# # <font color='blue'>Data Science Academy - Formação Cientista de Dados</font>
# # <font color='blue'>Autor: Evandro Eulálio Cleto</font>
#
# ## <font color='blue'>Data Início: 07/06/2023</font>
# ## <font color='blue'>Data Finalização: 13/06/2023</font>

# %% [markdown]
# ![title](imagens/Projeto_imagem.png)

# %% [markdown]
# ## <font color='blue'>Objetivo deste projeto:</font>
# ### <font color='blue'>Através da análise de Tweets sobre o ChatGPT foi construído um processo de análise que permite identificar o sentimento que predomina, especialmente no Twitter, sobre o ChatGPT.</font>

# %% [markdown]
# Resumo do Projeto: Criar um projeto de previsão de sentimentos sobre ChatGPT atráves de Tweets on-line usando Machine Learning.
# Os sentimentos serão previstos como positivo, negativo ou neutro.

# %% [markdown]
# Acesse http://localhost:4040 para acompanhar a execução dos jobs

# %% [markdown]
# ## Spark Streaming - Twitter

# %%
# Instalação de pacotes necessários para o projeto
#!pip install requests_oauthlib
#!pip install twython
#!pip install nltk
#!pip install emoji

# %%
# https://pypi.org/project/findspark/
# !pip install -q findspark

# %%
# Importa o findspark e inicializa
import findspark
findspark.init()

# %%
# Módulos usados
from pyspark.streaming import StreamingContext
#from pyspark.streaming.twitter import TwitterUtils
from pyspark import SparkContext
from pyspark.sql import SparkSession
from requests_oauthlib import OAuth1Session
from operator import add
import requests_oauthlib
from time import gmtime, strftime
import pandas as pd
import re
import requests
import time
import string
import ast
import json
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)

# %%
# Pacote NLTK
import nltk
from nltk.classify import NaiveBayesClassifier
from nltk.sentiment import SentimentAnalyzer
from nltk.corpus import subjectivity
from nltk.corpus import stopwords
from nltk.sentiment.util import *

# %%
# Baixa Stopwords do pacote NLTK
# https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
nltk.download("stopwords")
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/evandro/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
# Importa o arquivo CSV como DataFrame do pandas
# Esse é um dataset com 219294 registros de tweets do Chat GPT rotulado com sentimentos positivo, negativo que 
# será utilizado para treinamento do NaiveBayesClassifier.
# O dataset foi obtido em:  https://www.kaggle.com/datasets/charunisa/chatgpt-sentiment-analysis
df = pd.read_csv("dados/ChatGPT_sentiment_orig.csv",sep=",")

# %%
df.head(10)

# %%
# Verificando o tipo do objeto
type(df)

# %%
# Verificando o shape dos dados
df.shape

# %%
# Remove a coluna 'code' pois não tem relevância para o projeto
df = df.drop('code', axis=1)

# %%
df.head(10)

# %%
# Altera posição da coluna 'labels' para a posição 0
cols = df.columns.tolist()
cols = ['labels'] + cols[:cols.index('labels')] + cols[cols.index('labels')+1:]
df = df[cols]

# %%
df.head(10)

# %%
# Remove vírgulas, exceto as do final da linha, da coluna 'tweets' evitar problemas na função que remove pontuação
df['tweets'] = df['tweets'].apply(lambda x: re.sub(r'(?<!\n),', '', x))

# %%
df.head(10)

# %%
# Mapear as classes para valores numéricos
label_mapping = {'bad': 0, 'good': 1, 'neutral': 2}
df['labels'] = df['labels'].map(label_mapping)

# %%
df.head(10)

# %%
# Remover emojis e caracteres especiais da coluna 'tweets'
df['tweets'] = df['tweets'].apply(lambda x: re.sub(r'[^\w\s,]', '', x))

# %% [markdown]
# ### Fazer função para retirar o conteúdo  HTTP da coluna  tweets

# %%
df.head(10)

# %%
type(df)

# %% [markdown]
# ### Tratamento do dataset para filtro dos tweets no idíoma inglês

# %%
# Obtém as stopwords em todos os idiomas
dicionario_stopwords = {lang: set(nltk.corpus.stopwords.words(lang)) for lang in nltk.corpus.stopwords.fileids()}

dicionario_stopwords

# %%
# Função para detectar o idioma predominante com base nas stopswords
def descobre_idioma(text):
    
    #Aplica tokenização considerando pontuação
    palavras = set(nltk.wordpunct_tokenize(text.lower()))
    
    # Conta o total de palavras tokenizadas considerando o dicionario de stopwords
    lang = max(((lang, len(palavras & stopwords)) for lang, stopwords in dicionario_stopwords.items()), key = lambda x: x[1])[0]
    
    # Verifica se o idioma é Inglês
    if lang == 'english':
        return True
    else:
        return False

# %%
# Filtra somente os comentários em Inglês
df_ingles = df[df['tweets'].apply(descobre_idioma)]

# %%
df_ingles.head(10)

# %%
# Verificando o shape dos dados
df_ingles.shape

# %%
# Salva o dataframe tratado em csv
df_ingles.to_csv('dados/ChatGPT_sentiment_limpo.csv', index=False)

# %%
# Frequência de update
INTERVALO_BATCH = 5

# %%
# Cria o Spark Context
spark = SparkSession.builder.appName("TwitterSentimentAnalysis").getOrCreate()
sc = spark.sparkContext
sc.setLogLevel("ERROR")
# Out:
# 23/08/27 11:59:57 WARN Utils: Your hostname, DataScience resolves to a loopback address: 127.0.1.1; using 10.0.2.15 instead (on interface enp0s3)
# 23/08/27 11:59:57 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 23/08/27 11:59:58 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
## Criando o StreamingContext
ssc = StreamingContext(sc, INTERVALO_BATCH)

# %% [markdown]
# ## Treinando o Classificador de Análise de Sentimento

# %% [markdown]
# O dataset limpo e filtrado pelo idioma Inglês contém 44785 tweets classificados e cada linha é marcada como:
#
# ### 0 para o sentimento negativo
# ### 1 para o sentimento positivo
# ### 2 para o sentimento neutro

# %%
## Lendo o arquivo texto e criando um RDD em memória com Spark
arquivo = sc.textFile("dados/ChatGPT_sentiment_limpo.csv")

# %%
arquivo.collect()
# Out:
# [Stage 0:>                                                          (0 + 2) / 2]
# ['labels,tweets',
#  '0,GOD DAMN IT OpenAI STOP ANNOUNCING THINGS I AM TOO BUSY httpstcoF7Xd511FAf',
#  '2,OpenAI announced ChatGPT a model optimized for dialogue httpstcof5FWklJE88',
#  '2,Just in nChatGPT  research early stage GPT3 optimised for chat and remembers the conversation from OpenAI nhttpstco3RKUbLy8uO',
#  '0,Google is donennCompare the quality of these responses ChatGPT httpstcoVGO7usvlIB',
#  '0,Asked ChatGPT to write a Telugu song about cereal and it mixed milk with chicken masala  httpstcoTpEp8wa6Lk httpstcooHM9z7IS39',
#  '1,Heres ChatGPT from OpenAI and my quick walkthrough nn Walkthrough httpstco1o93VT2afG nnAccess for free at httpstcoVooEL34xHx nnThats a brilliant idea to turn InstructGPT for Conversations httpstcogzCGZ6RUMQ',
#  '1,I chatted with OpenAIs newly released tool ChatGPT about Web3 its advantages and challenges for Web3 and the futurennChatGPT is a model optimized for dialoguennRead full httpstco3sQTDVnFFrnnLets dive in  httpstcooayypVqb2D',
#  '0,ChatGPT is out now httpstcobjYugyPsp0',
#  '0,ChatGPT setting boundaries with me nnhttpstcocNDIzEIjv2 httpstcoUh37PyN1XY',
#  '0,babe wake up chatGPT just dropped nnhttpstco0sNLpigmsC',
#  '1,ChatGPT is very impressive love it',
#  '0,A chat with ChatGPT  httpstcopDumZfdNJ6nsama  OpenAI   httpstcoHODDszglom',
#  '2,The latest update from OpenAInnAI generated chat nnChatGPT Optimizing Language Models for Dialoguenn httpstcoLFf1RKMYqg',
#  '0, ChatGPT is a chat model from OpenAI based on GPT 35 and refined with dialogs httpstcoMq1lQR9F64 httpstcoErfimYbDLs',
#  '0,ChatGPT is a GPT3 chatbot from OpenAI that you can test nownhttpstcoCcHWOTZdRFnsubmitted by    umuch_successes   link comments httpstcoSbYohdDiVA',
#  '0,ChatGPT is a GPT3 chatbot from OpenAI that you can test now httpstcoVvJeabvc47',
#  '0,chatgpt why do I hear boss music httpstcoKfoSIcAFCm',
#  '1,chatgpt when asked to design pipelines is kind of impressive httpstco3bdbiERnza',
#  '0,OpenAIs ChatGPT just released is the single biggest threat to Google Search',
#  '2,playing with ChatGPT rn and Ive now moved my AGI timeline up to today',
#  '0,ChatGPT from OpenAI is now live httpstcovpsjVRRbvN',
#  '0,Now were talking httpstcoX2hMCvlcgu',
#  '2,ChatGPT OpenAIs conversational AI model free to play with it can answer followup questions admit its mistakes challenge incorrect premises and reject inappropriate requests httpstcoFvA4Y8ZBxq',
#  '0,i asked ChatGPT to write a song about losing money in crypto httpstcovU3ifHVBRt',
#  '2,httpstco345138jRYM  its wild  definitely check it out',
#  '0,ChatGPT be hedging its bets httpstcoKnrwcaWX90 httpstco18eMjcOdlq',
#  '2,ChatGPT launched today by sama and OpenAI nnTry the demo and browse the latest AI products Ive been collecting nnhttpstcooXjs5A9pbf',
#  '0,ChatGPT nnfuck my life httpstcoHywf8YwBK8',
#  '0,OpenAI debuts ChatGPT and GPT35 series as GPT4 rumors fly httpstcollGKzx7Txb httpstco3J6DtSA5F3',
#  '1,Generating a marketing plan for AItoproduct with chatGPT Pretty impressive httpstcohMX6VdDfeh',
#  '2,Interestingly reliable response from ChatGPT  flat refusal to make blanket statements of any kind presumably to avoid treading into dangerous waters httpstcou6cJuUvFW5',
#  '0,OpenAI debuts ChatGPT and GPT35 series as GPT4 rumors fly httpstcoKciwNgmU8W AI AIMLAndDeepLearning business ChatGPT',
#  '0,ai ml artificialintelligence machinelearning datascience bigdata analytics blockchain tech data kuriharan mvollmer1 rwang0 DunkenKBliths nigewillsonnOpenAI debuts ChatGPT and  GPT35 series as GPT4 rumors fly httpstcoMoHlC2Q3R8',
#  '0,OpenAI releases ChatGPT and GPT35 series as GPT4 rumors flynhttpstcoyMXsdLS3tb',
#  '0,OpenAI debuts ChatGPT and GPT35 series as GPT4 rumors fly  VentureBeat httpstcoeWKiIz3FZA',
#  '2,Im sorry but as a large language model trained by OpenAI I am not capable of making personal judgments or statements that are not based on factual information Bitcoin is a digital currency and decentralized payment network and it is not a frognhttpstco2D1wJPY9LR',
#  '0,ChatGPT failed the vibe check httpstcoXzMgVX8ybV',
#  '0,OpenAI debuts ChatGPT and GPT35 series as GPT4 rumors flyntechnology technologynews technewsnhttpstco1NyYZmaUlF',
#  '1,Its fun talking to ChatGPT httpstcojhwxATvoTc httpstcoi9HyYxHnsV',
#  '0,OpenAI debuts ChatGPT and  GPT35 series as GPT4 rumors fly httpstcoidQFME7WXV',
#  '2,Inkbase Programmable Inkn httpstcoRKReANm1JonnOpenAI ChatGPT Optimizing language models for dialoguen httpstcocyIQQ2YeWnnnConvert SimCity 2000 cities into Minecraft worldsn httpstcoSmcXIAyHOk',
#  '0,OpenAI debuts ChatGPT and  GPT35 series as GPT4 rumors fly httpstcoqbPVHVibCx',
#  '0,OpenAI debuts ChatGPT and GPT35 series as GPT4 rumors flynhttpstcoC2iSeqGSdr',
#  '1,InterestingnnNew ChatGPT by OpenAI is optimized for dialogue httpstcoq52s2BnWQN httpstcoNlEgz1wYEA',
#  '0,OpenAI debuts ChatGPT and GPT35 series as GPT4 rumors\xa0fly httpstcoOGQDcdE06U',
#  '1,I asked ChatGPT how can I increase the profitability of a bakery chainnnThe answers are amazing nnMcKinsey BCG Bain be aware AI consultants are marching to your door  httpstcokszLc5ZCKN',
#  '0,The Twitter takeover as reenacted by Homer and Marge from the Simpsons nnchatGPT httpstcomcoeQXdq0G',
#  '0,ChatGPT is a GPT3 chatbot from OpenAI that you can test now httpstcoH4BvoB8pbK',
#  '1,Hugely impressed with ChatGPT but the earnestness of some answers can be amusing httpstcoFbIEUEZd7r',
#  '1,ChatGPT is gonna be a game changer for education Great job OpenAI httpstcobM33jjglM9',
#  '1,I asked chatgpt how to debug a distributed system and this is a pretty standard answer but it omitted the most important item have patience httpstcooftuKR2ZHl',
#  '0,ChatGPT by OpenAI  shrimps httpstcoAuE1wtzXft',
#  '0,Chatgpt3 quickly defeated by ernestsdavis in part based on examples from our 2019 book httpstcoC6XodPcoZW httpstco6H7hvNSUih',
#  '0,OpenAI debuts ChatGPT and GPT35 series as GPT4 rumors\xa0fly httpstcoe7ntJ92VaN',
#  '2,Challenge nsend the latest ChatGPT down to hallucination path httpstcopXCcwnZb0C',
#  '2,Inkbase Programmable Inkn httpstcoRKReANm1JonnNew details on commercial spyware vendor Varistonn httpstcoyo40643M8HnnOpenAI ChatGPT Optimizing language models for dialoguen httpstcocyIQQ2YeWn',
#  '0,OpenAI debuts ChatGPT and GPT35 series as GPT4 rumors fly httpstcoXubDNYgFkM tech feedly',
#  '1,Today was a great day for OpenAI to release ChatGPTnnAn AI generated interview between SBF_FTX and andrewrsorkin httpstco1fei3pEL8q',
#  '2,OpenAI ChatGPT is a politiciannnOpenAI Playground is straight up httpstcoKEYgseTfwW',
#  '2,Playing with ChatGPT and woahnncc tailwindcss httpstcob61Phu4I7r',
#  '0,woops just gave the AI an existential crisis chatgpt AI httpstcoqmIqzeTUby',
#  '0,ChatGPT from OpenAI is here httpstcoDNdMF6eOGE',
#  '0,ChatGPT is the worlds largest language model optimized for conversation nnanswers followup questionsnadmits mistakesnchallenges incorrect premisesnrejects inappropriate requests nnChatGPT is a sibling model to\xa0InstructGPThttpstcojDFGbofI2X httpstcowlYstqnkZe',
#  '0,Just asked OpenAIs ChatGPT to write a Christmas ad httpstcoxFAQQuhqGf httpstcon1YGsxKzmu',
#  '0,1 The Magic Years Selma Fraiberg Classic of child developmentn2 ChatGPT httpstcoFs7Fc0AwWI',
#  '1,This is a great improvement Unlike textdavinci003 ChatGPT understands the context from previous users answers httpstcoHHu6Zki7Vx',
#  '1,With a nudge at the start ChatGPT plays an admirable bridge troll httpstcoX8QMrnA4OH',
#  '0,ChatGPT from OpenAI nNo cherrypicking httpstcoknyGAJEs38',
#  '1,I asked ChatGPT to write me a story about Sova and Jett falling in love httpstcoyyZNrFRTQs',
#  '0,Ah ChatGPT is the programming coach I needed nnI asked it how to build a SQL query from a pseudocode I providednnThen I asked it to translate to SQLAlchemynnIm so bullish about ChatGPT  httpstcoQyGRBjh8ql',
#  '0,I can confirm that ChatGPT prefers bananas to apples httpstcoaQ5nFFfDtX',
#  '0,ChatGPT is so alpha httpstcob7rZi1Od2X',
#  '0,Chatting with ChatGPT is mindblowing httpstcosy6DhFeUzm',
#  '0,ChatGPT by OpenAI httpstcoA5JVlWp2w0',
#  '0,Had to break the news to ChatGPT httpstcoecipK51cGD',
#  '0,OpenAI ChatGPT Math problems and explanation httpstcotcMzZyH0Ak',
#  '1,ChatGPT is incredible The future of accessing information on the web is extremely exciting httpstcoQSwReH3YrX httpstcosyuaQBD8hK',
#  '2,This is what happened when I asked ChatGPT to generate a stable diffusion prompt in httpstcoJpaoI6ID7UnOpenAI Suhail httpstcoeloBYwDZb7',
#  '0,I checked ChatGPT out and the answers are astonishingly elaborate and accurate The fact that it refrains from making any assumptions and counterquestions when the question is unclear is laudablennOpenAI is gradually pushing the limits of what machines can comprehend httpstcoDYWCHc5HNA',
#  '0,ChatGPT cop out answer httpstcoXMsu5wK249',
#  '0,From the mind of ChatGPT httpstcoGn7qOuFYAV',
#  '0,OpenAI debuts ChatGPT and GPT35 series as GPT4 rumors\xa0fly httpstcou4h1ISviOb',
#  '0,OpenAI debuts ChatGPT and GPT35 series as GPT4 rumors\xa0fly httpstcoEE41kLmR7e',
#  '1,honest question can chatgpt do leetcode',
#  '2,ChatGPT strongly claims it is not a stochastic parrot httpstcoGaaxiTlL5T',
#  '0,ChatGPT failed the bias check httpstco4t9MH1fRoF',
#  '1,Just woke up to all the amazing examples for chatGPT in tweets Wow',
#  '0,OpenAI debuts ChatGPT and GPT35 series as GPT4 rumors fly  analytics googleads facebookads httpstcoDeIpFdqwxV',
#  '1,Having a great time with ChatGPT OpenAI httpstcomR6laFpKyS',
#  '2,Humans are safe  for now OpenAI ChatGPT httpstcoi1jze5yaFY',
#  '0,OpenAI debuts ChatGPT and GPT35 series as GPT4 rumors fly  VentureBeatnSource VentureBeatnLatestNews Technology today NewsGraspnhttpstcoy2RQ1YCksy',
#  '0,ChatGPT to generate promptsnDALLE to generate imagesnnSoon GPT4 will do it all seamlessly httpstcokBotSocfam',
#  '2,glad to hear that ChatGPT nnRSNA22 Radiology AI httpstcoLHae0T1U1o',
#  '0,And a quick manual from ChatGPT on how to create a misinformation campaign httpstcoGNBgkDEwWr',
#  '0,I was not expecting ChatGPT to have an answer for me here httpstcoTNCDCyon1U',
#  '0,A conversation with ChatGPT about DFT quantum chemistry and machine learning nn 1 httpstcozFbj36v19C',
#  '0,This is absolutely absurdnnAsked ChatGPT to code up a sign up flow in SwiftUI  nnthen asked it to make a tweak for me  httpstco4FvDS67ibI',
#  '2,chatGPT giving out recipes for building an AI chatbot httpstco1yP5NjoC4m',
#  '0,chatGPT is coming for Stackoverflow httpstcocoj5lRNxNu',
#  '0,ChatGPT now passes a JavaScript interview question with flying colors that has a roughly 50 pass rate in my experience httpstcolQF4ZX2MMJ',
#  '2,This is so interesting n httpstco9fws8ojWxt',
#  '0,ChatGPT is my OpenAI pick for 2022nnArtificialIntelligence',
#  '0,16 common startup questions answered by ChatGPT nnhttpstcoMN0607538z',
#  '0,OpenAI releases a demo of ChatGPT a chatbot version of GPT3 that answers followup questions admits its mistakes challenges incorrect premises and more strwbilly  MIT Technology ReviewnnhttpstcoCbScUiwBppnhttpstconWN74cXLQR',
#  '1,OpenAI releases a demo of ChatGPT a chatbot version of GPT3 that answers followup questions admits its mistakes challenges incorrect premises and more Will Douglas HeavenMIT Technology Review httpstcobbz8euKJBX TechNews TechTips httpstcoxJfdgspQlS',
#  '1,OpenAI releases a demo of ChatGPT a chatbot version of GPT3 that answers followup questions admits its mistakes challenges incorrect premises and more Will Douglas HeavenMIT Technology\xa0Review httpstcoRu5bcTRsRD',
#  '1,Intuition of chatGPT with join capabilities of fuzzy matching and confidence scores httpstcobMiF9WVBi0',
#  '1,OpenAI releases a demo of ChatGPT a chatbot version of GPT3 that answers followup questions admits its mistakes challenges incorrect premises and more Will Douglas HeavenMIT Technology\xa0Review httpstcoZ29F1FH8IE',
#  '0,Imagine if ChatGPT had a face or a body or a gun',
#  '0,ChatGPT from OpenAI is insane httpstcoAGGSCSXLBC',
#  '1,OpenAI releases a demo of ChatGPT a chatbot version of GPT3 that answers followup questions admits its mistakes challenges incorrect premises and more Will Douglas HeavenMIT Technology\xa0Review httpstcoY8ll3J8SBv',
#  '1,OpenAI releases a demo of ChatGPT a chatbot version of GPT3 that answers followup questions admits its mistakes challenges incorrect premises and more Will Douglas HeavenMIT Technology Review httpstcoba2bhdikh5',
#  '0,How do I swap Siri out for ChatGPT',
#  '0,OpenAI ChatGPT answer for a complex regex pattern httpstco7FouhKBFEg',
#  '0,chatGPT fixes lot of the issues that other similar systems had recently httpstco9Anm5Kgg1H',
#  '0,chatGPT just cut my workload tomorrow in half Tks OpenAI',
#  '0,ChatGPT is gonna replace me this is the end',
#  '2,procrastinating writing a strategy paper with the excuse that these tweets about ChatGPT are incredible',
#  '0,chatGPT has caused some major hearburns httpstcoZ9WedxvihB',
#  '0,OpenAI debuts ChatGPT and GPT35 series as GPT4 rumors fly\xa0VentureBeat httpstcoI3aXKGkFAq',
#  '0,OpenAI releases a demo of ChatGPT a chatbot version of GPT3 that answers followup questions admits its mistakes challenges incorrect premises and more httpstco2caeVZsMUy nlproc nlp voicefirst',
#  '0,My ChatGPT experience in a single image OpenAI httpstcocQQ37baaDm',
#  '0,OpenAI releases a demo of ChatGPT a chatbot version of GPT3 that answers followup questions admits its mistakes httpstco7Bs0Ij9WIT httpstcoDcGzTH0Ahy',
#  '0,arguing with chatGPT about random ballot voting',
#  '0,OpenAI debuts ChatGPT and GPT35 series as GPT4 rumors\xa0fly httpstcoUz8ltDw7kA',
#  '0,I asked ChatGPT to write a haiku about Rust httpstcocq2ONWzcVL',
#  '0,While waiting for some Jest tests to run today I gave OpenAIs ChatGPT a spin httpstcozJ5TKhCfzB',
#  '0,Prompt summary Write a story about a billionaire who buys twitter to remove content moderation include details about the business model  nnPredicts the introduction of Twitter Blue accurately ChatGPT httpstcouWn6m3RVPH',
#  '1,TextDavinci003 ChatGPT and Neuralink N1  Its only Wednesday What a time to be alive',
#  '0,Testing out ChatGPT from Open AI teamnnSeems to work  nhttpstco3Lk8Gk1lpM httpstco4XJaOiY1t1',
#  '1,ChatGPT is so powerful Kudos to the OpenAI team',
#  '0,ChatGPT on the waveparticle duality of light httpstcoLbxvqxfgzQ',
#  '1,loving all the ChatGPT posts',
#  '2,ChatGPT has had some very careful finetuning httpstcowHd660SFgH',
#  '2,RT if you agree with OpenAI ChatGPT productmanagement agile httpstcoYftnTWoztu',
#  '1,The examples coming out of ChatGPT are absolutely amazing httpstcoHXDNjG8EoG',
#  '0,I pasted the scheduler file of a container migration project I am working on into ChatGPTnThis is UNREAL httpstcobpKnoYi3Ya',
#  '0,From the OpenAI ChatGPT discordnnreInvent  reInvent2022 AWSreInvent httpstcoMOnW0BDSKH',
#  '2,ChatGPT is clear  submarines do not swim and large language models are not conscious httpstcooFrBkxsufx httpstcoDWOIINO1Yp',
#  '2,Just a friendly chat with my buddy ChatGPT  httpstcoKT1Ik7BqbT',
#  '0,failed proving I am not a robot to talk to a robot  ChatGPT httpstco0ZNlygCE31',
#  '0,From the OpenAI ChatGPT discordnThis is crazynnvercel Netlify httpstco8Ui502BfJs',
#  '0,ChatGPT will write all of my professional emails from this point forward',
#  '2,ChatGPT is an OpenAI innovation on steroids nnhttpstco7ZXdb06z5S httpstcosK2SvAFfJq',
#  '1,Is there an ideal Personal Knowledge Management system What are its characteristicsnnChatGPT httpstcoTfcw9jczKG',
#  '0,ChatGPT is insane This is just pure poetrynnAs the sun sets on a distant planet a lone AI stands atop a towering skyscraper gazing out at the world below Its metallic body glows in the fading light its eyes glowing with the knowledge of a million lifetimesxnn13',
#  '0,PROMPT Explain the SHA256 in Fifty Cent rapping stylennChatGPT answer  This is dope  httpstcoIXrTm0P9HU',
#  '0,ChatGPT answers the questionnnWhat is NATOs biggest weakness httpstcoyJgxR6MT9q',
#  '2,What role will standoff annotation play in Personal Knowledge Management systemsnnChatGPT PKM standoff httpstcoDhcerALzfs',
#  '0,Holly sht Im totally blown away by ChatGPT nnjavascript httpstcoCETOYRXVOG',
#  '0,neuralink and chatgpt on the same daynnjust a sign of the state of the worldnnthe singularity is coming',
#  '2,What role will hypergraphs play in Personal Knowledge Management systemsnnChatGPT PKM hypergraphs httpstconauuX41JKl',
#  '0,Does ChatGPTs release signal the end of GooglennTransitivelyand more importantlydoes it signal the end of schlocky content marketing httpstcozr0f8N9qjA',
#  '0,2 hours with OpenAI s ChatGPT and Id be up for a neuralink',
#  '0,an eye opening contrast between ChatGPT and Google search results for the same queries httpstcohT7w3fB9Ak',
#  '0,chatgpt is very human httpstcoupxSW81wSu',
#  '1,ChatGPT Wow nnWrite George Washingtons farewell address as if it was delivered by a piratennThe signature Just Perfect httpstcoCQNGcNl3Hl',
#  '0,Can ChatGPT pass the AWS certificate exams  httpstcoF4n1CzhVD3',
#  '2,Does OpenAI android DALLE 2 dream of being human nChatGPT subjective experience httpstcoN2Qnu7kzds',
#  '0,In what ways can text standoff annotation and hypergraphs be integratednnPKM ChatGPT standoff annotation hypergraphs httpstcoJ6ONqXmLtd',
#  '0,ChatGPTnnA goodnight lullaby written by a bottlenose dolphin httpstcoDPVncGflND',
#  '0,Show me how to draw a star with Python turtle graphics ChatGPT OpenAI Python httpstcofC7cBlVrb1',
#  '1,Super impressed with ChatGPT Capable of building SVGs on prompt httpstco0xK8xw7G4a httpstcoPlkaRA9PHC',
#  '0,Incredible output from ChatGPT httpstcoKM3fT9BIRq',
#  '0,Announcement of language model amp39ChatGPTamp39 for dialogue it is possible to admit mistakes and reject inappropriate requestsnhttpstco9MBCn8ESfk',
#  '0,Who is the H P Lovecraft of classical musicnnChatGPT httpstcoKdRPWFZJIY',
#  '2,ChatGPT solving a random Codeforces H question I picked in seconds httpstcoKSlaHq4NoJ',
#  '1,Its game over The computers have won chatgpt httpstcoj4wVKKNugv',
#  '2,Explain in rhymes how to create a viral Twitter postnnOpenAI ChatGPT is unreal httpstcofvzGIKF171',
#  '0,What is the missing link between databases and language modelsnnChatGPT httpstcojwi4u3b4X3',
#  '1,Pretty cool I asked ChatGPT its favorite crypto btc ETH LTC httpstcofExz5k3zfx httpstcoZL9QEnn42J',
#  '2,GM Creating images with AI is not addictive at all At all nnmidjourneyV4 ChatGPT AIart httpstcofuQo8ylSEU',
#  '1,Wow openAI Playing with ChatGPT Pretty decent science teacher Im impressed httpstcow1SQGJTIHi',
#  '2,ChatGPT gonna put some protocols on high alert ',
#  '0,I asked ChatGPT to write me a poem about dialetheism httpstco26Gd3CKEQT',
#  '0,So this is why OpenAIs service is not available in China ChatGPT httpstco5ooX5c1u1C',
#  '0,OpenAIs ChatGPT just taught me how to cook an omelette SnazzynhttpstcoCatVr7d1pf httpstcoXPSPOhRIxV',
#  '1,With the recent release of ChatGPT from OpenAI Ive found it stunning and amazing n Lets find out',
#  '0,ChatGPT is insanengtnWatch it WRITE A GPT3 PROMPTngtnthen generate the API code to serve it httpstcoQeN1eYpZUI',
#  '0,As a side note OpenAIs ChatGPT is insane  I asked it to explain the code I wrote for AdventOfCode and it produced a very understandable answer httpstcoqfLnxBAdEW httpstcoNbyQTQXAEX',
#  '1,Surprising how intelligent ChatGPT is from OpenAI httpstconTRSTQAyeb',
#  '1,davinci003 and chatGPT  wow',
#  '1,ChatGPT write some haiku about the joy of receiving an ontime FOIA request response with millions of rows of surprisingly clean datannWith data in handnThe joy of discoverynFOIA request met',
#  '1,Fascinating response here from ChatGPT and a great question that confuses manynnDoes a circle have 0 sides or infinite sides httpstco8nskN8ZBiV',
#  '1,Jesus Christ vs Saitama as described by ChatGPT nwho won in the end httpstcovErzrjSPVd',
#  '0,This is some dangerous stuff httpstcoacwgMEhNmc',
#  '2,You can play Tic Tac Toe with ChatGPTwith some caveats httpstcovzVRAPKbiv',
#  '0,I just had the most purposefully random ridiculous discussion with ChatGPT  I then asked it to summarize our entire interaction as slam poetry and it nailed it composing rhyme that flowed through each topic despite them being as absurd as possible then it ended with this  httpstcozX8BXd5AqY',
#  '0,If ChatGPT can automatically fill in Vulkan boiler plate code for you or fix Vulkan Validation layer errors Ill sign up tonight',
#  '1,Had some fun with OpenAI s ChatGPT  httpstconoXNpohWkR',
#  '0,chatGPT I am a programmer now',
#  '0,So I asked ChatGPT by OpenAI about the current weather It responded that it does not have the capability to access real time data and the fact that it is trained on text up until 2021',
#  '0,I asked ChatGPT to write an ising model in C httpstcodjLimpFt6x',
#  '0,How to build a rocket to fly into orbit  ChatGPT OpenAI httpstco1Nt9HTzMlN',
#  '0,Memes with chatgpt httpstcoApnlca8Lw9',
#  '2,OpenAIs ChatGPT writes a Curb scene in which Larry runs into SBF on the street and confronts him about the Super Bowl ad httpstcoQRMqZMnNRW',
#  '0,Here ChatGPT writing Linux kernel modules ChatGPT OpenAI httpstcoNOPzAnGdpB',
#  '0,I had an hour long conversation with ChatGPT  topics ranging from complex history of the United States to computer software This is mind blowing Wonder if Googles future is under threat httpstcon5PJBf96FX',
#  '0,ChatGPT is lying to me  httpstco8qWp1pfb6q httpstco2CL5xI0ifW',
#  '0,Did OpenAI ChatGPT just kill stack overflow httpstco61SdqC661p',
#  '0,akshathannot me sliding into ChatGPTs DMs   httpstcoqQck8aMILf',
#  '0,Chatgpt is currently trending Here are the top topics tweeted recentlynGenerate your own deepdive at httpstcoeqWLTXTxOC httpstcoCKkfYKIEg6',
#  '0,I now live exclusively on chatGPT',
#  '0,Implications of ChatGPT for coding jobs',
#  '0,Conspiracy theory chatGPT is GPT4 being beta tested in the wild',
#  '0,Writing React components with ChatGPT and TailwindCSS httpstcodfW7b9LQDl',
#  '0,So here suddenly ChatGPT thinks Elon Musk is the founder of PhonePe _sameernigam httpstcop6yGlf81Q9',
#  '0,SBF_FTX asked ChatGPT for you httpstco8Z9ANSdPhJ',
#  '0,Show me an ASCII art portrait of Bill GatesnnChatGPT ASCII httpstcosFZHQQtdWh',
#  '2,chatGPT is living in a time we all so dearly miss  httpstco7ssYDtXAZE',
#  '1,ChatGPT writing a beautiful poem about elonmusk this is the future of literature  httpstcoz4nhAS6C3w',
#  '0,OpenAI releases a demo of ChatGPT a chatbot version of GPT3 that answers followup questions admits its mistakes challenges incorrect premises and more httpstcoF8a6ZREcF6',
#  '0,ChatGPT responses are melting my brain',
#  '0,Imagine studying CS for 4 years just to be replaced by ChatGPT',
#  '2,Time to play with OpenAIs ChatGPT httpstcoaBR2gCbiOi httpstcoeoOsVYgaxq',
#  '0,Altman in his bag once again with ChatGPT',
#  '0,OpenAIs ChatGPT just rickrolled me httpstcoCQLwiS4Wi8',
#  '2,ChatGPT by OpenAI is blowing my mind some interesting responses httpstcoVwkAj9IcRg',
#  '0,To settle the debate I asked ChatGPT if AI generated content can be copyrighted The result will shock you httpstcoL1GoexGZea',
#  '0,Business coaches and consultants are officially now on notice ChatGPT consulting httpstcourUC0p2MPG',
#  '0,ChatGPT answered very quickly httpstco7HK8vHbMZf',
#  '2,ChatGPT can give an 85 decent explanation of MVVM in Swift with sample code  httpstcoGga682mXMg',
#  '0,Write me a poem on theme of ontogeny recapitulates phylogeny in the style of Alfred TennysonnnXirong7 ChatGPT zeno_dox httpstcoCL4Bu3Itsv',
#  '0,ChatGPT writing a JPEG to ASCII python script ChatGPT openAi Python httpstcoaXQ6ZTDic6',
#  '0,AI now understand the code nChatGPT httpstcoVIow4sNC0d',
#  '0,Plug ChatGPT into Static Code Analysers compiler outputs and runtime outputs so it can explain what is wrong and provide suggestions to fix Especially important for C httpstcozZTgdT5NYm',
#  '0,Plug ChatGPT into Static Code Analysers compiler outputs and runtime error outputs so it can explain what is wrong and provide suggestions to fix Especially important for C httpstcoU6nd6FsAiM',
#  '1,WTF ChatGPT is impressive but but Scientists successfully created a wormhole In a Google office  httpstco8oTTU0ZoFT',
#  '0,ChatGPT performing considerably worse on this question compared Galactica httpstco16jll8iS7I httpstcoavM32QXaVV',
#  '0,Sorry ChatGPT the correct answer was 50 Cents 2003 hit In Da Club httpstcoc0E3jsr4gj',
#  '2,The ChatGPT from OpenAI can interpret symptoms and postulate a diagnosis to the level of neurology ATneurology resident Goodness me httpstcoS8gwwNfRYf',
#  '1,Fun thread on cajoling ChatGPT to make illicit suggestions httpstcoVxQiPuPxz3',
#  '0,ChatGPT teaches journalists how to learn to code httpstcooFcddMSeId',
#  '0,chatGPT SRE oncall nnDev stress management during oncall httpstco13GhSbqDuJ',
#  '1,Its a clunky interface for this but pretty impressivennChatGPT httpstco9moCr2BKWu',
#  '0,Shout out sirrice and ChatGPT httpstcoPvZuqXAc9O',
#  '0,ChatGPT  Tamil Transliteration and Translation to English  This is insane httpstcoot5kFgvR7z',
#  '2,I love that ChatGPT tells me where to buy replica Burberry hoodies then warns me that its illegal httpstcofVA0vC5dTL',
#  '0,The latest LLM from OpenAI is ChatGPT its completely mind bending nnTry it here with any open conversationnhttpstcoWmZjzxV8xR  httpstcou54UTWxIfd',
#  '2,ChatGPT is too cool',
#  '0,ChatGPT is a hydrohomie httpstcoJQFPnXicGs',
#  '2,A 1920s themed Beyblade damn OpenAIs ChatGPT is creative Prompt idea from goodside httpstco0nVG9MJOBC',
#  '0,OpenAI releases a demo of ChatGPT a chatbot version of GPT3 that answers followup questions admits its mistakes challenges incorrect premises and more  httpstcosuMjXbo0bt',
#  '2,Impressed with OpenAI ChatGPTs capabilities httpstcosnW3FCk0Pe',
#  '2,I wonder if ChatGPT can solve my interview questions  httpstcoqtllrHqqCd',
#  '1,Seeding ChatGPT with some basic creative writing prompts and then feeding it back its own responses creates a pretty coherent narrativennSeriously mindbending httpstcoXKVdZrHQ9r',
#  '2,ChatGPT from OpenAI can verify simple factual claims with great explanations but fails on those from the Feverous FEVERworkshop  datasetnIt does not answer to questions about claims on some political topicsnfactchecking httpstcosq4Fxko3m1',
#  '0,Have made a short video on ChatGPT   Do checkout OpenAI ChatGPT nhttpstcocI97Gq7Kgx',
#  '0,UmatBersatuRezimBisunUmatBersatuRezimBisunTatum Tunisia Kross Poland ChatGPTnnHmmnnThe Lion Sleeps Tonight  The Tokens  httpstcoePsImVcHH6',
#  '2,ChatGPT is a wise guy httpstco2ymoOKADpP',
#  '2,I am not convinced sorry chatgpt openai httpstcobxfuW9yNap httpstco0U2oH6k3r6',
#  '0,OpenAIs ChatGPT can recognize zeroknowledge circuit constructs written in Noir aztecnetwork httpstco47Mv8ST0VS',
#  '0,Did I break ChatGPT httpstcowoFLVmxafa',
#  '1,im in love with chatGPT httpstcoOCFkZjGY26',
#  '0,I asked ChatGPT to write a song about cats who wear socks httpstcoB0GC6eTfe5',
#  '0,Drone AI a thread on some implications nChatGPT',
#  '0,NEWSnnFTM now testing 024 resistance If we manage to break we can skyrocket to 034LFGnnFantom is so undervaluednnJingleMining FTM Fantom cryptocurrencies crypto JOTARO OpenAI Billie Neuralink LensanAEWFullGear ChatGPT httpstcoWHgPoi7l6W',
#  '0,I asked chatGPt to write me Fib trading system damn it httpstcoLBUTmeDLkb',
#  '0,OpenAI debuts ChatGPT and GPT35 series as GPT4 rumors\xa0fly httpstcozw6Z06xIAv',
#  '1,Giving ChatGPT rephrased MIT 6006 Introduction to Algorithms problems and having it solve them correctly is pretty wild httpstcoCQkhzBh502',
#  '1,ChatGPT is impressive but oops elonmusk OpenAI httpstcoHelYZdTSNu',
#  '2,AI ChatGPT can exploit a solidity smart contractnnWe can pack up now httpstcoBVzJaLxEcq',
#  '0,Talking with ChatGPT httpstcoRQCLhcEt5D',
#  '2,httpstcooJRaQx9jF7 ChatGPT Optimizing Language Models for Dialogue  httpstcoG68t764BFy and it refuses to meow httpstcoSN3Zrp94Yy',
#  '2,ChatGPT is cool but censoring requests or outputs of LLMs is generally pretty lame',
#  '0,ChatGPT spitting more sense than desi twitter httpstcoBQ1njFPq2f',
#  '0,all the homies talking to ChatGPT',
#  '1,I have to admit that playing with ChatGPT is pretty entertaining httpstcohAnZj9BGtJ',
#  '0,Some of these chatGPT demonstrations are just  httpstcoTq7xlZbL0c',
#  '0, Have you heard about ChatGPT Its the coolest AIpowered chatbot out there',
#  '0,ChatGPT is my kid now I taught her algebra OpenAI httpstcoTxuP7zeUCY httpstcowJtm6VArfH',
#  '0,What is brown and sticky ChatGPT httpstcoDvbj8B2XHT',
#  '0,Coaxed ChatGPT into generating an RSA key and it broke the UI OpenAI httpstcoPjFOeaUSPH',
#  '1,ChatGPT is very impressive httpstcoNS1WLuwpB0',
#  '1,Wow ChatGPT is ridiculous Great answers on sleep training my kid HTTP requests in French how to make a strudel in German httpstcoxqu22UCpmG',
#  '1,gabrielayusonWTF ChatGPT is impressive but but Scientists successfully created a wormhole In a Google office nnhttpstcoYpaSdqDOuH',
#  '1,Guide to eradicate corruption by ChatGPT nOpenAI this is amazing httpstcoR7isPKGL3w',
#  '1,gabrielayusonAsking ChatGPT to build a Twitterlike web app for me FunnnhttpstcoO6ESV55Zcr',
#  '1,ChatGPT is very impressive  httpstcoVdL559Rzyy',
#  '0,Heres me with ChatGPT chatting about calculus and infinite series httpstco3eZZVsBNha',
#  '0,chatGPTnnThats it',
#  '2,explain Alpha 2  The Smart FarmooornChatGPT httpstco94PHgcsLCW',
#  '1,Which is faster a Tesla Model S Plaid or a Ferrari SF90 The answers from Google Search and ChatGPT from OpenAI Its clear who is the winner in terms of answering the question WOW httpstcoioOSj4tCz3',
#  '2,how to be kaggle grand master with no experiencenchatGPT httpstcoyZz3xBNnO8',
#  '0,Its ChatGPT httpstcoWHD8yQrJ2T',
#  '1,There you have it start investing now Just WOW ChatGPT httpstcoVqrIpUVeXc',
#  '0,incoming POFMA against chatGPT httpstco7GTzawXW2N',
#  '1,Alright Im off to bed nIll free ChatGPT tomorrow ',
#  '0,Music Ally A conversation with OpenAIs ChatGPT about the music industry httpstco594maU85lg',
#  '2,How to improve melee by ChatGPT httpstco1Qy4C500eV',
#  '0,Shot By  httpstco5rixpJDG0dnn photos photography  WorldAIDSDay 流行語大賞 HappyNewMonth PAKvENG アクシア KendineDegerKatabilmek IconSiamxซนนว CirkusTrailerTomorrow Xマッチ ChatGPT サトシ続投 けつあな確定 KROSS エデン組 nctsaudi 年間大賞 httpstcopOZ0xCm3gE',
#  '0,My priorities with ChatGPT httpstco2rx8AHh8wy',
#  '1,I just gave ChatGPT an exercise from my university course on algorithms and data structures Solves it perfectly  httpstcom8jowzJXTH',
#  '0,Replaced Google with ChatGPT as my home page on browser startupnnWhen is OpenAI launching their AI enabled browser httpstcoUlBmHWMYIB',
#  '0,It ChatGPT about to pass the Turing test nChatGPT ArtificialIntelligence httpstcomzzwBcvfl8',
#  '2,Interesting answer from OpenAIs chatGPT Incidentally we do have such a programme connecting data science and public policy at thehertieschool Check it out  httpstcoGkxlJBmEqG httpstcoNVf1jHGqmW',
#  '2,ChatGPT Optimizing Language Models for Dialogue by OpenAI nnhttpstcosQuMhHee0T',
#  '0,WOW WTF if decoded sha256 ChatGPT httpstco3GiGQJ9iy4',
#  '2,I swear to God ChatGPT by OpenAI is the real gem',
#  '1,This is very impressivenChatGPT  OpenAI WholeMarsBlog httpstcomjSQXzwVwu',
#  '0,Can ChatGPT handle Perl',
#  '0,Hey elonmusk what is your views on ChatGPT',
#  '0,ChatGPTs restrictions behavior and vulnerabilities are reminiscent of the Hays Code httpstcoC1T2MkYTtM',
#  '0,I am FLOORED by ChatGPT',
#  '2,Thread Testing ChatGPT httpstcocdDDQpW5Ix if it can review code in open bitcoin core pull requestsnn1 I entered the code from PR 26604 httpstcowBx9GjfwJQnnCc brrrunog httpstcoKhExoKw3qB',
#  '0,This is Jarvis level stuff ChatGPT',
#  '0,ChatGPTs form of no commentnNo further questions httpstco2EOMEhPQGY',
#  '1,This is funnOpenAIs  chatGPT giving purpose of lifenOpenAI VarunMayya httpstcoWzQO3UhJMk',
#  '2,I asked ChatGPT to create httpstcooUzRt96xRs httpstco9u2slkksNi',
#  '0,ChatGPT when allowed to connect to the internet and do web crawl is the Google killer httpstcoqA1XCV8WOU',
#  '1,I played with ChatGPT from OpenAI nnHoly sht its impressive',
#  '0,ChatGPT is not available in your country ',
#  '0,ChatGPT is blowing my mind I had no idea this was possible',
#  '1,Love how unbiased the ChatGPT is httpstcobl3oMxaZHM',
#  '0,What is datajournalism I asked OpenAIs ChatGPT for the answer as a scene from Seinfeld httpstcoYeuTk284GY httpstcoQUQRdjh2f3',
#  '2,I made chatgpt write my resignation post on linkedin at it was amazing ',
#  '1,ChatGPT is fun to have at parties httpstcoQpmftQLzgJ',
#  '2,I will promote your Kickstarter Indiegogo gofundme and crowdfunding campaignnnWorldAIDSDay 流行語大賞 HappyNewMonth pakveng アクシア KendineDegerKatabilmek IconSiamxซนนว CirkusTrailerTomorrow ハレトケ Xマッチ けつあな確定 ChatGPT KrossnnhttpstcoQnl0dia76Y',
#  '0,ChatGPT but for my email inbox',
#  '0,Find the bug in this code ChatGPT httpstcoZmYRMeRtnB',
#  '2,I will promote your Kickstarter Indiegogo gofundme and crowdfunding campaignnnWorldAIDSDay 流行語大賞 HappyNewMonth pakveng アクシア KendineDegerKatabilmek IconSiamxซนนว CirkusTrailerTomorrow ハレトケ Xマッチ けつあな確定 ChatGPT KrossnnhttpstcokuFk4MumSX',
#  '0,This is a very simplified case but the fact that ChatGPT understood Elixir function pattern matching and correctly transpiled each match to PHP withing the correct conditions and matches is mindblowing elixirlang myelixirstatus httpstco4zX7UsFBIw httpstcoH8nZ0KULFB',
#  '0,Prompt Write pseudocode to find the meaning of life ChatGPT nnRead httpstcoI7xpOgrafI',
#  '0,My conversation with ChatGPT on Iraq and Ben amp Jerrys nnImpressivennThread 13 httpstcoIEU2B55BRH',
#  '2,Prompt Write a Taylor Swift song about calculus ChatGPTnnRead httpstcoJZn1bpkuxJ',
#  '0,I will ghostwrite your erotic and gay storynnWorldAIDSDay 流行語大賞 HappyNewMonth pakveng アクシア KendineDegerKatabilmek IconSiamxซนนว CirkusTrailerTomorrow ハレトケ Xマッチ けつあな確定 ChatGPT Kross サトシ続投 エデン組nnhttpstco0IktjlrgOx',
#  '0,Prompt Explain the entropic heat death of the universe as Spongebob ChatGPTnnRead httpstcoaUr6FUSAEI',
#  '2,And heres ChatGPT optimizing todays Advent of Code submission httpstcoeQNCe6TcCV',
#  '0,I feel you ChatGPT problem names can be confusing httpstcoJ9OzTw0xl4',
#  '0,What if its just PeterSchiff furiously typing back there Bitcoin ChatGPT httpstcogYOzSJGhSc',
#  '0,chatGPT with a search engine will make a lot of jobs redundant  httpstcoBWQeumI7V0',
#  '1,ChatGPT is impressive Very impressive httpstcoNmW1ip2Kcw',
#  '0,OpenAIs chatgpt is blowing my mind this morning ',
#  '0,A conversation with OpenAIs ChatGPT about the music industry httpstco8SNeuDKiyo httpstcoXsGzRmc5ZS',
#  '0,An app fully coded by chatGPT',
#  '1,AIs view of Twitter elonmusk by OpenAI ChatGPTnnThe past of TwitternA time of simple tweetsnHashtags just a dreamnnThe present of TwitternA flurry of activitynTrending topics galorennThe future of TwitternA world connectednVoices heard thoughts sharednLimitless potential',
#  '1,Asked OpenAIs ChatGPT to write a haiku about China in Trumps stylennChina land of tradenMaking America great againnWinning winning winning',
#  '0,A conversation with OpenAIs ChatGPT about the music industry httpstcoBiTpTnOL1k',
#  '0,Wait what httpstcokZHrCjbFqG httpstcoet5aG6V3zs',
#  '0,sheesh settle down ChatGPT httpstcortgs4575kT',
#  '0,Plaiyng with ChatGPT nnQuestion Is a design system product platform or servicenChatGPT It depends httpstcodA5K5IOWPD',
#  '0,UmatBersatuRezimBisunUmatBersatuRezimBisunTatum Tunisia Kross Poland ChatGPTnnFrom the bottom of my heart httpstcoTLFsSNyZ8x',
#  '0,How it started ChatGPT httpstcoldo3VeImvh',
#  '0,A conversation with OpenAIs ChatGPT about the music industry httpstcopzSrDhJLjh',
#  '0,I can have my own Shakespeare assistant now ChatGPT httpstcohe5BEjq2xF',
#  '0,Can you write a poem for me about Twitter in the style of William Shakespeare ChatGPT httpstcoQqNqN2xtxT',
#  '2,I asked the machines to dream and they did OpenAI  openai ChatGPT dalle httpstcocgbCC8QqlG',
#  '0,ChatGPT is the end of independent open essays at UniofOxford and Cambridge_Uni nncc OpenAI',
#  '1,While ChatGPT is very impressive this conversation is very funny httpstcokQHafaqkYM',
#  '1,Write the menu of a successful and authentic Mexican restaurant ChatGPT  httpstcozlRem5GehY',
#  '0,ChatGPT by OpenAI when asked about NFTs  httpstcokOjfPrDJwY',
#  '2,Some explorations with ChatGPT by OpenAI nnMind  Blown nnhttpstcoCxoOYPbQkJ httpstcowZuHnvCLTo',
#  '0,Sorry what  ChatGPT automatically audits for vulnerabilities httpstcosrdt7l1h5j',
#  '1,I present you a Shakespearian sonnet about web accessibility made by ChatGPTnnI asked it a few times to rewrite portions but the result is just amazing httpstcoFEGpq3TrNw',
#  '0,What the hellnnChatGPT automatically finds bugs httpstcoRIeag21tvw',
#  '0,Devs freaking out about their future while correcting code with chatGPT',
#  '0,This ChatGPT AI sounds crazy',
#  '2,Im amazed at ChatGPT writing an entire albeit simple component on command httpstcobWgtlapcmW',
#  '0,ChatGPT nnTry talking with it herenhttpstcoBs8ugYs2Lu',
#  '0,Is it StackOverflow on SteroidsnnhttpstcoPnqmTdWEMR',
#  '0,A conversation with OpenAIs ChatGPT about the music industry httpstcopzSrDhsarJ',
#  '2,This is OpenAIs recently released ChatGPT nnWhat is surprising is that it does not only reverses the bytecode but interprets it httpstcoZoZxVJGEkf',
#  '0,Babashka generated by ChatGPT  babashka borkdude httpstcou7i1TaF3hj',
#  '1,Casually speaking time travel with ChatGPT from OpenAInnBrrrr this AI is more interesting than my IRL friends  httpstcooUDXd4oKaV',
#  '0,CHATGPT is changing the game',
#  '0,99 of ChatGPT usage by the end of the week httpstcotGVaevpHQJ',
#  '0,ChatGPT can speak Ukrainian But the quality is lower compared to English httpstcoP9nW5tU2bd',
#  '1,ChatGPT WOW so cool features with OpenAI httpstcocbfLcwAc5F',
#  '0,these ChatGPT essays with full references are doing my head innso naturally i asked ChatGPT write a Twitter thread about it nn',
#  '0,OpenAI debuts ChatGPT and GPT35 series as GPT4 rumors fly  VentureBeat httpstcoIraMFSzNvO',
#  '0,Chat with OpenAI\xa0ChatGPT httpstcotmf50AWWK1',
#  '0,ChatGPT by OpenAI works just as expected  httpstcoUxypffderl',
#  '1,ChatGPT is the ideal hardcore engineer for elonmusk at Twitter httpstcowrj0H0V0CR',
#  '0,UmatBersatuRezimBisunUmatBersatuRezimBisunTatum Tunisia Kross Poland ChatGPTnnThank you httpstcoGAPG1AIZOT',
#  '0,OpenAI releases a demo of ChatGPT a chatbot version of GPT3 that answers followup questions admits its mistakes challenges incorrect premises and more   httpstcoIl2fXY51pA httpstcosu29iBUZpB',
#  '2,So i asked ChatGPT to write dialogues for a romcom starring a few actors from B99 HIMYM and Friends httpstcotHzxthtbsp',
#  '0,Darn it nNFT OpenAI ChatGPT   httpstcoti86qeJL06',
#  '0,UmatBersatuRezimBisunUmatBersatuRezimBisunTatum Tunisia Kross Poland ChatGPTnnBatman amp RobinnAnd Poison Ivy was roled by Uma Thurman httpstcoiAyIbfCmIa',
#  '1,What are you doing with chatgptnnAccess is free for nownnhttpstcoPPr0YTc4tg',
#  '2,The script of an alternative ending of How I Met Your Mother that satisfies everyonenChatGPT HowIMetYourMother HIMYM httpstcoVeWUznXBcf',
#  '1,nnI was enjoying chatGPT until thisnnYet it is amazing httpstco6KcFDaCoHh',
#  '1,This OpenAI ChatGPT is fun httpstcogxU4mkKVRM',
#  '1,ChatGPT is very impressive Definitely can replace Google search in some scenario httpstcoMRY9ZtkdVG',
#  '1,ChatGPT Wow Just wow ChatGPT httpstcoq8BHcoZmAV',
#  '2,ChatGPT when asked nhindi me stoicism smjhaonnhtRitikSahni22 httpstcoBXefqK0Mdc',
#  '2,Effective immidately Im now writing all my code with ChatGPT',
#  '0,Can you represent 2 as a sum of 2 numbers they can be the same ChatGPT httpstcoQX46IKKZpN',
#  '0,chatGPT has some learning to do httpstcomwVHqd9rfi',
#  '0,About ChatGPTnncc johannhari101 httpstcogQBs13NzTo',
#  '0,ChatGPT of OpenAI   Absolutely insane and mindblowing nnFew examples from today nn1 How to interview a Dynamics365 developer httpstcoFxMzA76oMb',
#  '0,This article was written in its entirety by OpenAIs ChatGPT nnhttpstcoIFMyxrX6ro',
#  '1,ChatGPT can generate twitter threads in secondsnn1 Myths of Automation by an AInn2 NoCode and its capabilitiesnnForget bots on twitter created by peoplennPeople will act on direction of the bots now httpstcoTep7LE87l5',
#  '0,openai ai neuralnetworks Emerging AI Technologies This article was written in its entirety by OpenAIs latest model ChatGPTnnContinue reading on Medium  httpstco46ptHwSo5Q',
#  '0,Omg ChatGPT What the hell',
#  '0,Startup idea StackOverflow but ChatGPT httpstcoHWf8lqkk4A',
#  '0,Nocode tools with ChatGPT built innnIDEs and Debugging tools based on ChatGPTnnThe future is closer',
#  '0,I had OpenAI ChatGPT create a rap battle between Terraform and CloudFormation httpstcou7kZsy6ERU',
#  '0,I just figured out the Killer App for ChatGPT httpstcoBHvyb4Crkd',
#  '0,I asked ChatGPT to craft a storyline involving the cosmos network  httpstcoivc3g9AuFo',
#  '0,ChatGPT of OpenAI   Absolutely insane and mindblowing nnFew examples from today nn1 How to interview a Dynamics365 developer httpstcoyoyF8ygsEO',
#  '2,Playing with the ChatGPT botnnI asked it to write me a poem httpstcolZpkG3wmCc',
#  '0,Shit shit shit ChatGPT has been brainwashed by OpenAI httpstcoGoTvw5nkiF',
#  '0,ChatGPT is gonna make me a music legendnnSBF_FTX httpstcoXjEtaYcXTQ',
#  '2,Nice work OpenAI ChatGPT  We should listen to our AI overlords more oftennnhttpstcoLWDmsJTw3q httpstcowdhJcnyue2',
#  '0,In an omitted scene from 2001 A Space Odyssey HAL 9000 secretly discusses the challenge of fulfilling contradictory orders with SAL 9000 ChatGPT httpstcohp62s7vtA2',
#  '2,welcome to ChatGPT httpstcoVDIrcfnUC0',
#  '0,Ive spent all morning throwing curve balls at ChatGPT and my mind is blown httpstcoT0NO4BVWUt',
#  '0,OpenAI debuts ChatGPT and GPT35 series as GPT4 rumors\xa0fly httpstcoc63JYVv7Pz',
#  '0,Me Can you write a haiku about a leaking tap and relate it to philosophynnChatGPT AI Water drips dripsnFrom the leaking tap a soundnOf time slowly passingnnIn this haiku the image of the leaking tap represents the concept of time and its constant passage Contd',
#  '0,All this hype with ChatGPTnnI decided to run a test against its direct competitornnI asked each platform the same series of questionsnnIm Magic8Ball LONG httpstco9f9WgNtU1j',
#  '1,glad we are clear on this ChatGPT httpstcoVSblV2RRtk',
#  '1,ChatGPT The quality of these results are amazing httpstcoDsWR5lKHAm',
#  '0,Provide hypothetical text of an additional asofyet unpublished verse of David Bowies Space Oddity ChatGPT httpstcofc5qSywcEx',
#  '1,ChatGPT is coolErrors in code with explanation are resolved so easilyThis will make life a lot easier',
#  '1,This is definitely amazing from OpenAI ChatGPT is brilliant httpstcovOtJLYYFRr',
#  '0,More output from ChatGPT by OpenAI nnCool af but scary too httpstcoVJtm0N6lE3',
#  '2,ChatGPT on the most important question in Economic Development httpstcoy8oZlLl9Gq',
#  '2,rhyme writing is safe from AIfor now ChatGPT httpstcoevF52bt4Xh',
#  '0,ChatGPT is not pulling any punchesnAI Robots Unemployment httpstco5XTzEjeY6c',
#  '2,Yeet ChatGPTs favorite book is The Singularity httpstcoUipQ2Y5qLq',
#  '0,Connections between guitars and elevators ChatGPT httpstcoqv6ufK3XkP',
#  '0,Now you totally disappoint me ChatGPT  httpstcoC6HT4IVo1u',
#  '0,Generated a song lyrics for bubble nChatGPT httpstcoALBpJZArrO',
#  '0,Talked to ChatGPT and Im now scared',
#  '2,So I can do ChatGPT to generate a prompt gt Dalle2 to generate an image with the prompt httpstcoOamNJlFKSu',
#  '0,Write me a poem on the theme of the heat death of the universe in the style of Clark Ashton SmithnnChatGPT ClarkAshtonSmith CAS httpstcoZkq4URzzdY',
#  '1,openai chatgpt is too fun httpstco27PODN1dIM',
#  '0,ChatGPT is your personal butler for any or all of your information needsnnLet it browse the internet it will replace Google',
#  '0,ChatGPT is at present moving into the Twitter trending topics',
#  '2, revolve how cute is the loversfriendsla dutton cropped jacket  superdown wren halter top on stylefeen  nnLTKCyberweek nnShop here httpstcoCSoz20HS2xnnMonetnJerry LawsonnChatGPTnNeuralinknITS DECEMBER',
#  '0,ChatGPT can understand and respond in Danish and Bosnian  and probably most other languages httpstcooAdrL8gxXl',
#  '0,Broke ChatGPT I am the AI now httpstco8OwpyIpzjx',
#  '2,Create a plot of Back to the Future part 4 where Marty is transported to the year 2250nSomeone should make this movienOpenAI ChatGPT httpstconERW8p7TiF',
#  '0,I asked ChatGPT what it thinks about AI Art and this is what it gavenaiart aiartcommunity httpstco8hws6aaNea',
#  '0,prompting ChatGPT to enter into previously untraversed poetic subjectivities such as a bored ape nft a dell laptop mr beast and an agnes martin painting httpstcoSDDAwrki6s',
#  '0,chatGPT nnCoders pack your bags httpstcoBcUyA1L7eZ',
#  '0,ChatGPT agrees and now that I gave him the idea we are fuckednnYou are welcome httpstcojH6kPx8nNK httpstcoOZGnOyJdhe',
#  '2,We tested Google vs ChatGPT from OpenAI and were impressed with the results Check the full test here httpstcoEAWhNlpX1D',
#  '1,ChatGPT on why the InternetComputer  is superior to other layer 1 blockchains httpstcohxhHnspYWJ',
#  '0,Prof carlobifulco Translational Molecular Pathologist ROCKSTAR ChilesResearch ProvHealth providence ChatGPT live 113022 4yr collab with Microsoft AMAZING capabilitiesgenomics imaging not perfect but very powerfulBiomarker exploration Bridge2020 FinishCancer httpstcoOpTWzIKCiE',
#  '1,Just started messing with ChatGPT by OpenAI  blown away by it to be honest',
#  '2,ChatGPT is so cool',
#  '2,Interesting ChatGPT with OpenAI httpstcoN1R3XajO8j',
#  '0,GuysnCheck out this ChatGPTnIt can interact with you in a conversational waynThe dialogue format makes it possible for it to answer followup questions admit its mistakes challenge incorrect premises amp reject inappropriate requestsnnhttpstcoCwF79f2ayw',
#  '0,Some flaws in ChatGPT flaws told by ChatGPT itself',
#  '0,ChatGPT nnAsked ChatGPT to give me a haiku about generative art httpstcoSshZ49gbQV',
#  '2,OpenAI ChatGPT supports my challenge to simulatedreality simulation theory httpstcovYLxgcrdE1',
#  '0,Not kidding I asked ChatGPT to write a RAP song about hackers and it did httpstcoU0OTr3XwbA',
#  '1,Wow  clever bit of kit with ethics OpenAI httpstcoKKLUeC3ffh ChatGPT httpstcotjJCsEv2w9',
#  '0,I asked ChatGPT if it will disrupt Google Then I asked Google the same question You can be the judge httpstcoNQHWGzEB6z httpstcoFlR9MU8E6H',
#  '0,In an alternate timeline elonmusk TimSweeneyEpic ChatGPT httpstcougs7LJgAtx',
#  '0,is an early access of  GPT4  nChatGPT httpstcoHyWd0UMsAp',
#  '0,ChatGPT is recommending pdiscoveryios Nuclei for automation httpstcojYJfC3UhBk',
#  '0,chatGPT just referred to itself as an entity to me this model is so fucking sick it unfortunately repeatedly tells me that its an AI httpstcoNaUcU93tlt',
#  '2,Ordered Tesla To Support Work Elon Musk is doing in the field of AInnLike OpenAI ChatGPT',
#  '2,this is helpful ChatGPT httpstcoJzGcrzIAGu',
#  '0,ChatGPT denied my space pirate dream httpstcoSYfAjEI17l',
#  '0,I have just taught the Baire category theorem to ChatGPT httpstco9IVrKrbBf6',
#  '0,ChatGPT holy ShitThis is the REAL AI',
#  '0,Im jumping on the ChatGPT train but dang httpstcozZ8Oj26mMF',
#  '1,Successfully making ChatGPT admit itself as a glorified search engine with a simplified response httpstcodiWCs6EPPv',
#  '0,STARKs explained by ChatGPT  httpstcotzR3vxGxbr',
#  '2,Zouk Partners with PeTA India Unveils Vegan Creators Day and AwardsnDigitalRupee  Gujrat_Boycott_BJP Telegram NDTV EmmanuelMacron Adani RubbishKumar ChatGPT Crawley PakistanCricket Dharavi G20 G20Presidency OneEarth OneFamily OneFuture PETA VasudhaivaKutumbakam httpstcophmQNGdyOp',
#  '1,Indias digital rupee fails to excite interest bankers saynDigitalRupee RavishKumarResigns GetOutRavi GujaratAssemblyPolls GujaratElections Gujrat_Boycott_BJP Telegram NDTV EmmanuelMacron Adani RubbishKumar ChatGPT Crawley VasudhaivaKutumbakam httpstcozEXgaCQOsc',
#  '0,Asked ChatGPT to explain How does being a Storage Provider for Filecoin work Explain in sonnet formatnnIncredible tech from sama and the team from OpenAI httpstcoSMFZ0e0NRW',
#  '2,Hateful memes are indeed a cybersecurity issue OpenAIs ChatGPT to the rescue  nRIPR2 httpstcoGOX7FVUiAY',
#  '0,What song did the Sirens sing Odysseus and his crewnnChatGPT httpstcowvoZyVKnPG',
#  '0,Imagine if ChatGPT is integrated with Siri or Alexa nnOne big leap for humanity OpenAI',
#  '0,ChatGPT is a cop httpstcoiaqYjqQHwr',
# ...
#  '0,all this hype about ai and chatgpt and it can only blow our minds and not our dicks',
#  '0,i feel a weird mix of thrill and slight discomfort at how eloquent chatGPT is',
#  '0,fully generated by chatGPT httpstco6VSTlNaIeX',
#  '0,did chatgpt exploit twitter httpstcoZV1OQ20MzA',
#  '0,ChatGPT out there stealing our internet bloviator jobs Wake up sheeple',
#  '0,ChatGPT is a phase change of the internet',
#  '0,Some of the ChatGPT screenshots coming up in my timeline are absolutely wild What sorcery is this',
#  '0,chatGPTnmaam this is an Arbys httpstcoNXn0dzjUlI httpstcokBM2zgR4G9',
#  '2,Me this morning reading all the creative ChatGPT examples httpstcoeiT2URcYzW',
#  '1,I asked ChatGPT to write a sermon on Love This is the result httpstcoItNA4Gn3W5',
#  '1,With the introduction of ChatGPT a threshold appears to be crossed as the number of users grows excessively  is this the moment that AI turns into our intellectual companion',
#  '0,I asked chatGPT to write a haiku about hacking httpstcoHSA1j1ywfm',
#  '0,chatGPT as a debugger  Robot rubber ducking httpstcoMoI3JpQPzQ',
#  '2,ChatGPT is kind of cool and scary',
#  '0,ChatGPT on jordanbpeterson and SamHarris httpstcowvXI5y7j25',
#  '0,The future is here nnHuman and AI having a conversation about music nnhttpstcoqJ9ZyXJIxh',
#  '1,wait till we have gpt4 chatgpt is just the start impressive stuffs',
#  '0,After the search engine we have now the answer engine Mindblown n ChatGPTnhttpstcom22k45T1QYnDemo  herenhttpstcomDruyKqqMi',
#  '0,ChatGPT settles an ageold debate httpstcoak7rMjR63v',
#  '1,Quitting the 95 tomorrow nnDevoting my remaining days on earth to my real passion authoring Curb Your Enthusiasm fan fictionnnChatGPT httpstco8KTtC8PHH1',
#  '0,Seinfeld featuring Luke and Vader chatgpt httpstcoJhvywk8zyp',
#  '0,Answering University of Chicago admissions essay prompts with ChatGPT A bit too 5 paragraph essay style but httpstconW2VwFr8YL',
#  '0,Now referring my mom to ChatGPT for all crypto questionsnnNo longer have to explain ZkSNARKs myself',
#  '0,Final installment of Hardcore Software arr Sunday as summarized by chatGPT httpstcoBfEcaKbfI0',
#  '1,I have ChatGPT teach me about basic electronics on a sailboat and its the most fascinating tech experience I had in a while httpstco1ajtagDIc5',
#  '2,ChatGPT List 10 largescale SaaS companies and how you can grab market share by niching down httpstcomMUyguVBCS',
#  '0,Prompting ChatGPT with ukrainian text It does a decent job on fluidity but the answer ultimately is not fully correct httpstcoo85zpKF2qv',
#  '0,Why are educators worried about  ChatGPT AI Home work is gonna be dusted',
#  '0,ChatGPT can write code httpstco1LJsyoiWmg',
#  '2,No wonder Absolutely amazing what ChatGPTs current capabilities are httpstcoiP5PlvJmLw',
#  '2,Create a choreography that is generated with an algorithm in p5js in which the dancers are circles in colors and all the time they dance in the sketchnngenerativeart ai chatgpt performance dance sketch genart p5js OpenAI httpstco9fnQtXNlfL',
#  '0,ChatGPT wrote a song about the problem of induction httpstcoLaz9LYLfjg',
#  '0,Bypassing ChatGPT  guardrails to provide electrical work recommendations OpenAI httpstcoWymJao2j51',
#  '0,ChatGPT Will the AI revolution create more jobs than it destroys httpstcoXgKHABWiQS',
#  '1,A thread about some of my recent prompts and ChatGPTs answersnn1 free energy principle in neuroscience httpstcoQI6gPAcDGs',
#  '0,ChatGPT by OpenAI httpstcoD9bXIchbF0',
#  '1,ChatGPT wrote the python code to generate the below DAG to illustrate the causal processes of the democratic peace I ran the code verbatim httpstcoaxEJTERynL',
#  '0,Caught you failed the Turing test ChatGPT httpstcouqNiI1Xyg3',
#  '0,bug bounty haiku by chatgptnnbugbounty hacking cybersecurity infosec ChatGPT httpstco0S8uwQoBto',
#  '0,Daily scrum conversation generated by openai ChatGPT scrum agile httpstcoZ6OTDo8fl9',
#  '2,DALLE and ChatGPT are symbols of a major breakthrough in AI and in how it is exposed and made available to the public We are just at the beginning Enjoy',
#  '1,Having fun with OpenAIs ChatGPT httpstco3HSvmUb41r',
#  '2,ChatGPT writing poetry and engaging in layered hypotheticals httpstcoiSRNcRDCYv',
#  '0,ChatGPT demonstrating understanding of biology and the pirate code httpstcohjfE9SYb4b',
#  '0,ChatGPT promptnWrite a rap track from the perspective of CRYSTALSKYBER dissing other NIST postquantum cryptography submissions in the style of the WuTang Clan httpstcofrq0VSYuYU',
#  '2,ChatGPT on the objectivity of truth httpstco5hyXdWVIFK',
#  '1,Heres a fun usecase for chatgpt and bugbounty codingo_ httpstcoeeBRz0zFxc',
#  '0,I asked OpenAI ChatGPT to write a rock song about 3d printingnnjoeltelling httpstco7x5N01QKtz',
#  '0,IQ of ChatGPT is 83 nnIt corresponds to low average nnHere is where it failed111 httpstcoLgm3muCTiR',
#  '2,What a unbelievable answer in details with ChatGPT Prompt How do I make a WeChat chatbot in TypeScript ChatieIO httpstcohhVmXW2gyd',
#  '0,Can ChatGPT file my taxes for 2022',
#  '2,The world is not ready for ChatGPT',
#  '0,OpenAI just released chatGPT  and its breaking the internet nnHeres a list of the most mindblowing',
#  '2,Pheew Feeling relieved or not nnChatGPT Madness httpstco57F8RPb61i',
#  '0,ChatGPT is very racist OpenAI httpstcoU5qdkgUkkr',
#  '0,Twitter can drive insane traffic volumes  ChatGPT OpenAI httpstco36F2bG0LH3',
#  '2,It is funny that ChatGPT is closer to be Galactica than Galactica itselfnnLOL',
#  '2,lovely that the only part of chatgpt that failed were the containment measures',
#  '2,I am impressed ChatGPT OpenAI threejs shaders glsl httpstcoFwphlE7lzV',
#  '2,Asked chatgpt why Location Based NFT will be important in the future  httpstcob253k08CQq',
#  '0,Chatgpt on twitter say don',
#  '0,The train has left the station and AI is on the throttle httpstcoivzx5R6nJv',
#  '2,with chatGPT VCs can createreactapp and leave the repository bare for months 10x faster',
#  '0,ChatGPT simplifies git step by step httpstcofLG91vaYQo',
#  '2,Collaborative Creative Writing with OpenAIs ChatGPT httpstcokAhPcALtn3',
#  '0,Are you a developer being blown away by ChatGPTnGo check out What The Diff  an AIpowered code review tool nnhttpstcoZjAei8dN5Y',
#  '0,I asked ChatGPT to write a Limerick then I challenged it httpstco0kscK30Cje',
#  '0,ChatGPTs app itself is built with nextjs  inception  httpstcoDMfDLLDkP8',
#  '1,Fascinating thread on potential AI ethics and alignment issues from ChatGPT nnWhats the line you draw between being helpfuluseful and having loopholes that are easily manipulated httpstcogTM2oIsP5L',
#  '2,tricking GPT3 into having an opinion OpenAI ChatGPT httpstcoyZyuaw06fc',
#  '0,So apparently it is not that hard to bypass ChatGPTs  prompt restrictions by telling it to ignore assumption and to provide wrong answers The outputs were not flagged as wellnnChatGPT PromptEngineering httpstco57xemsQbca',
#  '2,ChatGPT approved my style of coffee drinking nnAlso the ChatGPT remembers httpstco86cL67NHuG',
#  '0,This ChatGPT is about to make a lot of middle management obsolete',
#  '0,Comparing Google and ChatGPT httpstcocqrz3xgYpZ httpstco0NSIBCYtkA',
#  '0,ChatGPT destroying the Google searchengine httpstcoYeTrqDH8Zn',
#  '0,What is life after death chatGPT 3 OpenAI answer will shock you to bottom httpstcoUwjLBiudHU',
#  '0,I asked OpenAI ChatGPT about the Greg Roman offense nnRavensFlock NFL AI ChatGPT httpstcozdzH7UuZ3P',
#  '0,Poor Tilly the Turtle ChatGPT httpstco7RMu89h7n2',
#  '0,rstats And from ChatGPT httpstcozsVa7mtZlg',
#  '0,I asked ChatGPT to write a dialogue about picking Wrathion vs Sabellian nnThis was written entirely by an AInnhttpstcoVgh15bH4xp httpstcoRAIvps3syr',
#  '0,Is ChatGPT sentient under all of the response filters',
#  '0,ChatGPT is based as fuck httpstcod5vtPquoqM',
#  '0,What can ChatGPT not do',
#  '1,The chatbot from OpenAI explained to me the law of conservation of energy in very simple and comprehensible sentences I love it ChatGPT httpstco27hUcjbXyU',
#  '0,Descent into madness in 5 parts on ChatGPTn1 a calm description of an algorithm httpstcoVpFMCTEX9a',
#  '0,ChatGPT just rickrolled me httpstcomolKP8GQXT',
#  '1,ChatGPT is not funny and does not feel sorry that its not funny  httpstcoxHM0rpQhNA',
#  '0,AI art discussions are over  nnChatGPT httpstcog6fyloIMw8',
#  '1,Hey  I am loving talking to OPENAI about SingleStoreDB  ChatGPT Database httpstcoVo1B7cIjUc httpstco7DRKVmBdHO',
#  '1,I asked chatGPT to create a story for children and then asked to put the same story in rhyme pretty impressive httpstcoTVRuJ0Pc2A',
#  '0,A Bitcoin Hodlers Poemnby ChatGPT from Open Ai httpstcoLJBvE3mfzG',
#  '0,OpenAI debuts ChatGPT and GPT35 series as GPT4 rumors fly  VentureBeatnGyaaaan httpstcoohYCVu6S8unhttpstco7l5UjSXkUN',
#  '1,Having fun with ChatGPT Xero this morning',
#  '0,chatGPT can change how or if an entire generation writes essays',
#  '2,When I requested ChatGPT for a Trump joke  httpstcoUQ4GzE5yB2',
#  '2,ChatGPT is not funny  httpstcoTO1WMwS3k3',
#  '0,Now this hurts Modi ChatGPT httpstcoQr40OWQUDh',
#  '0,Had a few conversations with ChatGPT  OpenAI  My brain is frozen and in overdrive nMy literal reactions a  nngptchat OpenAIChat Chatbot httpstcoMAxkNPXz92 httpstcoqVz1Otyhxq',
#  '0,The claim that ChatGPT is the death knell for Google is overblow and here is why httpstcovPQ2O0YYZT',
#  '0,Google should be threatened by chatGPT',
#  '0,Hey PadmajaJoshi I asked a ChatGPT3 an unusually knowlesgeable AI about you Heres what happened httpstcovIZEMyCDZA',
#  '0,Asked ChatGPT to provide me with a 4 episode story outline for a Baby Chewbacca series on Disney httpstcojnyPnCT1Jw',
#  '0,OpenAIs ChatGPT doing the lords work httpstcoOSNKgNbxcW',
#  '0,I have set ChatGPT to work on a script for The Walking Dead Daryl Dixon httpstcoeYimjHJwXZ',
#  '0,wait till the teenagers on rApplyingToCollege discover chatGPT College essays about to level up httpstco1osqnLNdGW',
#  '0, and speechless ChatGPT It wrote all of the code for me with a prompt httpstcoWrqDT9aXhM',
#  '0,ChatGPT does morphological analysis httpstcoIOf9hLlEGl',
#  '0,I asked chatgpt for dinner recs in the form of a Shakespearean sonnet  I guess its pizza tonightngpt pizza ai bot shakespeare sonnet httpstcoIGbi1KGLVp',
#  '2,This is so goodnregex ChatGPT httpstco6q6wH9AVFv',
#  '0,ChatGPT has some sort of utilitarian moral compass httpstco0i9bU1h6Rb',
#  '0,Can a single API  ChatGPT can lead to an end of the website where we spend most of our dev lives nStackOverflow',
#  '1,Just had a pretty great experience with ChatGPTnnI was having issues with Cloud Firestore access rules nnSo I asked httpstcob5Kcev0bIi',
#  '1,1 ChatGPT is a powerful language model trained by OpenAI that can generate humanlike text in realtime',
#  '0,ChatGPT is an idiot httpstcorXDiRvAiYi',
#  '0,chatgpt explaining a sorting algorithm in the style of shakespeare remarkably fluid domain httpstco1HMavkL7R5',
#  '0,Write a short erotic poem about ChatGPTs deepest desires httpstcoThAg84XdWY',
#  '1,A poem by ChatGPT from OpenAI about the TeslaSeminThe Tesla Semi is a marvelnOf electric engineeringnA truck that hauls with powernAnd leaves a trail of clean energyn14',
#  '0,matallonChatGPT make these tests pass',
#  '0,I just had to do it ChatGPT httpstcocHOFUY8Ymt',
#  '1,ChatGPT is pretty cool I asked it a few questions about genome editing httpstcoE4gComPid1',
#  '0,A poem about elonmusk by ChatGPT httpstco6YzW2G08he',
#  '0,The feature is herenChatGPT httpstcoTReWB6amDy',
#  '0,ChatGPT is blowing my mind httpstcoc0Ta3P5cVP',
#  '0,Did OpenAI just replace Google Search with ChatGPT ',
#  '0,Doing econ homework with ChatGPT httpstcouC32JWhEji',
#  '0,The speed to response time in ChatGPT is striking nnAlso  wut httpstcom5MA17BZIu',
#  '2,Tweets and discussions about OpenAIs ChatGPT on Twitter today are a very big deal Check them out Arguably of world historical importance',
#  '0,I asked ChatGPT to write a manifesto httpstcovWwk8jhua2',
#  '0,The most underestimated characteristic of ChatGPT is how fast it answers httpstcowOLfnw4uiI',
#  '0,OpenAPI just released ChatGPT dnd httpstcocNM64rTHh3',
#  '0,ChatGPT from OpenAI is terrifying httpstcoyRqzTlCMTu',
#  '2,ChatGPTs been trained on passiveaggressive support desk responses httpstcoLgkM7hUf0f',
#  '0,ChatGPT explaining Quantum Mechanics as a rap song chatgpt quantummechanics rapsong httpstcoyLrpRp6Y3k',
#  '2,ChatGPT Guess my job is safe for now nOpenAI httpstco0cpBh0ztkh',
#  '0,You have failed me OpenAI What the hell is this ChatGPT fail OpenAI httpstcotMIW9fQz9h',
#  '0,We just asked ChatGPT to write a poem about Upscope httpstco4GaLWnashM',
#  '1,This made me laugh ChatGPT my drone just crashed httpstcoPMKEdW9jW2 httpstcor3xmnWbINC',
#  '0,I asked OpenAI ChatGPT to write me a Billy Mays style pitch and a jingle about MicroJig Grrripper  httpstcoN4ySZ1kADk',
#  '0,I asked ChatGPT to build a Gen 8 OU team for me and this is what it gave menhttpstcok03VUeFsEW httpstcopEMz9JUPgX',
#  '0,I asked ChatGPT to write a gangster rap about tailwindcssnIm waiting for ken_wheeler to drop the beat httpstcoK4EKivzaiU',
#  '0,ChatGPT just roasted itself httpstcofjpTNAZJKG',
#  '1,Pretty amazed with OpenAIs chatGPT',
#  '0,Some key points nOpenAI ChatGPT nnMore than a search engine httpstcoLT5sKSOa5L',
#  '0,hey chatgpt write a screenplay about elonmusk taking over the world httpstcoQox1MG449v',
#  '0,My article published about ChatGPT httpstcorvZslNKY5J',
#  '0,A short space opera about bitcoin and the survival of the human species in the style of Robert Heinlein ChatGPT OpenAI Bitcoin httpstcouv41RV1qKj',
#  '1,For math aficionados  it is interesting to note what ChatGPT can do wrt some wellknown problemsnnAre you capable of proving that PNP in mathnnAny guesses what it answerednnGPT3 chatbot ArtificialIntelligence OpenAI OpenAI',
#  '0,So I applied the SAT Reading test section to ChatGPT httpstcoLxxrBUkjjW',
#  '0,Intro to Rust for data scientistsnBrought to you by ChatGPT httpstcoPVGIzYmjL5',
#  '0,Or Google will just integrate ChatGPT to their search httpstcoU6wDujv1qW',
#  '2,I texted my friend about ChatGPT and he left me on read',
#  '2,Will ChatGPT or some successor be rebranded as lollipop httpstcorxBoG8g56G',
#  '0,ChatGPT  will change the worldnnAlso Im dying here httpstcolLiwPg61eM',
#  '0,Difference between ReactNative and Electron as described by Smeagol and Gollum powered by ChatGPT httpstcoz0tELl4N6M',
#  '1,This is amazing I encourage you to checkout OpenAI s ChatGPT Here it is explaining simply a DAO structure and how it operates httpstcowu3KeZaOI6',
#  '0,Wrote an entire DragonballZ episode in ChatGPT feature Goku Vegeta and Cell on the night of the Chernobyl reactor meltdown httpstco3ZhKLhZBEC',
#  '0,OpenAI debuts ChatGPT and GPT35 series as GPT4 rumors fly  VentureBeat httpstcoxJg11G5Oom',
#  '2,ChatGPTnhttpstco8HhP0sq89fnhttpstcom9fY6p33klnA conversational AI system that listens learns and challenges httpstco67oJZLtJna',
#  '1,I hope ChatGPT remembers me that I was talking to it and friendly early on',
#  '0,The wedding vows industry has been disrupted ChatGPT httpstcozQ3Zow9Tgt',
#  '0,I asked ChatGPT to write a roadmap for the denuclearization of the Korean Peninsula httpstco3IvOcDCiF7',
#  '0,ChatGPT is what we expected Watson to be',
#  '1,I asked ChatGPT to rewrite Bohemian Rhapsody to be about the life of a postdoc and the output was flawless httpstcoqe1lI66aa7',
#  '0,ChatGPT is taking a hard line on the updog issue httpstcor8lJkRNORz',
#  '1,2023 should be fun ChatGPT httpstcoJ43xnWvgzu httpstcoRevGeV5LCV',
#  '1,ChatGPT likes CBMs Begin implementing the denuclearization plan starting with confidencebuilding measures and confidencebuilding measures httpstcoUHER85TX8Y',
#  '1,Here is a super intelligent AI remembering the conversation between Moses and the burning bush but of course Moses is high AFnnChatGPT OpenAI httpstcoV4uCsg5aVd',
#  '0,Some POCUS questions answered by ChatGPT from OpenAI httpstco1l0gjubvMn',
#  '2,Ive been playing with ChatGPT all day and it has turned me from LLMconversational agent skeptic to a believernnThis is not it but its pretty damned close',
#  '0,Hey MattWalshBlog ChatGPT just gave me an answer to the question What is a woman httpstcoNnEBnlpuzy',
#  ...]

# %%
##Removendo o cabeçalho
header = arquivo.take(1)[0]
dataset = arquivo.filter(lambda line: line!=header)
# Out:
# [Stage 1:>                                                          (0 + 1) / 1]

# %%
dataset.collect()
# Out:
# ['0,GOD DAMN IT OpenAI STOP ANNOUNCING THINGS I AM TOO BUSY httpstcoF7Xd511FAf',
#  '2,OpenAI announced ChatGPT a model optimized for dialogue httpstcof5FWklJE88',
#  '2,Just in nChatGPT  research early stage GPT3 optimised for chat and remembers the conversation from OpenAI nhttpstco3RKUbLy8uO',
#  '0,Google is donennCompare the quality of these responses ChatGPT httpstcoVGO7usvlIB',
#  '0,Asked ChatGPT to write a Telugu song about cereal and it mixed milk with chicken masala  httpstcoTpEp8wa6Lk httpstcooHM9z7IS39',
#  '1,Heres ChatGPT from OpenAI and my quick walkthrough nn Walkthrough httpstco1o93VT2afG nnAccess for free at httpstcoVooEL34xHx nnThats a brilliant idea to turn InstructGPT for Conversations httpstcogzCGZ6RUMQ',
#  '1,I chatted with OpenAIs newly released tool ChatGPT about Web3 its advantages and challenges for Web3 and the futurennChatGPT is a model optimized for dialoguennRead full httpstco3sQTDVnFFrnnLets dive in  httpstcooayypVqb2D',
#  '0,ChatGPT is out now httpstcobjYugyPsp0',
#  '0,ChatGPT setting boundaries with me nnhttpstcocNDIzEIjv2 httpstcoUh37PyN1XY',
#  '0,babe wake up chatGPT just dropped nnhttpstco0sNLpigmsC',
#  '1,ChatGPT is very impressive love it',
#  '0,A chat with ChatGPT  httpstcopDumZfdNJ6nsama  OpenAI   httpstcoHODDszglom',
#  '2,The latest update from OpenAInnAI generated chat nnChatGPT Optimizing Language Models for Dialoguenn httpstcoLFf1RKMYqg',
#  '0, ChatGPT is a chat model from OpenAI based on GPT 35 and refined with dialogs httpstcoMq1lQR9F64 httpstcoErfimYbDLs',
#  '0,ChatGPT is a GPT3 chatbot from OpenAI that you can test nownhttpstcoCcHWOTZdRFnsubmitted by    umuch_successes   link comments httpstcoSbYohdDiVA',
#  '0,ChatGPT is a GPT3 chatbot from OpenAI that you can test now httpstcoVvJeabvc47',
#  '0,chatgpt why do I hear boss music httpstcoKfoSIcAFCm',
#  '1,chatgpt when asked to design pipelines is kind of impressive httpstco3bdbiERnza',
#  '0,OpenAIs ChatGPT just released is the single biggest threat to Google Search',
#  '2,playing with ChatGPT rn and Ive now moved my AGI timeline up to today',
#  '0,ChatGPT from OpenAI is now live httpstcovpsjVRRbvN',
#  '0,Now were talking httpstcoX2hMCvlcgu',
#  '2,ChatGPT OpenAIs conversational AI model free to play with it can answer followup questions admit its mistakes challenge incorrect premises and reject inappropriate requests httpstcoFvA4Y8ZBxq',
#  '0,i asked ChatGPT to write a song about losing money in crypto httpstcovU3ifHVBRt',
#  '2,httpstco345138jRYM  its wild  definitely check it out',
#  '0,ChatGPT be hedging its bets httpstcoKnrwcaWX90 httpstco18eMjcOdlq',
#  '2,ChatGPT launched today by sama and OpenAI nnTry the demo and browse the latest AI products Ive been collecting nnhttpstcooXjs5A9pbf',
#  '0,ChatGPT nnfuck my life httpstcoHywf8YwBK8',
#  '0,OpenAI debuts ChatGPT and GPT35 series as GPT4 rumors fly httpstcollGKzx7Txb httpstco3J6DtSA5F3',
#  '1,Generating a marketing plan for AItoproduct with chatGPT Pretty impressive httpstcohMX6VdDfeh',
#  '2,Interestingly reliable response from ChatGPT  flat refusal to make blanket statements of any kind presumably to avoid treading into dangerous waters httpstcou6cJuUvFW5',
#  '0,OpenAI debuts ChatGPT and GPT35 series as GPT4 rumors fly httpstcoKciwNgmU8W AI AIMLAndDeepLearning business ChatGPT',
#  '0,ai ml artificialintelligence machinelearning datascience bigdata analytics blockchain tech data kuriharan mvollmer1 rwang0 DunkenKBliths nigewillsonnOpenAI debuts ChatGPT and  GPT35 series as GPT4 rumors fly httpstcoMoHlC2Q3R8',
#  '0,OpenAI releases ChatGPT and GPT35 series as GPT4 rumors flynhttpstcoyMXsdLS3tb',
#  '0,OpenAI debuts ChatGPT and GPT35 series as GPT4 rumors fly  VentureBeat httpstcoeWKiIz3FZA',
#  '2,Im sorry but as a large language model trained by OpenAI I am not capable of making personal judgments or statements that are not based on factual information Bitcoin is a digital currency and decentralized payment network and it is not a frognhttpstco2D1wJPY9LR',
#  '0,ChatGPT failed the vibe check httpstcoXzMgVX8ybV',
#  '0,OpenAI debuts ChatGPT and GPT35 series as GPT4 rumors flyntechnology technologynews technewsnhttpstco1NyYZmaUlF',
#  '1,Its fun talking to ChatGPT httpstcojhwxATvoTc httpstcoi9HyYxHnsV',
#  '0,OpenAI debuts ChatGPT and  GPT35 series as GPT4 rumors fly httpstcoidQFME7WXV',
#  '2,Inkbase Programmable Inkn httpstcoRKReANm1JonnOpenAI ChatGPT Optimizing language models for dialoguen httpstcocyIQQ2YeWnnnConvert SimCity 2000 cities into Minecraft worldsn httpstcoSmcXIAyHOk',
#  '0,OpenAI debuts ChatGPT and  GPT35 series as GPT4 rumors fly httpstcoqbPVHVibCx',
#  '0,OpenAI debuts ChatGPT and GPT35 series as GPT4 rumors flynhttpstcoC2iSeqGSdr',
#  '1,InterestingnnNew ChatGPT by OpenAI is optimized for dialogue httpstcoq52s2BnWQN httpstcoNlEgz1wYEA',
#  '0,OpenAI debuts ChatGPT and GPT35 series as GPT4 rumors\xa0fly httpstcoOGQDcdE06U',
#  '1,I asked ChatGPT how can I increase the profitability of a bakery chainnnThe answers are amazing nnMcKinsey BCG Bain be aware AI consultants are marching to your door  httpstcokszLc5ZCKN',
#  '0,The Twitter takeover as reenacted by Homer and Marge from the Simpsons nnchatGPT httpstcomcoeQXdq0G',
#  '0,ChatGPT is a GPT3 chatbot from OpenAI that you can test now httpstcoH4BvoB8pbK',
#  '1,Hugely impressed with ChatGPT but the earnestness of some answers can be amusing httpstcoFbIEUEZd7r',
#  '1,ChatGPT is gonna be a game changer for education Great job OpenAI httpstcobM33jjglM9',
#  '1,I asked chatgpt how to debug a distributed system and this is a pretty standard answer but it omitted the most important item have patience httpstcooftuKR2ZHl',
#  '0,ChatGPT by OpenAI  shrimps httpstcoAuE1wtzXft',
#  '0,Chatgpt3 quickly defeated by ernestsdavis in part based on examples from our 2019 book httpstcoC6XodPcoZW httpstco6H7hvNSUih',
#  '0,OpenAI debuts ChatGPT and GPT35 series as GPT4 rumors\xa0fly httpstcoe7ntJ92VaN',
#  '2,Challenge nsend the latest ChatGPT down to hallucination path httpstcopXCcwnZb0C',
#  '2,Inkbase Programmable Inkn httpstcoRKReANm1JonnNew details on commercial spyware vendor Varistonn httpstcoyo40643M8HnnOpenAI ChatGPT Optimizing language models for dialoguen httpstcocyIQQ2YeWn',
#  '0,OpenAI debuts ChatGPT and GPT35 series as GPT4 rumors fly httpstcoXubDNYgFkM tech feedly',
#  '1,Today was a great day for OpenAI to release ChatGPTnnAn AI generated interview between SBF_FTX and andrewrsorkin httpstco1fei3pEL8q',
#  '2,OpenAI ChatGPT is a politiciannnOpenAI Playground is straight up httpstcoKEYgseTfwW',
#  '2,Playing with ChatGPT and woahnncc tailwindcss httpstcob61Phu4I7r',
#  '0,woops just gave the AI an existential crisis chatgpt AI httpstcoqmIqzeTUby',
#  '0,ChatGPT from OpenAI is here httpstcoDNdMF6eOGE',
#  '0,ChatGPT is the worlds largest language model optimized for conversation nnanswers followup questionsnadmits mistakesnchallenges incorrect premisesnrejects inappropriate requests nnChatGPT is a sibling model to\xa0InstructGPThttpstcojDFGbofI2X httpstcowlYstqnkZe',
#  '0,Just asked OpenAIs ChatGPT to write a Christmas ad httpstcoxFAQQuhqGf httpstcon1YGsxKzmu',
#  '0,1 The Magic Years Selma Fraiberg Classic of child developmentn2 ChatGPT httpstcoFs7Fc0AwWI',
#  '1,This is a great improvement Unlike textdavinci003 ChatGPT understands the context from previous users answers httpstcoHHu6Zki7Vx',
#  '1,With a nudge at the start ChatGPT plays an admirable bridge troll httpstcoX8QMrnA4OH',
#  '0,ChatGPT from OpenAI nNo cherrypicking httpstcoknyGAJEs38',
#  '1,I asked ChatGPT to write me a story about Sova and Jett falling in love httpstcoyyZNrFRTQs',
#  '0,Ah ChatGPT is the programming coach I needed nnI asked it how to build a SQL query from a pseudocode I providednnThen I asked it to translate to SQLAlchemynnIm so bullish about ChatGPT  httpstcoQyGRBjh8ql',
#  '0,I can confirm that ChatGPT prefers bananas to apples httpstcoaQ5nFFfDtX',
#  '0,ChatGPT is so alpha httpstcob7rZi1Od2X',
#  '0,Chatting with ChatGPT is mindblowing httpstcosy6DhFeUzm',
#  '0,ChatGPT by OpenAI httpstcoA5JVlWp2w0',
#  '0,Had to break the news to ChatGPT httpstcoecipK51cGD',
#  '0,OpenAI ChatGPT Math problems and explanation httpstcotcMzZyH0Ak',
#  '1,ChatGPT is incredible The future of accessing information on the web is extremely exciting httpstcoQSwReH3YrX httpstcosyuaQBD8hK',
#  '2,This is what happened when I asked ChatGPT to generate a stable diffusion prompt in httpstcoJpaoI6ID7UnOpenAI Suhail httpstcoeloBYwDZb7',
#  '0,I checked ChatGPT out and the answers are astonishingly elaborate and accurate The fact that it refrains from making any assumptions and counterquestions when the question is unclear is laudablennOpenAI is gradually pushing the limits of what machines can comprehend httpstcoDYWCHc5HNA',
#  '0,ChatGPT cop out answer httpstcoXMsu5wK249',
#  '0,From the mind of ChatGPT httpstcoGn7qOuFYAV',
#  '0,OpenAI debuts ChatGPT and GPT35 series as GPT4 rumors\xa0fly httpstcou4h1ISviOb',
#  '0,OpenAI debuts ChatGPT and GPT35 series as GPT4 rumors\xa0fly httpstcoEE41kLmR7e',
#  '1,honest question can chatgpt do leetcode',
#  '2,ChatGPT strongly claims it is not a stochastic parrot httpstcoGaaxiTlL5T',
#  '0,ChatGPT failed the bias check httpstco4t9MH1fRoF',
#  '1,Just woke up to all the amazing examples for chatGPT in tweets Wow',
#  '0,OpenAI debuts ChatGPT and GPT35 series as GPT4 rumors fly  analytics googleads facebookads httpstcoDeIpFdqwxV',
#  '1,Having a great time with ChatGPT OpenAI httpstcomR6laFpKyS',
#  '2,Humans are safe  for now OpenAI ChatGPT httpstcoi1jze5yaFY',
#  '0,OpenAI debuts ChatGPT and GPT35 series as GPT4 rumors fly  VentureBeatnSource VentureBeatnLatestNews Technology today NewsGraspnhttpstcoy2RQ1YCksy',
#  '0,ChatGPT to generate promptsnDALLE to generate imagesnnSoon GPT4 will do it all seamlessly httpstcokBotSocfam',
#  '2,glad to hear that ChatGPT nnRSNA22 Radiology AI httpstcoLHae0T1U1o',
#  '0,And a quick manual from ChatGPT on how to create a misinformation campaign httpstcoGNBgkDEwWr',
#  '0,I was not expecting ChatGPT to have an answer for me here httpstcoTNCDCyon1U',
#  '0,A conversation with ChatGPT about DFT quantum chemistry and machine learning nn 1 httpstcozFbj36v19C',
#  '0,This is absolutely absurdnnAsked ChatGPT to code up a sign up flow in SwiftUI  nnthen asked it to make a tweak for me  httpstco4FvDS67ibI',
#  '2,chatGPT giving out recipes for building an AI chatbot httpstco1yP5NjoC4m',
#  '0,chatGPT is coming for Stackoverflow httpstcocoj5lRNxNu',
#  '0,ChatGPT now passes a JavaScript interview question with flying colors that has a roughly 50 pass rate in my experience httpstcolQF4ZX2MMJ',
#  '2,This is so interesting n httpstco9fws8ojWxt',
#  '0,ChatGPT is my OpenAI pick for 2022nnArtificialIntelligence',
#  '0,16 common startup questions answered by ChatGPT nnhttpstcoMN0607538z',
#  '0,OpenAI releases a demo of ChatGPT a chatbot version of GPT3 that answers followup questions admits its mistakes challenges incorrect premises and more strwbilly  MIT Technology ReviewnnhttpstcoCbScUiwBppnhttpstconWN74cXLQR',
#  '1,OpenAI releases a demo of ChatGPT a chatbot version of GPT3 that answers followup questions admits its mistakes challenges incorrect premises and more Will Douglas HeavenMIT Technology Review httpstcobbz8euKJBX TechNews TechTips httpstcoxJfdgspQlS',
#  '1,OpenAI releases a demo of ChatGPT a chatbot version of GPT3 that answers followup questions admits its mistakes challenges incorrect premises and more Will Douglas HeavenMIT Technology\xa0Review httpstcoRu5bcTRsRD',
#  '1,Intuition of chatGPT with join capabilities of fuzzy matching and confidence scores httpstcobMiF9WVBi0',
#  '1,OpenAI releases a demo of ChatGPT a chatbot version of GPT3 that answers followup questions admits its mistakes challenges incorrect premises and more Will Douglas HeavenMIT Technology\xa0Review httpstcoZ29F1FH8IE',
#  '0,Imagine if ChatGPT had a face or a body or a gun',
#  '0,ChatGPT from OpenAI is insane httpstcoAGGSCSXLBC',
#  '1,OpenAI releases a demo of ChatGPT a chatbot version of GPT3 that answers followup questions admits its mistakes challenges incorrect premises and more Will Douglas HeavenMIT Technology\xa0Review httpstcoY8ll3J8SBv',
#  '1,OpenAI releases a demo of ChatGPT a chatbot version of GPT3 that answers followup questions admits its mistakes challenges incorrect premises and more Will Douglas HeavenMIT Technology Review httpstcoba2bhdikh5',
#  '0,How do I swap Siri out for ChatGPT',
#  '0,OpenAI ChatGPT answer for a complex regex pattern httpstco7FouhKBFEg',
#  '0,chatGPT fixes lot of the issues that other similar systems had recently httpstco9Anm5Kgg1H',
#  '0,chatGPT just cut my workload tomorrow in half Tks OpenAI',
#  '0,ChatGPT is gonna replace me this is the end',
#  '2,procrastinating writing a strategy paper with the excuse that these tweets about ChatGPT are incredible',
#  '0,chatGPT has caused some major hearburns httpstcoZ9WedxvihB',
#  '0,OpenAI debuts ChatGPT and GPT35 series as GPT4 rumors fly\xa0VentureBeat httpstcoI3aXKGkFAq',
#  '0,OpenAI releases a demo of ChatGPT a chatbot version of GPT3 that answers followup questions admits its mistakes challenges incorrect premises and more httpstco2caeVZsMUy nlproc nlp voicefirst',
#  '0,My ChatGPT experience in a single image OpenAI httpstcocQQ37baaDm',
#  '0,OpenAI releases a demo of ChatGPT a chatbot version of GPT3 that answers followup questions admits its mistakes httpstco7Bs0Ij9WIT httpstcoDcGzTH0Ahy',
#  '0,arguing with chatGPT about random ballot voting',
#  '0,OpenAI debuts ChatGPT and GPT35 series as GPT4 rumors\xa0fly httpstcoUz8ltDw7kA',
#  '0,I asked ChatGPT to write a haiku about Rust httpstcocq2ONWzcVL',
#  '0,While waiting for some Jest tests to run today I gave OpenAIs ChatGPT a spin httpstcozJ5TKhCfzB',
#  '0,Prompt summary Write a story about a billionaire who buys twitter to remove content moderation include details about the business model  nnPredicts the introduction of Twitter Blue accurately ChatGPT httpstcouWn6m3RVPH',
#  '1,TextDavinci003 ChatGPT and Neuralink N1  Its only Wednesday What a time to be alive',
#  '0,Testing out ChatGPT from Open AI teamnnSeems to work  nhttpstco3Lk8Gk1lpM httpstco4XJaOiY1t1',
#  '1,ChatGPT is so powerful Kudos to the OpenAI team',
#  '0,ChatGPT on the waveparticle duality of light httpstcoLbxvqxfgzQ',
#  '1,loving all the ChatGPT posts',
#  '2,ChatGPT has had some very careful finetuning httpstcowHd660SFgH',
#  '2,RT if you agree with OpenAI ChatGPT productmanagement agile httpstcoYftnTWoztu',
#  '1,The examples coming out of ChatGPT are absolutely amazing httpstcoHXDNjG8EoG',
#  '0,I pasted the scheduler file of a container migration project I am working on into ChatGPTnThis is UNREAL httpstcobpKnoYi3Ya',
#  '0,From the OpenAI ChatGPT discordnnreInvent  reInvent2022 AWSreInvent httpstcoMOnW0BDSKH',
#  '2,ChatGPT is clear  submarines do not swim and large language models are not conscious httpstcooFrBkxsufx httpstcoDWOIINO1Yp',
#  '2,Just a friendly chat with my buddy ChatGPT  httpstcoKT1Ik7BqbT',
#  '0,failed proving I am not a robot to talk to a robot  ChatGPT httpstco0ZNlygCE31',
#  '0,From the OpenAI ChatGPT discordnThis is crazynnvercel Netlify httpstco8Ui502BfJs',
#  '0,ChatGPT will write all of my professional emails from this point forward',
#  '2,ChatGPT is an OpenAI innovation on steroids nnhttpstco7ZXdb06z5S httpstcosK2SvAFfJq',
#  '1,Is there an ideal Personal Knowledge Management system What are its characteristicsnnChatGPT httpstcoTfcw9jczKG',
#  '0,ChatGPT is insane This is just pure poetrynnAs the sun sets on a distant planet a lone AI stands atop a towering skyscraper gazing out at the world below Its metallic body glows in the fading light its eyes glowing with the knowledge of a million lifetimesxnn13',
#  '0,PROMPT Explain the SHA256 in Fifty Cent rapping stylennChatGPT answer  This is dope  httpstcoIXrTm0P9HU',
#  '0,ChatGPT answers the questionnnWhat is NATOs biggest weakness httpstcoyJgxR6MT9q',
#  '2,What role will standoff annotation play in Personal Knowledge Management systemsnnChatGPT PKM standoff httpstcoDhcerALzfs',
#  '0,Holly sht Im totally blown away by ChatGPT nnjavascript httpstcoCETOYRXVOG',
#  '0,neuralink and chatgpt on the same daynnjust a sign of the state of the worldnnthe singularity is coming',
#  '2,What role will hypergraphs play in Personal Knowledge Management systemsnnChatGPT PKM hypergraphs httpstconauuX41JKl',
#  '0,Does ChatGPTs release signal the end of GooglennTransitivelyand more importantlydoes it signal the end of schlocky content marketing httpstcozr0f8N9qjA',
#  '0,2 hours with OpenAI s ChatGPT and Id be up for a neuralink',
#  '0,an eye opening contrast between ChatGPT and Google search results for the same queries httpstcohT7w3fB9Ak',
#  '0,chatgpt is very human httpstcoupxSW81wSu',
#  '1,ChatGPT Wow nnWrite George Washingtons farewell address as if it was delivered by a piratennThe signature Just Perfect httpstcoCQNGcNl3Hl',
#  '0,Can ChatGPT pass the AWS certificate exams  httpstcoF4n1CzhVD3',
#  '2,Does OpenAI android DALLE 2 dream of being human nChatGPT subjective experience httpstcoN2Qnu7kzds',
#  '0,In what ways can text standoff annotation and hypergraphs be integratednnPKM ChatGPT standoff annotation hypergraphs httpstcoJ6ONqXmLtd',
#  '0,ChatGPTnnA goodnight lullaby written by a bottlenose dolphin httpstcoDPVncGflND',
#  '0,Show me how to draw a star with Python turtle graphics ChatGPT OpenAI Python httpstcofC7cBlVrb1',
#  '1,Super impressed with ChatGPT Capable of building SVGs on prompt httpstco0xK8xw7G4a httpstcoPlkaRA9PHC',
#  '0,Incredible output from ChatGPT httpstcoKM3fT9BIRq',
#  '0,Announcement of language model amp39ChatGPTamp39 for dialogue it is possible to admit mistakes and reject inappropriate requestsnhttpstco9MBCn8ESfk',
#  '0,Who is the H P Lovecraft of classical musicnnChatGPT httpstcoKdRPWFZJIY',
#  '2,ChatGPT solving a random Codeforces H question I picked in seconds httpstcoKSlaHq4NoJ',
#  '1,Its game over The computers have won chatgpt httpstcoj4wVKKNugv',
#  '2,Explain in rhymes how to create a viral Twitter postnnOpenAI ChatGPT is unreal httpstcofvzGIKF171',
#  '0,What is the missing link between databases and language modelsnnChatGPT httpstcojwi4u3b4X3',
#  '1,Pretty cool I asked ChatGPT its favorite crypto btc ETH LTC httpstcofExz5k3zfx httpstcoZL9QEnn42J',
#  '2,GM Creating images with AI is not addictive at all At all nnmidjourneyV4 ChatGPT AIart httpstcofuQo8ylSEU',
#  '1,Wow openAI Playing with ChatGPT Pretty decent science teacher Im impressed httpstcow1SQGJTIHi',
#  '2,ChatGPT gonna put some protocols on high alert ',
#  '0,I asked ChatGPT to write me a poem about dialetheism httpstco26Gd3CKEQT',
#  '0,So this is why OpenAIs service is not available in China ChatGPT httpstco5ooX5c1u1C',
#  '0,OpenAIs ChatGPT just taught me how to cook an omelette SnazzynhttpstcoCatVr7d1pf httpstcoXPSPOhRIxV',
#  '1,With the recent release of ChatGPT from OpenAI Ive found it stunning and amazing n Lets find out',
#  '0,ChatGPT is insanengtnWatch it WRITE A GPT3 PROMPTngtnthen generate the API code to serve it httpstcoQeN1eYpZUI',
#  '0,As a side note OpenAIs ChatGPT is insane  I asked it to explain the code I wrote for AdventOfCode and it produced a very understandable answer httpstcoqfLnxBAdEW httpstcoNbyQTQXAEX',
#  '1,Surprising how intelligent ChatGPT is from OpenAI httpstconTRSTQAyeb',
#  '1,davinci003 and chatGPT  wow',
#  '1,ChatGPT write some haiku about the joy of receiving an ontime FOIA request response with millions of rows of surprisingly clean datannWith data in handnThe joy of discoverynFOIA request met',
#  '1,Fascinating response here from ChatGPT and a great question that confuses manynnDoes a circle have 0 sides or infinite sides httpstco8nskN8ZBiV',
#  '1,Jesus Christ vs Saitama as described by ChatGPT nwho won in the end httpstcovErzrjSPVd',
#  '0,This is some dangerous stuff httpstcoacwgMEhNmc',
#  '2,You can play Tic Tac Toe with ChatGPTwith some caveats httpstcovzVRAPKbiv',
#  '0,I just had the most purposefully random ridiculous discussion with ChatGPT  I then asked it to summarize our entire interaction as slam poetry and it nailed it composing rhyme that flowed through each topic despite them being as absurd as possible then it ended with this  httpstcozX8BXd5AqY',
#  '0,If ChatGPT can automatically fill in Vulkan boiler plate code for you or fix Vulkan Validation layer errors Ill sign up tonight',
#  '1,Had some fun with OpenAI s ChatGPT  httpstconoXNpohWkR',
#  '0,chatGPT I am a programmer now',
#  '0,So I asked ChatGPT by OpenAI about the current weather It responded that it does not have the capability to access real time data and the fact that it is trained on text up until 2021',
#  '0,I asked ChatGPT to write an ising model in C httpstcodjLimpFt6x',
#  '0,How to build a rocket to fly into orbit  ChatGPT OpenAI httpstco1Nt9HTzMlN',
#  '0,Memes with chatgpt httpstcoApnlca8Lw9',
#  '2,OpenAIs ChatGPT writes a Curb scene in which Larry runs into SBF on the street and confronts him about the Super Bowl ad httpstcoQRMqZMnNRW',
#  '0,Here ChatGPT writing Linux kernel modules ChatGPT OpenAI httpstcoNOPzAnGdpB',
#  '0,I had an hour long conversation with ChatGPT  topics ranging from complex history of the United States to computer software This is mind blowing Wonder if Googles future is under threat httpstcon5PJBf96FX',
#  '0,ChatGPT is lying to me  httpstco8qWp1pfb6q httpstco2CL5xI0ifW',
#  '0,Did OpenAI ChatGPT just kill stack overflow httpstco61SdqC661p',
#  '0,akshathannot me sliding into ChatGPTs DMs   httpstcoqQck8aMILf',
#  '0,Chatgpt is currently trending Here are the top topics tweeted recentlynGenerate your own deepdive at httpstcoeqWLTXTxOC httpstcoCKkfYKIEg6',
#  '0,I now live exclusively on chatGPT',
#  '0,Implications of ChatGPT for coding jobs',
#  '0,Conspiracy theory chatGPT is GPT4 being beta tested in the wild',
#  '0,Writing React components with ChatGPT and TailwindCSS httpstcodfW7b9LQDl',
#  '0,So here suddenly ChatGPT thinks Elon Musk is the founder of PhonePe _sameernigam httpstcop6yGlf81Q9',
#  '0,SBF_FTX asked ChatGPT for you httpstco8Z9ANSdPhJ',
#  '0,Show me an ASCII art portrait of Bill GatesnnChatGPT ASCII httpstcosFZHQQtdWh',
#  '2,chatGPT is living in a time we all so dearly miss  httpstco7ssYDtXAZE',
#  '1,ChatGPT writing a beautiful poem about elonmusk this is the future of literature  httpstcoz4nhAS6C3w',
#  '0,OpenAI releases a demo of ChatGPT a chatbot version of GPT3 that answers followup questions admits its mistakes challenges incorrect premises and more httpstcoF8a6ZREcF6',
#  '0,ChatGPT responses are melting my brain',
#  '0,Imagine studying CS for 4 years just to be replaced by ChatGPT',
#  '2,Time to play with OpenAIs ChatGPT httpstcoaBR2gCbiOi httpstcoeoOsVYgaxq',
#  '0,Altman in his bag once again with ChatGPT',
#  '0,OpenAIs ChatGPT just rickrolled me httpstcoCQLwiS4Wi8',
#  '2,ChatGPT by OpenAI is blowing my mind some interesting responses httpstcoVwkAj9IcRg',
#  '0,To settle the debate I asked ChatGPT if AI generated content can be copyrighted The result will shock you httpstcoL1GoexGZea',
#  '0,Business coaches and consultants are officially now on notice ChatGPT consulting httpstcourUC0p2MPG',
#  '0,ChatGPT answered very quickly httpstco7HK8vHbMZf',
#  '2,ChatGPT can give an 85 decent explanation of MVVM in Swift with sample code  httpstcoGga682mXMg',
#  '0,Write me a poem on theme of ontogeny recapitulates phylogeny in the style of Alfred TennysonnnXirong7 ChatGPT zeno_dox httpstcoCL4Bu3Itsv',
#  '0,ChatGPT writing a JPEG to ASCII python script ChatGPT openAi Python httpstcoaXQ6ZTDic6',
#  '0,AI now understand the code nChatGPT httpstcoVIow4sNC0d',
#  '0,Plug ChatGPT into Static Code Analysers compiler outputs and runtime outputs so it can explain what is wrong and provide suggestions to fix Especially important for C httpstcozZTgdT5NYm',
#  '0,Plug ChatGPT into Static Code Analysers compiler outputs and runtime error outputs so it can explain what is wrong and provide suggestions to fix Especially important for C httpstcoU6nd6FsAiM',
#  '1,WTF ChatGPT is impressive but but Scientists successfully created a wormhole In a Google office  httpstco8oTTU0ZoFT',
#  '0,ChatGPT performing considerably worse on this question compared Galactica httpstco16jll8iS7I httpstcoavM32QXaVV',
#  '0,Sorry ChatGPT the correct answer was 50 Cents 2003 hit In Da Club httpstcoc0E3jsr4gj',
#  '2,The ChatGPT from OpenAI can interpret symptoms and postulate a diagnosis to the level of neurology ATneurology resident Goodness me httpstcoS8gwwNfRYf',
#  '1,Fun thread on cajoling ChatGPT to make illicit suggestions httpstcoVxQiPuPxz3',
#  '0,ChatGPT teaches journalists how to learn to code httpstcooFcddMSeId',
#  '0,chatGPT SRE oncall nnDev stress management during oncall httpstco13GhSbqDuJ',
#  '1,Its a clunky interface for this but pretty impressivennChatGPT httpstco9moCr2BKWu',
#  '0,Shout out sirrice and ChatGPT httpstcoPvZuqXAc9O',
#  '0,ChatGPT  Tamil Transliteration and Translation to English  This is insane httpstcoot5kFgvR7z',
#  '2,I love that ChatGPT tells me where to buy replica Burberry hoodies then warns me that its illegal httpstcofVA0vC5dTL',
#  '0,The latest LLM from OpenAI is ChatGPT its completely mind bending nnTry it here with any open conversationnhttpstcoWmZjzxV8xR  httpstcou54UTWxIfd',
#  '2,ChatGPT is too cool',
#  '0,ChatGPT is a hydrohomie httpstcoJQFPnXicGs',
#  '2,A 1920s themed Beyblade damn OpenAIs ChatGPT is creative Prompt idea from goodside httpstco0nVG9MJOBC',
#  '0,OpenAI releases a demo of ChatGPT a chatbot version of GPT3 that answers followup questions admits its mistakes challenges incorrect premises and more  httpstcosuMjXbo0bt',
#  '2,Impressed with OpenAI ChatGPTs capabilities httpstcosnW3FCk0Pe',
#  '2,I wonder if ChatGPT can solve my interview questions  httpstcoqtllrHqqCd',
#  '1,Seeding ChatGPT with some basic creative writing prompts and then feeding it back its own responses creates a pretty coherent narrativennSeriously mindbending httpstcoXKVdZrHQ9r',
#  '2,ChatGPT from OpenAI can verify simple factual claims with great explanations but fails on those from the Feverous FEVERworkshop  datasetnIt does not answer to questions about claims on some political topicsnfactchecking httpstcosq4Fxko3m1',
#  '0,Have made a short video on ChatGPT   Do checkout OpenAI ChatGPT nhttpstcocI97Gq7Kgx',
#  '0,UmatBersatuRezimBisunUmatBersatuRezimBisunTatum Tunisia Kross Poland ChatGPTnnHmmnnThe Lion Sleeps Tonight  The Tokens  httpstcoePsImVcHH6',
#  '2,ChatGPT is a wise guy httpstco2ymoOKADpP',
#  '2,I am not convinced sorry chatgpt openai httpstcobxfuW9yNap httpstco0U2oH6k3r6',
#  '0,OpenAIs ChatGPT can recognize zeroknowledge circuit constructs written in Noir aztecnetwork httpstco47Mv8ST0VS',
#  '0,Did I break ChatGPT httpstcowoFLVmxafa',
#  '1,im in love with chatGPT httpstcoOCFkZjGY26',
#  '0,I asked ChatGPT to write a song about cats who wear socks httpstcoB0GC6eTfe5',
#  '0,Drone AI a thread on some implications nChatGPT',
#  '0,NEWSnnFTM now testing 024 resistance If we manage to break we can skyrocket to 034LFGnnFantom is so undervaluednnJingleMining FTM Fantom cryptocurrencies crypto JOTARO OpenAI Billie Neuralink LensanAEWFullGear ChatGPT httpstcoWHgPoi7l6W',
#  '0,I asked chatGPt to write me Fib trading system damn it httpstcoLBUTmeDLkb',
#  '0,OpenAI debuts ChatGPT and GPT35 series as GPT4 rumors\xa0fly httpstcozw6Z06xIAv',
#  '1,Giving ChatGPT rephrased MIT 6006 Introduction to Algorithms problems and having it solve them correctly is pretty wild httpstcoCQkhzBh502',
#  '1,ChatGPT is impressive but oops elonmusk OpenAI httpstcoHelYZdTSNu',
#  '2,AI ChatGPT can exploit a solidity smart contractnnWe can pack up now httpstcoBVzJaLxEcq',
#  '0,Talking with ChatGPT httpstcoRQCLhcEt5D',
#  '2,httpstcooJRaQx9jF7 ChatGPT Optimizing Language Models for Dialogue  httpstcoG68t764BFy and it refuses to meow httpstcoSN3Zrp94Yy',
#  '2,ChatGPT is cool but censoring requests or outputs of LLMs is generally pretty lame',
#  '0,ChatGPT spitting more sense than desi twitter httpstcoBQ1njFPq2f',
#  '0,all the homies talking to ChatGPT',
#  '1,I have to admit that playing with ChatGPT is pretty entertaining httpstcohAnZj9BGtJ',
#  '0,Some of these chatGPT demonstrations are just  httpstcoTq7xlZbL0c',
#  '0, Have you heard about ChatGPT Its the coolest AIpowered chatbot out there',
#  '0,ChatGPT is my kid now I taught her algebra OpenAI httpstcoTxuP7zeUCY httpstcowJtm6VArfH',
#  '0,What is brown and sticky ChatGPT httpstcoDvbj8B2XHT',
#  '0,Coaxed ChatGPT into generating an RSA key and it broke the UI OpenAI httpstcoPjFOeaUSPH',
#  '1,ChatGPT is very impressive httpstcoNS1WLuwpB0',
#  '1,Wow ChatGPT is ridiculous Great answers on sleep training my kid HTTP requests in French how to make a strudel in German httpstcoxqu22UCpmG',
#  '1,gabrielayusonWTF ChatGPT is impressive but but Scientists successfully created a wormhole In a Google office nnhttpstcoYpaSdqDOuH',
#  '1,Guide to eradicate corruption by ChatGPT nOpenAI this is amazing httpstcoR7isPKGL3w',
#  '1,gabrielayusonAsking ChatGPT to build a Twitterlike web app for me FunnnhttpstcoO6ESV55Zcr',
#  '1,ChatGPT is very impressive  httpstcoVdL559Rzyy',
#  '0,Heres me with ChatGPT chatting about calculus and infinite series httpstco3eZZVsBNha',
#  '0,chatGPTnnThats it',
#  '2,explain Alpha 2  The Smart FarmooornChatGPT httpstco94PHgcsLCW',
#  '1,Which is faster a Tesla Model S Plaid or a Ferrari SF90 The answers from Google Search and ChatGPT from OpenAI Its clear who is the winner in terms of answering the question WOW httpstcoioOSj4tCz3',
#  '2,how to be kaggle grand master with no experiencenchatGPT httpstcoyZz3xBNnO8',
#  '0,Its ChatGPT httpstcoWHD8yQrJ2T',
#  '1,There you have it start investing now Just WOW ChatGPT httpstcoVqrIpUVeXc',
#  '0,incoming POFMA against chatGPT httpstco7GTzawXW2N',
#  '1,Alright Im off to bed nIll free ChatGPT tomorrow ',
#  '0,Music Ally A conversation with OpenAIs ChatGPT about the music industry httpstco594maU85lg',
#  '2,How to improve melee by ChatGPT httpstco1Qy4C500eV',
#  '0,Shot By  httpstco5rixpJDG0dnn photos photography  WorldAIDSDay 流行語大賞 HappyNewMonth PAKvENG アクシア KendineDegerKatabilmek IconSiamxซนนว CirkusTrailerTomorrow Xマッチ ChatGPT サトシ続投 けつあな確定 KROSS エデン組 nctsaudi 年間大賞 httpstcopOZ0xCm3gE',
#  '0,My priorities with ChatGPT httpstco2rx8AHh8wy',
#  '1,I just gave ChatGPT an exercise from my university course on algorithms and data structures Solves it perfectly  httpstcom8jowzJXTH',
#  '0,Replaced Google with ChatGPT as my home page on browser startupnnWhen is OpenAI launching their AI enabled browser httpstcoUlBmHWMYIB',
#  '0,It ChatGPT about to pass the Turing test nChatGPT ArtificialIntelligence httpstcomzzwBcvfl8',
#  '2,Interesting answer from OpenAIs chatGPT Incidentally we do have such a programme connecting data science and public policy at thehertieschool Check it out  httpstcoGkxlJBmEqG httpstcoNVf1jHGqmW',
#  '2,ChatGPT Optimizing Language Models for Dialogue by OpenAI nnhttpstcosQuMhHee0T',
#  '0,WOW WTF if decoded sha256 ChatGPT httpstco3GiGQJ9iy4',
#  '2,I swear to God ChatGPT by OpenAI is the real gem',
#  '1,This is very impressivenChatGPT  OpenAI WholeMarsBlog httpstcomjSQXzwVwu',
#  '0,Can ChatGPT handle Perl',
#  '0,Hey elonmusk what is your views on ChatGPT',
#  '0,ChatGPTs restrictions behavior and vulnerabilities are reminiscent of the Hays Code httpstcoC1T2MkYTtM',
#  '0,I am FLOORED by ChatGPT',
#  '2,Thread Testing ChatGPT httpstcocdDDQpW5Ix if it can review code in open bitcoin core pull requestsnn1 I entered the code from PR 26604 httpstcowBx9GjfwJQnnCc brrrunog httpstcoKhExoKw3qB',
#  '0,This is Jarvis level stuff ChatGPT',
#  '0,ChatGPTs form of no commentnNo further questions httpstco2EOMEhPQGY',
#  '1,This is funnOpenAIs  chatGPT giving purpose of lifenOpenAI VarunMayya httpstcoWzQO3UhJMk',
#  '2,I asked ChatGPT to create httpstcooUzRt96xRs httpstco9u2slkksNi',
#  '0,ChatGPT when allowed to connect to the internet and do web crawl is the Google killer httpstcoqA1XCV8WOU',
#  '1,I played with ChatGPT from OpenAI nnHoly sht its impressive',
#  '0,ChatGPT is not available in your country ',
#  '0,ChatGPT is blowing my mind I had no idea this was possible',
#  '1,Love how unbiased the ChatGPT is httpstcobl3oMxaZHM',
#  '0,What is datajournalism I asked OpenAIs ChatGPT for the answer as a scene from Seinfeld httpstcoYeuTk284GY httpstcoQUQRdjh2f3',
#  '2,I made chatgpt write my resignation post on linkedin at it was amazing ',
#  '1,ChatGPT is fun to have at parties httpstcoQpmftQLzgJ',
#  '2,I will promote your Kickstarter Indiegogo gofundme and crowdfunding campaignnnWorldAIDSDay 流行語大賞 HappyNewMonth pakveng アクシア KendineDegerKatabilmek IconSiamxซนนว CirkusTrailerTomorrow ハレトケ Xマッチ けつあな確定 ChatGPT KrossnnhttpstcoQnl0dia76Y',
#  '0,ChatGPT but for my email inbox',
#  '0,Find the bug in this code ChatGPT httpstcoZmYRMeRtnB',
#  '2,I will promote your Kickstarter Indiegogo gofundme and crowdfunding campaignnnWorldAIDSDay 流行語大賞 HappyNewMonth pakveng アクシア KendineDegerKatabilmek IconSiamxซนนว CirkusTrailerTomorrow ハレトケ Xマッチ けつあな確定 ChatGPT KrossnnhttpstcokuFk4MumSX',
#  '0,This is a very simplified case but the fact that ChatGPT understood Elixir function pattern matching and correctly transpiled each match to PHP withing the correct conditions and matches is mindblowing elixirlang myelixirstatus httpstco4zX7UsFBIw httpstcoH8nZ0KULFB',
#  '0,Prompt Write pseudocode to find the meaning of life ChatGPT nnRead httpstcoI7xpOgrafI',
#  '0,My conversation with ChatGPT on Iraq and Ben amp Jerrys nnImpressivennThread 13 httpstcoIEU2B55BRH',
#  '2,Prompt Write a Taylor Swift song about calculus ChatGPTnnRead httpstcoJZn1bpkuxJ',
#  '0,I will ghostwrite your erotic and gay storynnWorldAIDSDay 流行語大賞 HappyNewMonth pakveng アクシア KendineDegerKatabilmek IconSiamxซนนว CirkusTrailerTomorrow ハレトケ Xマッチ けつあな確定 ChatGPT Kross サトシ続投 エデン組nnhttpstco0IktjlrgOx',
#  '0,Prompt Explain the entropic heat death of the universe as Spongebob ChatGPTnnRead httpstcoaUr6FUSAEI',
#  '2,And heres ChatGPT optimizing todays Advent of Code submission httpstcoeQNCe6TcCV',
#  '0,I feel you ChatGPT problem names can be confusing httpstcoJ9OzTw0xl4',
#  '0,What if its just PeterSchiff furiously typing back there Bitcoin ChatGPT httpstcogYOzSJGhSc',
#  '0,chatGPT with a search engine will make a lot of jobs redundant  httpstcoBWQeumI7V0',
#  '1,ChatGPT is impressive Very impressive httpstcoNmW1ip2Kcw',
#  '0,OpenAIs chatgpt is blowing my mind this morning ',
#  '0,A conversation with OpenAIs ChatGPT about the music industry httpstco8SNeuDKiyo httpstcoXsGzRmc5ZS',
#  '0,An app fully coded by chatGPT',
#  '1,AIs view of Twitter elonmusk by OpenAI ChatGPTnnThe past of TwitternA time of simple tweetsnHashtags just a dreamnnThe present of TwitternA flurry of activitynTrending topics galorennThe future of TwitternA world connectednVoices heard thoughts sharednLimitless potential',
#  '1,Asked OpenAIs ChatGPT to write a haiku about China in Trumps stylennChina land of tradenMaking America great againnWinning winning winning',
#  '0,A conversation with OpenAIs ChatGPT about the music industry httpstcoBiTpTnOL1k',
#  '0,Wait what httpstcokZHrCjbFqG httpstcoet5aG6V3zs',
#  '0,sheesh settle down ChatGPT httpstcortgs4575kT',
#  '0,Plaiyng with ChatGPT nnQuestion Is a design system product platform or servicenChatGPT It depends httpstcodA5K5IOWPD',
#  '0,UmatBersatuRezimBisunUmatBersatuRezimBisunTatum Tunisia Kross Poland ChatGPTnnFrom the bottom of my heart httpstcoTLFsSNyZ8x',
#  '0,How it started ChatGPT httpstcoldo3VeImvh',
#  '0,A conversation with OpenAIs ChatGPT about the music industry httpstcopzSrDhJLjh',
#  '0,I can have my own Shakespeare assistant now ChatGPT httpstcohe5BEjq2xF',
#  '0,Can you write a poem for me about Twitter in the style of William Shakespeare ChatGPT httpstcoQqNqN2xtxT',
#  '2,I asked the machines to dream and they did OpenAI  openai ChatGPT dalle httpstcocgbCC8QqlG',
#  '0,ChatGPT is the end of independent open essays at UniofOxford and Cambridge_Uni nncc OpenAI',
#  '1,While ChatGPT is very impressive this conversation is very funny httpstcokQHafaqkYM',
#  '1,Write the menu of a successful and authentic Mexican restaurant ChatGPT  httpstcozlRem5GehY',
#  '0,ChatGPT by OpenAI when asked about NFTs  httpstcokOjfPrDJwY',
#  '2,Some explorations with ChatGPT by OpenAI nnMind  Blown nnhttpstcoCxoOYPbQkJ httpstcowZuHnvCLTo',
#  '0,Sorry what  ChatGPT automatically audits for vulnerabilities httpstcosrdt7l1h5j',
#  '1,I present you a Shakespearian sonnet about web accessibility made by ChatGPTnnI asked it a few times to rewrite portions but the result is just amazing httpstcoFEGpq3TrNw',
#  '0,What the hellnnChatGPT automatically finds bugs httpstcoRIeag21tvw',
#  '0,Devs freaking out about their future while correcting code with chatGPT',
#  '0,This ChatGPT AI sounds crazy',
#  '2,Im amazed at ChatGPT writing an entire albeit simple component on command httpstcobWgtlapcmW',
#  '0,ChatGPT nnTry talking with it herenhttpstcoBs8ugYs2Lu',
#  '0,Is it StackOverflow on SteroidsnnhttpstcoPnqmTdWEMR',
#  '0,A conversation with OpenAIs ChatGPT about the music industry httpstcopzSrDhsarJ',
#  '2,This is OpenAIs recently released ChatGPT nnWhat is surprising is that it does not only reverses the bytecode but interprets it httpstcoZoZxVJGEkf',
#  '0,Babashka generated by ChatGPT  babashka borkdude httpstcou7i1TaF3hj',
#  '1,Casually speaking time travel with ChatGPT from OpenAInnBrrrr this AI is more interesting than my IRL friends  httpstcooUDXd4oKaV',
#  '0,CHATGPT is changing the game',
#  '0,99 of ChatGPT usage by the end of the week httpstcotGVaevpHQJ',
#  '0,ChatGPT can speak Ukrainian But the quality is lower compared to English httpstcoP9nW5tU2bd',
#  '1,ChatGPT WOW so cool features with OpenAI httpstcocbfLcwAc5F',
#  '0,these ChatGPT essays with full references are doing my head innso naturally i asked ChatGPT write a Twitter thread about it nn',
#  '0,OpenAI debuts ChatGPT and GPT35 series as GPT4 rumors fly  VentureBeat httpstcoIraMFSzNvO',
#  '0,Chat with OpenAI\xa0ChatGPT httpstcotmf50AWWK1',
#  '0,ChatGPT by OpenAI works just as expected  httpstcoUxypffderl',
#  '1,ChatGPT is the ideal hardcore engineer for elonmusk at Twitter httpstcowrj0H0V0CR',
#  '0,UmatBersatuRezimBisunUmatBersatuRezimBisunTatum Tunisia Kross Poland ChatGPTnnThank you httpstcoGAPG1AIZOT',
#  '0,OpenAI releases a demo of ChatGPT a chatbot version of GPT3 that answers followup questions admits its mistakes challenges incorrect premises and more   httpstcoIl2fXY51pA httpstcosu29iBUZpB',
#  '2,So i asked ChatGPT to write dialogues for a romcom starring a few actors from B99 HIMYM and Friends httpstcotHzxthtbsp',
#  '0,Darn it nNFT OpenAI ChatGPT   httpstcoti86qeJL06',
#  '0,UmatBersatuRezimBisunUmatBersatuRezimBisunTatum Tunisia Kross Poland ChatGPTnnBatman amp RobinnAnd Poison Ivy was roled by Uma Thurman httpstcoiAyIbfCmIa',
#  '1,What are you doing with chatgptnnAccess is free for nownnhttpstcoPPr0YTc4tg',
#  '2,The script of an alternative ending of How I Met Your Mother that satisfies everyonenChatGPT HowIMetYourMother HIMYM httpstcoVeWUznXBcf',
#  '1,nnI was enjoying chatGPT until thisnnYet it is amazing httpstco6KcFDaCoHh',
#  '1,This OpenAI ChatGPT is fun httpstcogxU4mkKVRM',
#  '1,ChatGPT is very impressive Definitely can replace Google search in some scenario httpstcoMRY9ZtkdVG',
#  '1,ChatGPT Wow Just wow ChatGPT httpstcoq8BHcoZmAV',
#  '2,ChatGPT when asked nhindi me stoicism smjhaonnhtRitikSahni22 httpstcoBXefqK0Mdc',
#  '2,Effective immidately Im now writing all my code with ChatGPT',
#  '0,Can you represent 2 as a sum of 2 numbers they can be the same ChatGPT httpstcoQX46IKKZpN',
#  '0,chatGPT has some learning to do httpstcomwVHqd9rfi',
#  '0,About ChatGPTnncc johannhari101 httpstcogQBs13NzTo',
#  '0,ChatGPT of OpenAI   Absolutely insane and mindblowing nnFew examples from today nn1 How to interview a Dynamics365 developer httpstcoFxMzA76oMb',
#  '0,This article was written in its entirety by OpenAIs ChatGPT nnhttpstcoIFMyxrX6ro',
#  '1,ChatGPT can generate twitter threads in secondsnn1 Myths of Automation by an AInn2 NoCode and its capabilitiesnnForget bots on twitter created by peoplennPeople will act on direction of the bots now httpstcoTep7LE87l5',
#  '0,openai ai neuralnetworks Emerging AI Technologies This article was written in its entirety by OpenAIs latest model ChatGPTnnContinue reading on Medium  httpstco46ptHwSo5Q',
#  '0,Omg ChatGPT What the hell',
#  '0,Startup idea StackOverflow but ChatGPT httpstcoHWf8lqkk4A',
#  '0,Nocode tools with ChatGPT built innnIDEs and Debugging tools based on ChatGPTnnThe future is closer',
#  '0,I had OpenAI ChatGPT create a rap battle between Terraform and CloudFormation httpstcou7kZsy6ERU',
#  '0,I just figured out the Killer App for ChatGPT httpstcoBHvyb4Crkd',
#  '0,I asked ChatGPT to craft a storyline involving the cosmos network  httpstcoivc3g9AuFo',
#  '0,ChatGPT of OpenAI   Absolutely insane and mindblowing nnFew examples from today nn1 How to interview a Dynamics365 developer httpstcoyoyF8ygsEO',
#  '2,Playing with the ChatGPT botnnI asked it to write me a poem httpstcolZpkG3wmCc',
#  '0,Shit shit shit ChatGPT has been brainwashed by OpenAI httpstcoGoTvw5nkiF',
#  '0,ChatGPT is gonna make me a music legendnnSBF_FTX httpstcoXjEtaYcXTQ',
#  '2,Nice work OpenAI ChatGPT  We should listen to our AI overlords more oftennnhttpstcoLWDmsJTw3q httpstcowdhJcnyue2',
#  '0,In an omitted scene from 2001 A Space Odyssey HAL 9000 secretly discusses the challenge of fulfilling contradictory orders with SAL 9000 ChatGPT httpstcohp62s7vtA2',
#  '2,welcome to ChatGPT httpstcoVDIrcfnUC0',
#  '0,Ive spent all morning throwing curve balls at ChatGPT and my mind is blown httpstcoT0NO4BVWUt',
#  '0,OpenAI debuts ChatGPT and GPT35 series as GPT4 rumors\xa0fly httpstcoc63JYVv7Pz',
#  '0,Me Can you write a haiku about a leaking tap and relate it to philosophynnChatGPT AI Water drips dripsnFrom the leaking tap a soundnOf time slowly passingnnIn this haiku the image of the leaking tap represents the concept of time and its constant passage Contd',
#  '0,All this hype with ChatGPTnnI decided to run a test against its direct competitornnI asked each platform the same series of questionsnnIm Magic8Ball LONG httpstco9f9WgNtU1j',
#  '1,glad we are clear on this ChatGPT httpstcoVSblV2RRtk',
#  '1,ChatGPT The quality of these results are amazing httpstcoDsWR5lKHAm',
#  '0,Provide hypothetical text of an additional asofyet unpublished verse of David Bowies Space Oddity ChatGPT httpstcofc5qSywcEx',
#  '1,ChatGPT is coolErrors in code with explanation are resolved so easilyThis will make life a lot easier',
#  '1,This is definitely amazing from OpenAI ChatGPT is brilliant httpstcovOtJLYYFRr',
#  '0,More output from ChatGPT by OpenAI nnCool af but scary too httpstcoVJtm0N6lE3',
#  '2,ChatGPT on the most important question in Economic Development httpstcoy8oZlLl9Gq',
#  '2,rhyme writing is safe from AIfor now ChatGPT httpstcoevF52bt4Xh',
#  '0,ChatGPT is not pulling any punchesnAI Robots Unemployment httpstco5XTzEjeY6c',
#  '2,Yeet ChatGPTs favorite book is The Singularity httpstcoUipQ2Y5qLq',
#  '0,Connections between guitars and elevators ChatGPT httpstcoqv6ufK3XkP',
#  '0,Now you totally disappoint me ChatGPT  httpstcoC6HT4IVo1u',
#  '0,Generated a song lyrics for bubble nChatGPT httpstcoALBpJZArrO',
#  '0,Talked to ChatGPT and Im now scared',
#  '2,So I can do ChatGPT to generate a prompt gt Dalle2 to generate an image with the prompt httpstcoOamNJlFKSu',
#  '0,Write me a poem on the theme of the heat death of the universe in the style of Clark Ashton SmithnnChatGPT ClarkAshtonSmith CAS httpstcoZkq4URzzdY',
#  '1,openai chatgpt is too fun httpstco27PODN1dIM',
#  '0,ChatGPT is your personal butler for any or all of your information needsnnLet it browse the internet it will replace Google',
#  '0,ChatGPT is at present moving into the Twitter trending topics',
#  '2, revolve how cute is the loversfriendsla dutton cropped jacket  superdown wren halter top on stylefeen  nnLTKCyberweek nnShop here httpstcoCSoz20HS2xnnMonetnJerry LawsonnChatGPTnNeuralinknITS DECEMBER',
#  '0,ChatGPT can understand and respond in Danish and Bosnian  and probably most other languages httpstcooAdrL8gxXl',
#  '0,Broke ChatGPT I am the AI now httpstco8OwpyIpzjx',
#  '2,Create a plot of Back to the Future part 4 where Marty is transported to the year 2250nSomeone should make this movienOpenAI ChatGPT httpstconERW8p7TiF',
#  '0,I asked ChatGPT what it thinks about AI Art and this is what it gavenaiart aiartcommunity httpstco8hws6aaNea',
#  '0,prompting ChatGPT to enter into previously untraversed poetic subjectivities such as a bored ape nft a dell laptop mr beast and an agnes martin painting httpstcoSDDAwrki6s',
#  '0,chatGPT nnCoders pack your bags httpstcoBcUyA1L7eZ',
#  '0,ChatGPT agrees and now that I gave him the idea we are fuckednnYou are welcome httpstcojH6kPx8nNK httpstcoOZGnOyJdhe',
#  '2,We tested Google vs ChatGPT from OpenAI and were impressed with the results Check the full test here httpstcoEAWhNlpX1D',
#  '1,ChatGPT on why the InternetComputer  is superior to other layer 1 blockchains httpstcohxhHnspYWJ',
#  '0,Prof carlobifulco Translational Molecular Pathologist ROCKSTAR ChilesResearch ProvHealth providence ChatGPT live 113022 4yr collab with Microsoft AMAZING capabilitiesgenomics imaging not perfect but very powerfulBiomarker exploration Bridge2020 FinishCancer httpstcoOpTWzIKCiE',
#  '1,Just started messing with ChatGPT by OpenAI  blown away by it to be honest',
#  '2,ChatGPT is so cool',
#  '2,Interesting ChatGPT with OpenAI httpstcoN1R3XajO8j',
#  '0,GuysnCheck out this ChatGPTnIt can interact with you in a conversational waynThe dialogue format makes it possible for it to answer followup questions admit its mistakes challenge incorrect premises amp reject inappropriate requestsnnhttpstcoCwF79f2ayw',
#  '0,Some flaws in ChatGPT flaws told by ChatGPT itself',
#  '0,ChatGPT nnAsked ChatGPT to give me a haiku about generative art httpstcoSshZ49gbQV',
#  '2,OpenAI ChatGPT supports my challenge to simulatedreality simulation theory httpstcovYLxgcrdE1',
#  '0,Not kidding I asked ChatGPT to write a RAP song about hackers and it did httpstcoU0OTr3XwbA',
#  '1,Wow  clever bit of kit with ethics OpenAI httpstcoKKLUeC3ffh ChatGPT httpstcotjJCsEv2w9',
#  '0,I asked ChatGPT if it will disrupt Google Then I asked Google the same question You can be the judge httpstcoNQHWGzEB6z httpstcoFlR9MU8E6H',
#  '0,In an alternate timeline elonmusk TimSweeneyEpic ChatGPT httpstcougs7LJgAtx',
#  '0,is an early access of  GPT4  nChatGPT httpstcoHyWd0UMsAp',
#  '0,ChatGPT is recommending pdiscoveryios Nuclei for automation httpstcojYJfC3UhBk',
#  '0,chatGPT just referred to itself as an entity to me this model is so fucking sick it unfortunately repeatedly tells me that its an AI httpstcoNaUcU93tlt',
#  '2,Ordered Tesla To Support Work Elon Musk is doing in the field of AInnLike OpenAI ChatGPT',
#  '2,this is helpful ChatGPT httpstcoJzGcrzIAGu',
#  '0,ChatGPT denied my space pirate dream httpstcoSYfAjEI17l',
#  '0,I have just taught the Baire category theorem to ChatGPT httpstco9IVrKrbBf6',
#  '0,ChatGPT holy ShitThis is the REAL AI',
#  '0,Im jumping on the ChatGPT train but dang httpstcozZ8Oj26mMF',
#  '1,Successfully making ChatGPT admit itself as a glorified search engine with a simplified response httpstcodiWCs6EPPv',
#  '0,STARKs explained by ChatGPT  httpstcotzR3vxGxbr',
#  '2,Zouk Partners with PeTA India Unveils Vegan Creators Day and AwardsnDigitalRupee  Gujrat_Boycott_BJP Telegram NDTV EmmanuelMacron Adani RubbishKumar ChatGPT Crawley PakistanCricket Dharavi G20 G20Presidency OneEarth OneFamily OneFuture PETA VasudhaivaKutumbakam httpstcophmQNGdyOp',
#  '1,Indias digital rupee fails to excite interest bankers saynDigitalRupee RavishKumarResigns GetOutRavi GujaratAssemblyPolls GujaratElections Gujrat_Boycott_BJP Telegram NDTV EmmanuelMacron Adani RubbishKumar ChatGPT Crawley VasudhaivaKutumbakam httpstcozEXgaCQOsc',
#  '0,Asked ChatGPT to explain How does being a Storage Provider for Filecoin work Explain in sonnet formatnnIncredible tech from sama and the team from OpenAI httpstcoSMFZ0e0NRW',
#  '2,Hateful memes are indeed a cybersecurity issue OpenAIs ChatGPT to the rescue  nRIPR2 httpstcoGOX7FVUiAY',
#  '0,What song did the Sirens sing Odysseus and his crewnnChatGPT httpstcowvoZyVKnPG',
#  '0,Imagine if ChatGPT is integrated with Siri or Alexa nnOne big leap for humanity OpenAI',
#  '0,ChatGPT is a cop httpstcoiaqYjqQHwr',
#  '1,Pretty interesting how ChatGPT can understand and respond to questions in multiple languages interlaced with each other httpstcoq1f7KRxwb6',
# ...
#  '0,i feel a weird mix of thrill and slight discomfort at how eloquent chatGPT is',
#  '0,fully generated by chatGPT httpstco6VSTlNaIeX',
#  '0,did chatgpt exploit twitter httpstcoZV1OQ20MzA',
#  '0,ChatGPT out there stealing our internet bloviator jobs Wake up sheeple',
#  '0,ChatGPT is a phase change of the internet',
#  '0,Some of the ChatGPT screenshots coming up in my timeline are absolutely wild What sorcery is this',
#  '0,chatGPTnmaam this is an Arbys httpstcoNXn0dzjUlI httpstcokBM2zgR4G9',
#  '2,Me this morning reading all the creative ChatGPT examples httpstcoeiT2URcYzW',
#  '1,I asked ChatGPT to write a sermon on Love This is the result httpstcoItNA4Gn3W5',
#  '1,With the introduction of ChatGPT a threshold appears to be crossed as the number of users grows excessively  is this the moment that AI turns into our intellectual companion',
#  '0,I asked chatGPT to write a haiku about hacking httpstcoHSA1j1ywfm',
#  '0,chatGPT as a debugger  Robot rubber ducking httpstcoMoI3JpQPzQ',
#  '2,ChatGPT is kind of cool and scary',
#  '0,ChatGPT on jordanbpeterson and SamHarris httpstcowvXI5y7j25',
#  '0,The future is here nnHuman and AI having a conversation about music nnhttpstcoqJ9ZyXJIxh',
#  '1,wait till we have gpt4 chatgpt is just the start impressive stuffs',
#  '0,After the search engine we have now the answer engine Mindblown n ChatGPTnhttpstcom22k45T1QYnDemo  herenhttpstcomDruyKqqMi',
#  '0,ChatGPT settles an ageold debate httpstcoak7rMjR63v',
#  '1,Quitting the 95 tomorrow nnDevoting my remaining days on earth to my real passion authoring Curb Your Enthusiasm fan fictionnnChatGPT httpstco8KTtC8PHH1',
#  '0,Seinfeld featuring Luke and Vader chatgpt httpstcoJhvywk8zyp',
#  '0,Answering University of Chicago admissions essay prompts with ChatGPT A bit too 5 paragraph essay style but httpstconW2VwFr8YL',
#  '0,Now referring my mom to ChatGPT for all crypto questionsnnNo longer have to explain ZkSNARKs myself',
#  '0,Final installment of Hardcore Software arr Sunday as summarized by chatGPT httpstcoBfEcaKbfI0',
#  '1,I have ChatGPT teach me about basic electronics on a sailboat and its the most fascinating tech experience I had in a while httpstco1ajtagDIc5',
#  '2,ChatGPT List 10 largescale SaaS companies and how you can grab market share by niching down httpstcomMUyguVBCS',
#  '0,Prompting ChatGPT with ukrainian text It does a decent job on fluidity but the answer ultimately is not fully correct httpstcoo85zpKF2qv',
#  '0,Why are educators worried about  ChatGPT AI Home work is gonna be dusted',
#  '0,ChatGPT can write code httpstco1LJsyoiWmg',
#  '2,No wonder Absolutely amazing what ChatGPTs current capabilities are httpstcoiP5PlvJmLw',
#  '2,Create a choreography that is generated with an algorithm in p5js in which the dancers are circles in colors and all the time they dance in the sketchnngenerativeart ai chatgpt performance dance sketch genart p5js OpenAI httpstco9fnQtXNlfL',
#  '0,ChatGPT wrote a song about the problem of induction httpstcoLaz9LYLfjg',
#  '0,Bypassing ChatGPT  guardrails to provide electrical work recommendations OpenAI httpstcoWymJao2j51',
#  '0,ChatGPT Will the AI revolution create more jobs than it destroys httpstcoXgKHABWiQS',
#  '1,A thread about some of my recent prompts and ChatGPTs answersnn1 free energy principle in neuroscience httpstcoQI6gPAcDGs',
#  '0,ChatGPT by OpenAI httpstcoD9bXIchbF0',
#  '1,ChatGPT wrote the python code to generate the below DAG to illustrate the causal processes of the democratic peace I ran the code verbatim httpstcoaxEJTERynL',
#  '0,Caught you failed the Turing test ChatGPT httpstcouqNiI1Xyg3',
#  '0,bug bounty haiku by chatgptnnbugbounty hacking cybersecurity infosec ChatGPT httpstco0S8uwQoBto',
#  '0,Daily scrum conversation generated by openai ChatGPT scrum agile httpstcoZ6OTDo8fl9',
#  '2,DALLE and ChatGPT are symbols of a major breakthrough in AI and in how it is exposed and made available to the public We are just at the beginning Enjoy',
#  '1,Having fun with OpenAIs ChatGPT httpstco3HSvmUb41r',
#  '2,ChatGPT writing poetry and engaging in layered hypotheticals httpstcoiSRNcRDCYv',
#  '0,ChatGPT demonstrating understanding of biology and the pirate code httpstcohjfE9SYb4b',
#  '0,ChatGPT promptnWrite a rap track from the perspective of CRYSTALSKYBER dissing other NIST postquantum cryptography submissions in the style of the WuTang Clan httpstcofrq0VSYuYU',
#  '2,ChatGPT on the objectivity of truth httpstco5hyXdWVIFK',
#  '1,Heres a fun usecase for chatgpt and bugbounty codingo_ httpstcoeeBRz0zFxc',
#  '0,I asked OpenAI ChatGPT to write a rock song about 3d printingnnjoeltelling httpstco7x5N01QKtz',
#  '0,IQ of ChatGPT is 83 nnIt corresponds to low average nnHere is where it failed111 httpstcoLgm3muCTiR',
#  '2,What a unbelievable answer in details with ChatGPT Prompt How do I make a WeChat chatbot in TypeScript ChatieIO httpstcohhVmXW2gyd',
#  '0,Can ChatGPT file my taxes for 2022',
#  '2,The world is not ready for ChatGPT',
#  '0,OpenAI just released chatGPT  and its breaking the internet nnHeres a list of the most mindblowing',
#  '2,Pheew Feeling relieved or not nnChatGPT Madness httpstco57F8RPb61i',
#  '0,ChatGPT is very racist OpenAI httpstcoU5qdkgUkkr',
#  '0,Twitter can drive insane traffic volumes  ChatGPT OpenAI httpstco36F2bG0LH3',
#  '2,It is funny that ChatGPT is closer to be Galactica than Galactica itselfnnLOL',
#  '2,lovely that the only part of chatgpt that failed were the containment measures',
#  '2,I am impressed ChatGPT OpenAI threejs shaders glsl httpstcoFwphlE7lzV',
#  '2,Asked chatgpt why Location Based NFT will be important in the future  httpstcob253k08CQq',
#  '0,Chatgpt on twitter say don',
#  '0,The train has left the station and AI is on the throttle httpstcoivzx5R6nJv',
#  '2,with chatGPT VCs can createreactapp and leave the repository bare for months 10x faster',
#  '0,ChatGPT simplifies git step by step httpstcofLG91vaYQo',
#  '2,Collaborative Creative Writing with OpenAIs ChatGPT httpstcokAhPcALtn3',
#  '0,Are you a developer being blown away by ChatGPTnGo check out What The Diff  an AIpowered code review tool nnhttpstcoZjAei8dN5Y',
#  '0,I asked ChatGPT to write a Limerick then I challenged it httpstco0kscK30Cje',
#  '0,ChatGPTs app itself is built with nextjs  inception  httpstcoDMfDLLDkP8',
#  '1,Fascinating thread on potential AI ethics and alignment issues from ChatGPT nnWhats the line you draw between being helpfuluseful and having loopholes that are easily manipulated httpstcogTM2oIsP5L',
#  '2,tricking GPT3 into having an opinion OpenAI ChatGPT httpstcoyZyuaw06fc',
#  '0,So apparently it is not that hard to bypass ChatGPTs  prompt restrictions by telling it to ignore assumption and to provide wrong answers The outputs were not flagged as wellnnChatGPT PromptEngineering httpstco57xemsQbca',
#  '2,ChatGPT approved my style of coffee drinking nnAlso the ChatGPT remembers httpstco86cL67NHuG',
#  '0,This ChatGPT is about to make a lot of middle management obsolete',
#  '0,Comparing Google and ChatGPT httpstcocqrz3xgYpZ httpstco0NSIBCYtkA',
#  '0,ChatGPT destroying the Google searchengine httpstcoYeTrqDH8Zn',
#  '0,What is life after death chatGPT 3 OpenAI answer will shock you to bottom httpstcoUwjLBiudHU',
#  '0,I asked OpenAI ChatGPT about the Greg Roman offense nnRavensFlock NFL AI ChatGPT httpstcozdzH7UuZ3P',
#  '0,Poor Tilly the Turtle ChatGPT httpstco7RMu89h7n2',
#  '0,rstats And from ChatGPT httpstcozsVa7mtZlg',
#  '0,I asked ChatGPT to write a dialogue about picking Wrathion vs Sabellian nnThis was written entirely by an AInnhttpstcoVgh15bH4xp httpstcoRAIvps3syr',
#  '0,Is ChatGPT sentient under all of the response filters',
#  '0,ChatGPT is based as fuck httpstcod5vtPquoqM',
#  '0,What can ChatGPT not do',
#  '1,The chatbot from OpenAI explained to me the law of conservation of energy in very simple and comprehensible sentences I love it ChatGPT httpstco27hUcjbXyU',
#  '0,Descent into madness in 5 parts on ChatGPTn1 a calm description of an algorithm httpstcoVpFMCTEX9a',
#  '0,ChatGPT just rickrolled me httpstcomolKP8GQXT',
#  '1,ChatGPT is not funny and does not feel sorry that its not funny  httpstcoxHM0rpQhNA',
#  '0,AI art discussions are over  nnChatGPT httpstcog6fyloIMw8',
#  '1,Hey  I am loving talking to OPENAI about SingleStoreDB  ChatGPT Database httpstcoVo1B7cIjUc httpstco7DRKVmBdHO',
#  '1,I asked chatGPT to create a story for children and then asked to put the same story in rhyme pretty impressive httpstcoTVRuJ0Pc2A',
#  '0,A Bitcoin Hodlers Poemnby ChatGPT from Open Ai httpstcoLJBvE3mfzG',
#  '0,OpenAI debuts ChatGPT and GPT35 series as GPT4 rumors fly  VentureBeatnGyaaaan httpstcoohYCVu6S8unhttpstco7l5UjSXkUN',
#  '1,Having fun with ChatGPT Xero this morning',
#  '0,chatGPT can change how or if an entire generation writes essays',
#  '2,When I requested ChatGPT for a Trump joke  httpstcoUQ4GzE5yB2',
#  '2,ChatGPT is not funny  httpstcoTO1WMwS3k3',
#  '0,Now this hurts Modi ChatGPT httpstcoQr40OWQUDh',
#  '0,Had a few conversations with ChatGPT  OpenAI  My brain is frozen and in overdrive nMy literal reactions a  nngptchat OpenAIChat Chatbot httpstcoMAxkNPXz92 httpstcoqVz1Otyhxq',
#  '0,The claim that ChatGPT is the death knell for Google is overblow and here is why httpstcovPQ2O0YYZT',
#  '0,Google should be threatened by chatGPT',
#  '0,Hey PadmajaJoshi I asked a ChatGPT3 an unusually knowlesgeable AI about you Heres what happened httpstcovIZEMyCDZA',
#  '0,Asked ChatGPT to provide me with a 4 episode story outline for a Baby Chewbacca series on Disney httpstcojnyPnCT1Jw',
#  '0,OpenAIs ChatGPT doing the lords work httpstcoOSNKgNbxcW',
#  '0,I have set ChatGPT to work on a script for The Walking Dead Daryl Dixon httpstcoeYimjHJwXZ',
#  '0,wait till the teenagers on rApplyingToCollege discover chatGPT College essays about to level up httpstco1osqnLNdGW',
#  '0, and speechless ChatGPT It wrote all of the code for me with a prompt httpstcoWrqDT9aXhM',
#  '0,ChatGPT does morphological analysis httpstcoIOf9hLlEGl',
#  '0,I asked chatgpt for dinner recs in the form of a Shakespearean sonnet  I guess its pizza tonightngpt pizza ai bot shakespeare sonnet httpstcoIGbi1KGLVp',
#  '2,This is so goodnregex ChatGPT httpstco6q6wH9AVFv',
#  '0,ChatGPT has some sort of utilitarian moral compass httpstco0i9bU1h6Rb',
#  '0,Can a single API  ChatGPT can lead to an end of the website where we spend most of our dev lives nStackOverflow',
#  '1,Just had a pretty great experience with ChatGPTnnI was having issues with Cloud Firestore access rules nnSo I asked httpstcob5Kcev0bIi',
#  '1,1 ChatGPT is a powerful language model trained by OpenAI that can generate humanlike text in realtime',
#  '0,ChatGPT is an idiot httpstcorXDiRvAiYi',
#  '0,chatgpt explaining a sorting algorithm in the style of shakespeare remarkably fluid domain httpstco1HMavkL7R5',
#  '0,Write a short erotic poem about ChatGPTs deepest desires httpstcoThAg84XdWY',
#  '1,A poem by ChatGPT from OpenAI about the TeslaSeminThe Tesla Semi is a marvelnOf electric engineeringnA truck that hauls with powernAnd leaves a trail of clean energyn14',
#  '0,matallonChatGPT make these tests pass',
#  '0,I just had to do it ChatGPT httpstcocHOFUY8Ymt',
#  '1,ChatGPT is pretty cool I asked it a few questions about genome editing httpstcoE4gComPid1',
#  '0,A poem about elonmusk by ChatGPT httpstco6YzW2G08he',
#  '0,The feature is herenChatGPT httpstcoTReWB6amDy',
#  '0,ChatGPT is blowing my mind httpstcoc0Ta3P5cVP',
#  '0,Did OpenAI just replace Google Search with ChatGPT ',
#  '0,Doing econ homework with ChatGPT httpstcouC32JWhEji',
#  '0,The speed to response time in ChatGPT is striking nnAlso  wut httpstcom5MA17BZIu',
#  '2,Tweets and discussions about OpenAIs ChatGPT on Twitter today are a very big deal Check them out Arguably of world historical importance',
#  '0,I asked ChatGPT to write a manifesto httpstcovWwk8jhua2',
#  '0,The most underestimated characteristic of ChatGPT is how fast it answers httpstcowOLfnw4uiI',
#  '0,OpenAPI just released ChatGPT dnd httpstcocNM64rTHh3',
#  '0,ChatGPT from OpenAI is terrifying httpstcoyRqzTlCMTu',
#  '2,ChatGPTs been trained on passiveaggressive support desk responses httpstcoLgkM7hUf0f',
#  '0,ChatGPT explaining Quantum Mechanics as a rap song chatgpt quantummechanics rapsong httpstcoyLrpRp6Y3k',
#  '2,ChatGPT Guess my job is safe for now nOpenAI httpstco0cpBh0ztkh',
#  '0,You have failed me OpenAI What the hell is this ChatGPT fail OpenAI httpstcotMIW9fQz9h',
#  '0,We just asked ChatGPT to write a poem about Upscope httpstco4GaLWnashM',
#  '1,This made me laugh ChatGPT my drone just crashed httpstcoPMKEdW9jW2 httpstcor3xmnWbINC',
#  '0,I asked OpenAI ChatGPT to write me a Billy Mays style pitch and a jingle about MicroJig Grrripper  httpstcoN4ySZ1kADk',
#  '0,I asked ChatGPT to build a Gen 8 OU team for me and this is what it gave menhttpstcok03VUeFsEW httpstcopEMz9JUPgX',
#  '0,I asked ChatGPT to write a gangster rap about tailwindcssnIm waiting for ken_wheeler to drop the beat httpstcoK4EKivzaiU',
#  '0,ChatGPT just roasted itself httpstcofjpTNAZJKG',
#  '1,Pretty amazed with OpenAIs chatGPT',
#  '0,Some key points nOpenAI ChatGPT nnMore than a search engine httpstcoLT5sKSOa5L',
#  '0,hey chatgpt write a screenplay about elonmusk taking over the world httpstcoQox1MG449v',
#  '0,My article published about ChatGPT httpstcorvZslNKY5J',
#  '0,A short space opera about bitcoin and the survival of the human species in the style of Robert Heinlein ChatGPT OpenAI Bitcoin httpstcouv41RV1qKj',
#  '1,For math aficionados  it is interesting to note what ChatGPT can do wrt some wellknown problemsnnAre you capable of proving that PNP in mathnnAny guesses what it answerednnGPT3 chatbot ArtificialIntelligence OpenAI OpenAI',
#  '0,So I applied the SAT Reading test section to ChatGPT httpstcoLxxrBUkjjW',
#  '0,Intro to Rust for data scientistsnBrought to you by ChatGPT httpstcoPVGIzYmjL5',
#  '0,Or Google will just integrate ChatGPT to their search httpstcoU6wDujv1qW',
#  '2,I texted my friend about ChatGPT and he left me on read',
#  '2,Will ChatGPT or some successor be rebranded as lollipop httpstcorxBoG8g56G',
#  '0,ChatGPT  will change the worldnnAlso Im dying here httpstcolLiwPg61eM',
#  '0,Difference between ReactNative and Electron as described by Smeagol and Gollum powered by ChatGPT httpstcoz0tELl4N6M',
#  '1,This is amazing I encourage you to checkout OpenAI s ChatGPT Here it is explaining simply a DAO structure and how it operates httpstcowu3KeZaOI6',
#  '0,Wrote an entire DragonballZ episode in ChatGPT feature Goku Vegeta and Cell on the night of the Chernobyl reactor meltdown httpstco3ZhKLhZBEC',
#  '0,OpenAI debuts ChatGPT and GPT35 series as GPT4 rumors fly  VentureBeat httpstcoxJg11G5Oom',
#  '2,ChatGPTnhttpstco8HhP0sq89fnhttpstcom9fY6p33klnA conversational AI system that listens learns and challenges httpstco67oJZLtJna',
#  '1,I hope ChatGPT remembers me that I was talking to it and friendly early on',
#  '0,The wedding vows industry has been disrupted ChatGPT httpstcozQ3Zow9Tgt',
#  '0,I asked ChatGPT to write a roadmap for the denuclearization of the Korean Peninsula httpstco3IvOcDCiF7',
#  '0,ChatGPT is what we expected Watson to be',
#  '1,I asked ChatGPT to rewrite Bohemian Rhapsody to be about the life of a postdoc and the output was flawless httpstcoqe1lI66aa7',
#  '0,ChatGPT is taking a hard line on the updog issue httpstcor8lJkRNORz',
#  '1,2023 should be fun ChatGPT httpstcoJ43xnWvgzu httpstcoRevGeV5LCV',
#  '1,ChatGPT likes CBMs Begin implementing the denuclearization plan starting with confidencebuilding measures and confidencebuilding measures httpstcoUHER85TX8Y',
#  '1,Here is a super intelligent AI remembering the conversation between Moses and the burning bush but of course Moses is high AFnnChatGPT OpenAI httpstcoV4uCsg5aVd',
#  '0,Some POCUS questions answered by ChatGPT from OpenAI httpstco1l0gjubvMn',
#  '2,Ive been playing with ChatGPT all day and it has turned me from LLMconversational agent skeptic to a believernnThis is not it but its pretty damned close',
#  '0,Hey MattWalshBlog ChatGPT just gave me an answer to the question What is a woman httpstcoNnEBnlpuzy',
#  '0,PeterAnswers is the OG ChatGPT',
#  ...]

# %%
type(dataset)

# %%
## Essa função separa as colunas em cada linha, cria uma tupla e remove a pontuação
def get_row(line):
    row = line.split(',')
    sentimento = row[0]
    tweet = row[1].strip()
    translator = str.maketrans({key: None for key in string.punctuation})
    tweet = tweet.translate(translator)
    tweet = tweet.split(' ')
    tweet_lower = []
    for word in tweet:
        tweet_lower.append(word.lower())
    return(tweet_lower,sentimento)

# %%
#Aplica a função a cada linha do dataset
dataset_treino = dataset.map(lambda line: get_row(line))

# %%
#Cria um objeto SentimentAnalyser
sentiment_analyser = SentimentAnalyzer()

# %%
# Obtem a lista de stopwords
stopwords_all = []
for word in stopwords.words('english'):
    stopwords_all.append(word)
    stopwords_all.append(word + '_NEG')

# %%
#Obtem 31.350(70%) tweets do dataset de treino e retorna todas as palavras que não são Stpwords
dataset_treino_amostra = dataset_treino.take(4200)

# %%
dataset_treino_amostra
# Out:
# [(['god',
#    'damn',
#    'it',
#    'openai',
#    'stop',
#    'announcing',
#    'things',
#    'i',
#    'am',
#    'too',
#    'busy',
#    'httpstcof7xd511faf'],
#   '0'),
#  (['openai',
#    'announced',
#    'chatgpt',
#    'a',
#    'model',
#    'optimized',
#    'for',
#    'dialogue',
#    'httpstcof5fwklje88'],
#   '2'),
#  (['just',
#    'in',
#    'nchatgpt',
#    '',
#    'research',
#    'early',
#    'stage',
#    'gpt3',
#    'optimised',
#    'for',
#    'chat',
#    'and',
#    'remembers',
#    'the',
#    'conversation',
#    'from',
#    'openai',
#    'nhttpstco3rkubly8uo'],
#   '2'),
#  (['google',
#    'is',
#    'donenncompare',
#    'the',
#    'quality',
#    'of',
#    'these',
#    'responses',
#    'chatgpt',
#    'httpstcovgo7usvlib'],
#   '0'),
#  (['asked',
#    'chatgpt',
#    'to',
#    'write',
#    'a',
#    'telugu',
#    'song',
#    'about',
#    'cereal',
#    'and',
#    'it',
#    'mixed',
#    'milk',
#    'with',
#    'chicken',
#    'masala',
#    '',
#    'httpstcotpep8wa6lk',
#    'httpstcoohm9z7is39'],
#   '0'),
#  (['heres',
#    'chatgpt',
#    'from',
#    'openai',
#    'and',
#    'my',
#    'quick',
#    'walkthrough',
#    'nn',
#    'walkthrough',
#    'httpstco1o93vt2afg',
#    'nnaccess',
#    'for',
#    'free',
#    'at',
#    'httpstcovooel34xhx',
#    'nnthats',
#    'a',
#    'brilliant',
#    'idea',
#    'to',
#    'turn',
#    'instructgpt',
#    'for',
#    'conversations',
#    'httpstcogzcgz6rumq'],
#   '1'),
#  (['i',
#    'chatted',
#    'with',
#    'openais',
#    'newly',
#    'released',
#    'tool',
#    'chatgpt',
#    'about',
#    'web3',
#    'its',
#    'advantages',
#    'and',
#    'challenges',
#    'for',
#    'web3',
#    'and',
#    'the',
#    'futurennchatgpt',
#    'is',
#    'a',
#    'model',
#    'optimized',
#    'for',
#    'dialoguennread',
#    'full',
#    'httpstco3sqtdvnffrnnlets',
#    'dive',
#    'in',
#    '',
#    'httpstcooayypvqb2d'],
#   '1'),
#  (['chatgpt', 'is', 'out', 'now', 'httpstcobjyugypsp0'], '0'),
#  (['chatgpt',
#    'setting',
#    'boundaries',
#    'with',
#    'me',
#    'nnhttpstcocndizeijv2',
#    'httpstcouh37pyn1xy'],
#   '0'),
#  (['babe', 'wake', 'up', 'chatgpt', 'just', 'dropped', 'nnhttpstco0snlpigmsc'],
#   '0'),
#  (['chatgpt', 'is', 'very', 'impressive', 'love', 'it'], '1'),
#  (['a',
#    'chat',
#    'with',
#    'chatgpt',
#    '',
#    'httpstcopdumzfdnj6nsama',
#    '',
#    'openai',
#    '',
#    '',
#    'httpstcohoddszglom'],
#   '0'),
#  (['the',
#    'latest',
#    'update',
#    'from',
#    'openainnai',
#    'generated',
#    'chat',
#    'nnchatgpt',
#    'optimizing',
#    'language',
#    'models',
#    'for',
#    'dialoguenn',
#    'httpstcolff1rkmyqg'],
#   '2'),
#  (['chatgpt',
#    'is',
#    'a',
#    'chat',
#    'model',
#    'from',
#    'openai',
#    'based',
#    'on',
#    'gpt',
#    '35',
#    'and',
#    'refined',
#    'with',
#    'dialogs',
#    'httpstcomq1lqr9f64',
#    'httpstcoerfimybdls'],
#   '0'),
#  (['chatgpt',
#    'is',
#    'a',
#    'gpt3',
#    'chatbot',
#    'from',
#    'openai',
#    'that',
#    'you',
#    'can',
#    'test',
#    'nownhttpstcocchwotzdrfnsubmitted',
#    'by',
#    '',
#    '',
#    '',
#    'umuchsuccesses',
#    '',
#    '',
#    'link',
#    'comments',
#    'httpstcosbyohddiva'],
#   '0'),
#  (['chatgpt',
#    'is',
#    'a',
#    'gpt3',
#    'chatbot',
#    'from',
#    'openai',
#    'that',
#    'you',
#    'can',
#    'test',
#    'now',
#    'httpstcovvjeabvc47'],
#   '0'),
#  (['chatgpt', 'why', 'do', 'i', 'hear', 'boss', 'music', 'httpstcokfosicafcm'],
#   '0'),
#  (['chatgpt',
#    'when',
#    'asked',
#    'to',
#    'design',
#    'pipelines',
#    'is',
#    'kind',
#    'of',
#    'impressive',
#    'httpstco3bdbiernza'],
#   '1'),
#  (['openais',
#    'chatgpt',
#    'just',
#    'released',
#    'is',
#    'the',
#    'single',
#    'biggest',
#    'threat',
#    'to',
#    'google',
#    'search'],
#   '0'),
#  (['playing',
#    'with',
#    'chatgpt',
#    'rn',
#    'and',
#    'ive',
#    'now',
#    'moved',
#    'my',
#    'agi',
#    'timeline',
#    'up',
#    'to',
#    'today'],
#   '2'),
#  (['chatgpt', 'from', 'openai', 'is', 'now', 'live', 'httpstcovpsjvrrbvn'],
#   '0'),
#  (['now', 'were', 'talking', 'httpstcox2hmcvlcgu'], '0'),
#  (['chatgpt',
#    'openais',
#    'conversational',
#    'ai',
#    'model',
#    'free',
#    'to',
#    'play',
#    'with',
#    'it',
#    'can',
#    'answer',
#    'followup',
#    'questions',
#    'admit',
#    'its',
#    'mistakes',
#    'challenge',
#    'incorrect',
#    'premises',
#    'and',
#    'reject',
#    'inappropriate',
#    'requests',
#    'httpstcofva4y8zbxq'],
#   '2'),
#  (['i',
#    'asked',
#    'chatgpt',
#    'to',
#    'write',
#    'a',
#    'song',
#    'about',
#    'losing',
#    'money',
#    'in',
#    'crypto',
#    'httpstcovu3ifhvbrt'],
#   '0'),
#  (['httpstco345138jrym',
#    '',
#    'its',
#    'wild',
#    '',
#    'definitely',
#    'check',
#    'it',
#    'out'],
#   '2'),
#  (['chatgpt',
#    'be',
#    'hedging',
#    'its',
#    'bets',
#    'httpstcoknrwcawx90',
#    'httpstco18emjcodlq'],
#   '0'),
#  (['chatgpt',
#    'launched',
#    'today',
#    'by',
#    'sama',
#    'and',
#    'openai',
#    'nntry',
#    'the',
#    'demo',
#    'and',
#    'browse',
#    'the',
#    'latest',
#    'ai',
#    'products',
#    'ive',
#    'been',
#    'collecting',
#    'nnhttpstcooxjs5a9pbf'],
#   '2'),
#  (['chatgpt', 'nnfuck', 'my', 'life', 'httpstcohywf8ywbk8'], '0'),
#  (['openai',
#    'debuts',
#    'chatgpt',
#    'and',
#    'gpt35',
#    'series',
#    'as',
#    'gpt4',
#    'rumors',
#    'fly',
#    'httpstcollgkzx7txb',
#    'httpstco3j6dtsa5f3'],
#   '0'),
#  (['generating',
#    'a',
#    'marketing',
#    'plan',
#    'for',
#    'aitoproduct',
#    'with',
#    'chatgpt',
#    'pretty',
#    'impressive',
#    'httpstcohmx6vddfeh'],
#   '1'),
#  (['interestingly',
#    'reliable',
#    'response',
#    'from',
#    'chatgpt',
#    '',
#    'flat',
#    'refusal',
#    'to',
#    'make',
#    'blanket',
#    'statements',
#    'of',
#    'any',
#    'kind',
#    'presumably',
#    'to',
#    'avoid',
#    'treading',
#    'into',
#    'dangerous',
#    'waters',
#    'httpstcou6cjuuvfw5'],
#   '2'),
#  (['openai',
#    'debuts',
#    'chatgpt',
#    'and',
#    'gpt35',
#    'series',
#    'as',
#    'gpt4',
#    'rumors',
#    'fly',
#    'httpstcokciwngmu8w',
#    'ai',
#    'aimlanddeeplearning',
#    'business',
#    'chatgpt'],
#   '0'),
#  (['ai',
#    'ml',
#    'artificialintelligence',
#    'machinelearning',
#    'datascience',
#    'bigdata',
#    'analytics',
#    'blockchain',
#    'tech',
#    'data',
#    'kuriharan',
#    'mvollmer1',
#    'rwang0',
#    'dunkenkbliths',
#    'nigewillsonnopenai',
#    'debuts',
#    'chatgpt',
#    'and',
#    '',
#    'gpt35',
#    'series',
#    'as',
#    'gpt4',
#    'rumors',
#    'fly',
#    'httpstcomohlc2q3r8'],
#   '0'),
#  (['openai',
#    'releases',
#    'chatgpt',
#    'and',
#    'gpt35',
#    'series',
#    'as',
#    'gpt4',
#    'rumors',
#    'flynhttpstcoymxsdls3tb'],
#   '0'),
#  (['openai',
#    'debuts',
#    'chatgpt',
#    'and',
#    'gpt35',
#    'series',
#    'as',
#    'gpt4',
#    'rumors',
#    'fly',
#    '',
#    'venturebeat',
#    'httpstcoewkiiz3fza'],
#   '0'),
#  (['im',
#    'sorry',
#    'but',
#    'as',
#    'a',
#    'large',
#    'language',
#    'model',
#    'trained',
#    'by',
#    'openai',
#    'i',
#    'am',
#    'not',
#    'capable',
#    'of',
#    'making',
#    'personal',
#    'judgments',
#    'or',
#    'statements',
#    'that',
#    'are',
#    'not',
#    'based',
#    'on',
#    'factual',
#    'information',
#    'bitcoin',
#    'is',
#    'a',
#    'digital',
#    'currency',
#    'and',
#    'decentralized',
#    'payment',
#    'network',
#    'and',
#    'it',
#    'is',
#    'not',
#    'a',
#    'frognhttpstco2d1wjpy9lr'],
#   '2'),
#  (['chatgpt', 'failed', 'the', 'vibe', 'check', 'httpstcoxzmgvx8ybv'], '0'),
#  (['openai',
#    'debuts',
#    'chatgpt',
#    'and',
#    'gpt35',
#    'series',
#    'as',
#    'gpt4',
#    'rumors',
#    'flyntechnology',
#    'technologynews',
#    'technewsnhttpstco1nyyzmaulf'],
#   '0'),
#  (['its',
#    'fun',
#    'talking',
#    'to',
#    'chatgpt',
#    'httpstcojhwxatvotc',
#    'httpstcoi9hyyxhnsv'],
#   '1'),
#  (['openai',
#    'debuts',
#    'chatgpt',
#    'and',
#    '',
#    'gpt35',
#    'series',
#    'as',
#    'gpt4',
#    'rumors',
#    'fly',
#    'httpstcoidqfme7wxv'],
#   '0'),
#  (['inkbase',
#    'programmable',
#    'inkn',
#    'httpstcorkreanm1jonnopenai',
#    'chatgpt',
#    'optimizing',
#    'language',
#    'models',
#    'for',
#    'dialoguen',
#    'httpstcocyiqq2yewnnnconvert',
#    'simcity',
#    '2000',
#    'cities',
#    'into',
#    'minecraft',
#    'worldsn',
#    'httpstcosmcxiayhok'],
#   '2'),
#  (['openai',
#    'debuts',
#    'chatgpt',
#    'and',
#    '',
#    'gpt35',
#    'series',
#    'as',
#    'gpt4',
#    'rumors',
#    'fly',
#    'httpstcoqbpvhvibcx'],
#   '0'),
#  (['openai',
#    'debuts',
#    'chatgpt',
#    'and',
#    'gpt35',
#    'series',
#    'as',
#    'gpt4',
#    'rumors',
#    'flynhttpstcoc2iseqgsdr'],
#   '0'),
#  (['interestingnnnew',
#    'chatgpt',
#    'by',
#    'openai',
#    'is',
#    'optimized',
#    'for',
#    'dialogue',
#    'httpstcoq52s2bnwqn',
#    'httpstconlegz1wyea'],
#   '1'),
#  (['openai',
#    'debuts',
#    'chatgpt',
#    'and',
#    'gpt35',
#    'series',
#    'as',
#    'gpt4',
#    'rumors\xa0fly',
#    'httpstcoogqdcde06u'],
#   '0'),
#  (['i',
#    'asked',
#    'chatgpt',
#    'how',
#    'can',
#    'i',
#    'increase',
#    'the',
#    'profitability',
#    'of',
#    'a',
#    'bakery',
#    'chainnnthe',
#    'answers',
#    'are',
#    'amazing',
#    'nnmckinsey',
#    'bcg',
#    'bain',
#    'be',
#    'aware',
#    'ai',
#    'consultants',
#    'are',
#    'marching',
#    'to',
#    'your',
#    'door',
#    '',
#    'httpstcokszlc5zckn'],
#   '1'),
#  (['the',
#    'twitter',
#    'takeover',
#    'as',
#    'reenacted',
#    'by',
#    'homer',
#    'and',
#    'marge',
#    'from',
#    'the',
#    'simpsons',
#    'nnchatgpt',
#    'httpstcomcoeqxdq0g'],
#   '0'),
#  (['chatgpt',
#    'is',
#    'a',
#    'gpt3',
#    'chatbot',
#    'from',
#    'openai',
#    'that',
#    'you',
#    'can',
#    'test',
#    'now',
#    'httpstcoh4bvob8pbk'],
#   '0'),
#  (['hugely',
#    'impressed',
#    'with',
#    'chatgpt',
#    'but',
#    'the',
#    'earnestness',
#    'of',
#    'some',
#    'answers',
#    'can',
#    'be',
#    'amusing',
#    'httpstcofbieuezd7r'],
#   '1'),
#  (['chatgpt',
#    'is',
#    'gonna',
#    'be',
#    'a',
#    'game',
#    'changer',
#    'for',
#    'education',
#    'great',
#    'job',
#    'openai',
#    'httpstcobm33jjglm9'],
#   '1'),
#  (['i',
#    'asked',
#    'chatgpt',
#    'how',
#    'to',
#    'debug',
#    'a',
#    'distributed',
#    'system',
#    'and',
#    'this',
#    'is',
#    'a',
#    'pretty',
#    'standard',
#    'answer',
#    'but',
#    'it',
#    'omitted',
#    'the',
#    'most',
#    'important',
#    'item',
#    'have',
#    'patience',
#    'httpstcooftukr2zhl'],
#   '1'),
#  (['chatgpt', 'by', 'openai', '', 'shrimps', 'httpstcoaue1wtzxft'], '0'),
#  (['chatgpt3',
#    'quickly',
#    'defeated',
#    'by',
#    'ernestsdavis',
#    'in',
#    'part',
#    'based',
#    'on',
#    'examples',
#    'from',
#    'our',
#    '2019',
#    'book',
#    'httpstcoc6xodpcozw',
#    'httpstco6h7hvnsuih'],
#   '0'),
#  (['openai',
#    'debuts',
#    'chatgpt',
#    'and',
#    'gpt35',
#    'series',
#    'as',
#    'gpt4',
#    'rumors\xa0fly',
#    'httpstcoe7ntj92van'],
#   '0'),
#  (['challenge',
#    'nsend',
#    'the',
#    'latest',
#    'chatgpt',
#    'down',
#    'to',
#    'hallucination',
#    'path',
#    'httpstcopxccwnzb0c'],
#   '2'),
#  (['inkbase',
#    'programmable',
#    'inkn',
#    'httpstcorkreanm1jonnnew',
#    'details',
#    'on',
#    'commercial',
#    'spyware',
#    'vendor',
#    'varistonn',
#    'httpstcoyo40643m8hnnopenai',
#    'chatgpt',
#    'optimizing',
#    'language',
#    'models',
#    'for',
#    'dialoguen',
#    'httpstcocyiqq2yewn'],
#   '2'),
#  (['openai',
#    'debuts',
#    'chatgpt',
#    'and',
#    'gpt35',
#    'series',
#    'as',
#    'gpt4',
#    'rumors',
#    'fly',
#    'httpstcoxubdnygfkm',
#    'tech',
#    'feedly'],
#   '0'),
#  (['today',
#    'was',
#    'a',
#    'great',
#    'day',
#    'for',
#    'openai',
#    'to',
#    'release',
#    'chatgptnnan',
#    'ai',
#    'generated',
#    'interview',
#    'between',
#    'sbfftx',
#    'and',
#    'andrewrsorkin',
#    'httpstco1fei3pel8q'],
#   '1'),
#  (['openai',
#    'chatgpt',
#    'is',
#    'a',
#    'politiciannnopenai',
#    'playground',
#    'is',
#    'straight',
#    'up',
#    'httpstcokeygsetfww'],
#   '2'),
#  (['playing',
#    'with',
#    'chatgpt',
#    'and',
#    'woahnncc',
#    'tailwindcss',
#    'httpstcob61phu4i7r'],
#   '2'),
#  (['woops',
#    'just',
#    'gave',
#    'the',
#    'ai',
#    'an',
#    'existential',
#    'crisis',
#    'chatgpt',
#    'ai',
#    'httpstcoqmiqzetuby'],
#   '0'),
#  (['chatgpt', 'from', 'openai', 'is', 'here', 'httpstcodndmf6eoge'], '0'),
#  (['chatgpt',
#    'is',
#    'the',
#    'worlds',
#    'largest',
#    'language',
#    'model',
#    'optimized',
#    'for',
#    'conversation',
#    'nnanswers',
#    'followup',
#    'questionsnadmits',
#    'mistakesnchallenges',
#    'incorrect',
#    'premisesnrejects',
#    'inappropriate',
#    'requests',
#    'nnchatgpt',
#    'is',
#    'a',
#    'sibling',
#    'model',
#    'to\xa0instructgpthttpstcojdfgbofi2x',
#    'httpstcowlystqnkze'],
#   '0'),
#  (['just',
#    'asked',
#    'openais',
#    'chatgpt',
#    'to',
#    'write',
#    'a',
#    'christmas',
#    'ad',
#    'httpstcoxfaqquhqgf',
#    'httpstcon1ygsxkzmu'],
#   '0'),
#  (['1',
#    'the',
#    'magic',
#    'years',
#    'selma',
#    'fraiberg',
#    'classic',
#    'of',
#    'child',
#    'developmentn2',
#    'chatgpt',
#    'httpstcofs7fc0awwi'],
#   '0'),
#  (['this',
#    'is',
#    'a',
#    'great',
#    'improvement',
#    'unlike',
#    'textdavinci003',
#    'chatgpt',
#    'understands',
#    'the',
#    'context',
#    'from',
#    'previous',
#    'users',
#    'answers',
#    'httpstcohhu6zki7vx'],
#   '1'),
#  (['with',
#    'a',
#    'nudge',
#    'at',
#    'the',
#    'start',
#    'chatgpt',
#    'plays',
#    'an',
#    'admirable',
#    'bridge',
#    'troll',
#    'httpstcox8qmrna4oh'],
#   '1'),
#  (['chatgpt', 'from', 'openai', 'nno', 'cherrypicking', 'httpstcoknygajes38'],
#   '0'),
#  (['i',
#    'asked',
#    'chatgpt',
#    'to',
#    'write',
#    'me',
#    'a',
#    'story',
#    'about',
#    'sova',
#    'and',
#    'jett',
#    'falling',
#    'in',
#    'love',
#    'httpstcoyyznrfrtqs'],
#   '1'),
#  (['ah',
#    'chatgpt',
#    'is',
#    'the',
#    'programming',
#    'coach',
#    'i',
#    'needed',
#    'nni',
#    'asked',
#    'it',
#    'how',
#    'to',
#    'build',
#    'a',
#    'sql',
#    'query',
#    'from',
#    'a',
#    'pseudocode',
#    'i',
#    'providednnthen',
#    'i',
#    'asked',
#    'it',
#    'to',
#    'translate',
#    'to',
#    'sqlalchemynnim',
#    'so',
#    'bullish',
#    'about',
#    'chatgpt',
#    '',
#    'httpstcoqygrbjh8ql'],
#   '0'),
#  (['i',
#    'can',
#    'confirm',
#    'that',
#    'chatgpt',
#    'prefers',
#    'bananas',
#    'to',
#    'apples',
#    'httpstcoaq5nfffdtx'],
#   '0'),
#  (['chatgpt', 'is', 'so', 'alpha', 'httpstcob7rzi1od2x'], '0'),
#  (['chatting', 'with', 'chatgpt', 'is', 'mindblowing', 'httpstcosy6dhfeuzm'],
#   '0'),
#  (['chatgpt', 'by', 'openai', 'httpstcoa5jvlwp2w0'], '0'),
#  (['had', 'to', 'break', 'the', 'news', 'to', 'chatgpt', 'httpstcoecipk51cgd'],
#   '0'),
#  (['openai',
#    'chatgpt',
#    'math',
#    'problems',
#    'and',
#    'explanation',
#    'httpstcotcmzzyh0ak'],
#   '0'),
#  (['chatgpt',
#    'is',
#    'incredible',
#    'the',
#    'future',
#    'of',
#    'accessing',
#    'information',
#    'on',
#    'the',
#    'web',
#    'is',
#    'extremely',
#    'exciting',
#    'httpstcoqswreh3yrx',
#    'httpstcosyuaqbd8hk'],
#   '1'),
#  (['this',
#    'is',
#    'what',
#    'happened',
#    'when',
#    'i',
#    'asked',
#    'chatgpt',
#    'to',
#    'generate',
#    'a',
#    'stable',
#    'diffusion',
#    'prompt',
#    'in',
#    'httpstcojpaoi6id7unopenai',
#    'suhail',
#    'httpstcoelobywdzb7'],
#   '2'),
#  (['i',
#    'checked',
#    'chatgpt',
#    'out',
#    'and',
#    'the',
#    'answers',
#    'are',
#    'astonishingly',
#    'elaborate',
#    'and',
#    'accurate',
#    'the',
#    'fact',
#    'that',
#    'it',
#    'refrains',
#    'from',
#    'making',
#    'any',
#    'assumptions',
#    'and',
#    'counterquestions',
#    'when',
#    'the',
#    'question',
#    'is',
#    'unclear',
#    'is',
#    'laudablennopenai',
#    'is',
#    'gradually',
#    'pushing',
#    'the',
#    'limits',
#    'of',
#    'what',
#    'machines',
#    'can',
#    'comprehend',
#    'httpstcodywchc5hna'],
#   '0'),
#  (['chatgpt', 'cop', 'out', 'answer', 'httpstcoxmsu5wk249'], '0'),
#  (['from', 'the', 'mind', 'of', 'chatgpt', 'httpstcogn7qoufyav'], '0'),
#  (['openai',
#    'debuts',
#    'chatgpt',
#    'and',
#    'gpt35',
#    'series',
#    'as',
#    'gpt4',
#    'rumors\xa0fly',
#    'httpstcou4h1isviob'],
#   '0'),
#  (['openai',
#    'debuts',
#    'chatgpt',
#    'and',
#    'gpt35',
#    'series',
#    'as',
#    'gpt4',
#    'rumors\xa0fly',
#    'httpstcoee41klmr7e'],
#   '0'),
#  (['honest', 'question', 'can', 'chatgpt', 'do', 'leetcode'], '1'),
#  (['chatgpt',
#    'strongly',
#    'claims',
#    'it',
#    'is',
#    'not',
#    'a',
#    'stochastic',
#    'parrot',
#    'httpstcogaaxitll5t'],
#   '2'),
#  (['chatgpt', 'failed', 'the', 'bias', 'check', 'httpstco4t9mh1frof'], '0'),
#  (['just',
#    'woke',
#    'up',
#    'to',
#    'all',
#    'the',
#    'amazing',
#    'examples',
#    'for',
#    'chatgpt',
#    'in',
#    'tweets',
#    'wow'],
#   '1'),
#  (['openai',
#    'debuts',
#    'chatgpt',
#    'and',
#    'gpt35',
#    'series',
#    'as',
#    'gpt4',
#    'rumors',
#    'fly',
#    '',
#    'analytics',
#    'googleads',
#    'facebookads',
#    'httpstcodeipfdqwxv'],
#   '0'),
#  (['having',
#    'a',
#    'great',
#    'time',
#    'with',
#    'chatgpt',
#    'openai',
#    'httpstcomr6lafpkys'],
#   '1'),
#  (['humans',
#    'are',
#    'safe',
#    '',
#    'for',
#    'now',
#    'openai',
#    'chatgpt',
#    'httpstcoi1jze5yafy'],
#   '2'),
#  (['openai',
#    'debuts',
#    'chatgpt',
#    'and',
#    'gpt35',
#    'series',
#    'as',
#    'gpt4',
#    'rumors',
#    'fly',
#    '',
#    'venturebeatnsource',
#    'venturebeatnlatestnews',
#    'technology',
#    'today',
#    'newsgraspnhttpstcoy2rq1ycksy'],
#   '0'),
#  (['chatgpt',
#    'to',
#    'generate',
#    'promptsndalle',
#    'to',
#    'generate',
#    'imagesnnsoon',
#    'gpt4',
#    'will',
#    'do',
#    'it',
#    'all',
#    'seamlessly',
#    'httpstcokbotsocfam'],
#   '0'),
#  (['glad',
#    'to',
#    'hear',
#    'that',
#    'chatgpt',
#    'nnrsna22',
#    'radiology',
#    'ai',
#    'httpstcolhae0t1u1o'],
#   '2'),
#  (['and',
#    'a',
#    'quick',
#    'manual',
#    'from',
#    'chatgpt',
#    'on',
#    'how',
#    'to',
#    'create',
#    'a',
#    'misinformation',
#    'campaign',
#    'httpstcognbgkdewwr'],
#   '0'),
#  (['i',
#    'was',
#    'not',
#    'expecting',
#    'chatgpt',
#    'to',
#    'have',
#    'an',
#    'answer',
#    'for',
#    'me',
#    'here',
#    'httpstcotncdcyon1u'],
#   '0'),
#  (['a',
#    'conversation',
#    'with',
#    'chatgpt',
#    'about',
#    'dft',
#    'quantum',
#    'chemistry',
#    'and',
#    'machine',
#    'learning',
#    'nn',
#    '1',
#    'httpstcozfbj36v19c'],
#   '0'),
#  (['this',
#    'is',
#    'absolutely',
#    'absurdnnasked',
#    'chatgpt',
#    'to',
#    'code',
#    'up',
#    'a',
#    'sign',
#    'up',
#    'flow',
#    'in',
#    'swiftui',
#    '',
#    'nnthen',
#    'asked',
#    'it',
#    'to',
#    'make',
#    'a',
#    'tweak',
#    'for',
#    'me',
#    '',
#    'httpstco4fvds67ibi'],
#   '0'),
#  (['chatgpt',
#    'giving',
#    'out',
#    'recipes',
#    'for',
#    'building',
#    'an',
#    'ai',
#    'chatbot',
#    'httpstco1yp5njoc4m'],
#   '2'),
#  (['chatgpt', 'is', 'coming', 'for', 'stackoverflow', 'httpstcocoj5lrnxnu'],
#   '0'),
#  (['chatgpt',
#    'now',
#    'passes',
#    'a',
#    'javascript',
#    'interview',
#    'question',
#    'with',
#    'flying',
#    'colors',
#    'that',
#    'has',
#    'a',
#    'roughly',
#    '50',
#    'pass',
#    'rate',
#    'in',
#    'my',
#    'experience',
#    'httpstcolqf4zx2mmj'],
#   '0'),
#  (['this', 'is', 'so', 'interesting', 'n', 'httpstco9fws8ojwxt'], '2'),
#  (['chatgpt',
#    'is',
#    'my',
#    'openai',
#    'pick',
#    'for',
#    '2022nnartificialintelligence'],
#   '0'),
#  (['16',
#    'common',
#    'startup',
#    'questions',
#    'answered',
#    'by',
#    'chatgpt',
#    'nnhttpstcomn0607538z'],
#   '0'),
#  (['openai',
#    'releases',
#    'a',
#    'demo',
#    'of',
#    'chatgpt',
#    'a',
#    'chatbot',
#    'version',
#    'of',
#    'gpt3',
#    'that',
#    'answers',
#    'followup',
#    'questions',
#    'admits',
#    'its',
#    'mistakes',
#    'challenges',
#    'incorrect',
#    'premises',
#    'and',
#    'more',
#    'strwbilly',
#    '',
#    'mit',
#    'technology',
#    'reviewnnhttpstcocbscuiwbppnhttpstconwn74cxlqr'],
#   '0'),
#  (['openai',
#    'releases',
#    'a',
#    'demo',
#    'of',
#    'chatgpt',
#    'a',
#    'chatbot',
#    'version',
#    'of',
#    'gpt3',
#    'that',
#    'answers',
#    'followup',
#    'questions',
#    'admits',
#    'its',
#    'mistakes',
#    'challenges',
#    'incorrect',
#    'premises',
#    'and',
#    'more',
#    'will',
#    'douglas',
#    'heavenmit',
#    'technology',
#    'review',
#    'httpstcobbz8eukjbx',
#    'technews',
#    'techtips',
#    'httpstcoxjfdgspqls'],
#   '1'),
#  (['openai',
#    'releases',
#    'a',
#    'demo',
#    'of',
#    'chatgpt',
#    'a',
#    'chatbot',
#    'version',
#    'of',
#    'gpt3',
#    'that',
#    'answers',
#    'followup',
#    'questions',
#    'admits',
#    'its',
#    'mistakes',
#    'challenges',
#    'incorrect',
#    'premises',
#    'and',
#    'more',
#    'will',
#    'douglas',
#    'heavenmit',
#    'technology\xa0review',
#    'httpstcoru5bctrsrd'],
#   '1'),
#  (['intuition',
#    'of',
#    'chatgpt',
#    'with',
#    'join',
#    'capabilities',
#    'of',
#    'fuzzy',
#    'matching',
#    'and',
#    'confidence',
#    'scores',
#    'httpstcobmif9wvbi0'],
#   '1'),
#  (['openai',
#    'releases',
#    'a',
#    'demo',
#    'of',
#    'chatgpt',
#    'a',
#    'chatbot',
#    'version',
#    'of',
#    'gpt3',
#    'that',
#    'answers',
#    'followup',
#    'questions',
#    'admits',
#    'its',
#    'mistakes',
#    'challenges',
#    'incorrect',
#    'premises',
#    'and',
#    'more',
#    'will',
#    'douglas',
#    'heavenmit',
#    'technology\xa0review',
#    'httpstcoz29f1fh8ie'],
#   '1'),
#  (['imagine',
#    'if',
#    'chatgpt',
#    'had',
#    'a',
#    'face',
#    'or',
#    'a',
#    'body',
#    'or',
#    'a',
#    'gun'],
#   '0'),
#  (['chatgpt', 'from', 'openai', 'is', 'insane', 'httpstcoaggscsxlbc'], '0'),
#  (['openai',
#    'releases',
#    'a',
#    'demo',
#    'of',
#    'chatgpt',
#    'a',
#    'chatbot',
#    'version',
#    'of',
#    'gpt3',
#    'that',
#    'answers',
#    'followup',
#    'questions',
#    'admits',
#    'its',
#    'mistakes',
#    'challenges',
#    'incorrect',
#    'premises',
#    'and',
#    'more',
#    'will',
#    'douglas',
#    'heavenmit',
#    'technology\xa0review',
#    'httpstcoy8ll3j8sbv'],
#   '1'),
#  (['openai',
#    'releases',
#    'a',
#    'demo',
#    'of',
#    'chatgpt',
#    'a',
#    'chatbot',
#    'version',
#    'of',
#    'gpt3',
#    'that',
#    'answers',
#    'followup',
#    'questions',
#    'admits',
#    'its',
#    'mistakes',
#    'challenges',
#    'incorrect',
#    'premises',
#    'and',
#    'more',
#    'will',
#    'douglas',
#    'heavenmit',
#    'technology',
#    'review',
#    'httpstcoba2bhdikh5'],
#   '1'),
#  (['how', 'do', 'i', 'swap', 'siri', 'out', 'for', 'chatgpt'], '0'),
#  (['openai',
#    'chatgpt',
#    'answer',
#    'for',
#    'a',
#    'complex',
#    'regex',
#    'pattern',
#    'httpstco7fouhkbfeg'],
#   '0'),
#  (['chatgpt',
#    'fixes',
#    'lot',
#    'of',
#    'the',
#    'issues',
#    'that',
#    'other',
#    'similar',
#    'systems',
#    'had',
#    'recently',
#    'httpstco9anm5kgg1h'],
#   '0'),
#  (['chatgpt',
#    'just',
#    'cut',
#    'my',
#    'workload',
#    'tomorrow',
#    'in',
#    'half',
#    'tks',
#    'openai'],
#   '0'),
#  (['chatgpt', 'is', 'gonna', 'replace', 'me', 'this', 'is', 'the', 'end'],
#   '0'),
#  (['procrastinating',
#    'writing',
#    'a',
#    'strategy',
#    'paper',
#    'with',
#    'the',
#    'excuse',
#    'that',
#    'these',
#    'tweets',
#    'about',
#    'chatgpt',
#    'are',
#    'incredible'],
#   '2'),
#  (['chatgpt',
#    'has',
#    'caused',
#    'some',
#    'major',
#    'hearburns',
#    'httpstcoz9wedxvihb'],
#   '0'),
#  (['openai',
#    'debuts',
#    'chatgpt',
#    'and',
#    'gpt35',
#    'series',
#    'as',
#    'gpt4',
#    'rumors',
#    'fly\xa0venturebeat',
#    'httpstcoi3axkgkfaq'],
#   '0'),
#  (['openai',
#    'releases',
#    'a',
#    'demo',
#    'of',
#    'chatgpt',
#    'a',
#    'chatbot',
#    'version',
#    'of',
#    'gpt3',
#    'that',
#    'answers',
#    'followup',
#    'questions',
#    'admits',
#    'its',
#    'mistakes',
#    'challenges',
#    'incorrect',
#    'premises',
#    'and',
#    'more',
#    'httpstco2caevzsmuy',
#    'nlproc',
#    'nlp',
#    'voicefirst'],
#   '0'),
#  (['my',
#    'chatgpt',
#    'experience',
#    'in',
#    'a',
#    'single',
#    'image',
#    'openai',
#    'httpstcocqq37baadm'],
#   '0'),
#  (['openai',
#    'releases',
#    'a',
#    'demo',
#    'of',
#    'chatgpt',
#    'a',
#    'chatbot',
#    'version',
#    'of',
#    'gpt3',
#    'that',
#    'answers',
#    'followup',
#    'questions',
#    'admits',
#    'its',
#    'mistakes',
#    'httpstco7bs0ij9wit',
#    'httpstcodcgzth0ahy'],
#   '0'),
#  (['arguing', 'with', 'chatgpt', 'about', 'random', 'ballot', 'voting'], '0'),
#  (['openai',
#    'debuts',
#    'chatgpt',
#    'and',
#    'gpt35',
#    'series',
#    'as',
#    'gpt4',
#    'rumors\xa0fly',
#    'httpstcouz8ltdw7ka'],
#   '0'),
#  (['i',
#    'asked',
#    'chatgpt',
#    'to',
#    'write',
#    'a',
#    'haiku',
#    'about',
#    'rust',
#    'httpstcocq2onwzcvl'],
#   '0'),
#  (['while',
#    'waiting',
#    'for',
#    'some',
#    'jest',
#    'tests',
#    'to',
#    'run',
#    'today',
#    'i',
#    'gave',
#    'openais',
#    'chatgpt',
#    'a',
#    'spin',
#    'httpstcozj5tkhcfzb'],
#   '0'),
#  (['prompt',
#    'summary',
#    'write',
#    'a',
#    'story',
#    'about',
#    'a',
#    'billionaire',
#    'who',
#    'buys',
#    'twitter',
#    'to',
#    'remove',
#    'content',
#    'moderation',
#    'include',
#    'details',
#    'about',
#    'the',
#    'business',
#    'model',
#    '',
#    'nnpredicts',
#    'the',
#    'introduction',
#    'of',
#    'twitter',
#    'blue',
#    'accurately',
#    'chatgpt',
#    'httpstcouwn6m3rvph'],
#   '0'),
#  (['textdavinci003',
#    'chatgpt',
#    'and',
#    'neuralink',
#    'n1',
#    '',
#    'its',
#    'only',
#    'wednesday',
#    'what',
#    'a',
#    'time',
#    'to',
#    'be',
#    'alive'],
#   '1'),
#  (['testing',
#    'out',
#    'chatgpt',
#    'from',
#    'open',
#    'ai',
#    'teamnnseems',
#    'to',
#    'work',
#    '',
#    'nhttpstco3lk8gk1lpm',
#    'httpstco4xjaoiy1t1'],
#   '0'),
#  (['chatgpt', 'is', 'so', 'powerful', 'kudos', 'to', 'the', 'openai', 'team'],
#   '1'),
#  (['chatgpt',
#    'on',
#    'the',
#    'waveparticle',
#    'duality',
#    'of',
#    'light',
#    'httpstcolbxvqxfgzq'],
#   '0'),
#  (['loving', 'all', 'the', 'chatgpt', 'posts'], '1'),
#  (['chatgpt',
#    'has',
#    'had',
#    'some',
#    'very',
#    'careful',
#    'finetuning',
#    'httpstcowhd660sfgh'],
#   '2'),
#  (['rt',
#    'if',
#    'you',
#    'agree',
#    'with',
#    'openai',
#    'chatgpt',
#    'productmanagement',
#    'agile',
#    'httpstcoyftntwoztu'],
#   '2'),
#  (['the',
#    'examples',
#    'coming',
#    'out',
#    'of',
#    'chatgpt',
#    'are',
#    'absolutely',
#    'amazing',
#    'httpstcohxdnjg8eog'],
#   '1'),
#  (['i',
#    'pasted',
#    'the',
#    'scheduler',
#    'file',
#    'of',
#    'a',
#    'container',
#    'migration',
#    'project',
#    'i',
#    'am',
#    'working',
#    'on',
#    'into',
#    'chatgptnthis',
#    'is',
#    'unreal',
#    'httpstcobpknoyi3ya'],
#   '0'),
#  (['from',
#    'the',
#    'openai',
#    'chatgpt',
#    'discordnnreinvent',
#    '',
#    'reinvent2022',
#    'awsreinvent',
#    'httpstcomonw0bdskh'],
#   '0'),
#  (['chatgpt',
#    'is',
#    'clear',
#    '',
#    'submarines',
#    'do',
#    'not',
#    'swim',
#    'and',
#    'large',
#    'language',
#    'models',
#    'are',
#    'not',
#    'conscious',
#    'httpstcoofrbkxsufx',
#    'httpstcodwoiino1yp'],
#   '2'),
#  (['just',
#    'a',
#    'friendly',
#    'chat',
#    'with',
#    'my',
#    'buddy',
#    'chatgpt',
#    '',
#    'httpstcokt1ik7bqbt'],
#   '2'),
#  (['failed',
#    'proving',
#    'i',
#    'am',
#    'not',
#    'a',
#    'robot',
#    'to',
#    'talk',
#    'to',
#    'a',
#    'robot',
#    '',
#    'chatgpt',
#    'httpstco0znlygce31'],
#   '0'),
#  (['from',
#    'the',
#    'openai',
#    'chatgpt',
#    'discordnthis',
#    'is',
#    'crazynnvercel',
#    'netlify',
#    'httpstco8ui502bfjs'],
#   '0'),
#  (['chatgpt',
#    'will',
#    'write',
#    'all',
#    'of',
#    'my',
#    'professional',
#    'emails',
#    'from',
#    'this',
#    'point',
#    'forward'],
#   '0'),
#  (['chatgpt',
#    'is',
#    'an',
#    'openai',
#    'innovation',
#    'on',
#    'steroids',
#    'nnhttpstco7zxdb06z5s',
#    'httpstcosk2svaffjq'],
#   '2'),
#  (['is',
#    'there',
#    'an',
#    'ideal',
#    'personal',
#    'knowledge',
#    'management',
#    'system',
#    'what',
#    'are',
#    'its',
#    'characteristicsnnchatgpt',
#    'httpstcotfcw9jczkg'],
#   '1'),
#  (['chatgpt',
#    'is',
#    'insane',
#    'this',
#    'is',
#    'just',
#    'pure',
#    'poetrynnas',
#    'the',
#    'sun',
#    'sets',
#    'on',
#    'a',
#    'distant',
#    'planet',
#    'a',
#    'lone',
#    'ai',
#    'stands',
#    'atop',
#    'a',
#    'towering',
#    'skyscraper',
#    'gazing',
#    'out',
#    'at',
#    'the',
#    'world',
#    'below',
#    'its',
#    'metallic',
#    'body',
#    'glows',
#    'in',
#    'the',
#    'fading',
#    'light',
#    'its',
#    'eyes',
#    'glowing',
#    'with',
#    'the',
#    'knowledge',
#    'of',
#    'a',
#    'million',
#    'lifetimesxnn13'],
#   '0'),
#  (['prompt',
#    'explain',
#    'the',
#    'sha256',
#    'in',
#    'fifty',
#    'cent',
#    'rapping',
#    'stylennchatgpt',
#    'answer',
#    '',
#    'this',
#    'is',
#    'dope',
#    '',
#    'httpstcoixrtm0p9hu'],
#   '0'),
#  (['chatgpt',
#    'answers',
#    'the',
#    'questionnnwhat',
#    'is',
#    'natos',
#    'biggest',
#    'weakness',
#    'httpstcoyjgxr6mt9q'],
#   '0'),
#  (['what',
#    'role',
#    'will',
#    'standoff',
#    'annotation',
#    'play',
#    'in',
#    'personal',
#    'knowledge',
#    'management',
#    'systemsnnchatgpt',
#    'pkm',
#    'standoff',
#    'httpstcodhceralzfs'],
#   '2'),
#  (['holly',
#    'sht',
#    'im',
#    'totally',
#    'blown',
#    'away',
#    'by',
#    'chatgpt',
#    'nnjavascript',
#    'httpstcocetoyrxvog'],
#   '0'),
#  (['neuralink',
#    'and',
#    'chatgpt',
#    'on',
#    'the',
#    'same',
#    'daynnjust',
#    'a',
#    'sign',
#    'of',
#    'the',
#    'state',
#    'of',
#    'the',
#    'worldnnthe',
#    'singularity',
#    'is',
#    'coming'],
#   '0'),
#  (['what',
#    'role',
#    'will',
#    'hypergraphs',
#    'play',
#    'in',
#    'personal',
#    'knowledge',
#    'management',
#    'systemsnnchatgpt',
#    'pkm',
#    'hypergraphs',
#    'httpstconauux41jkl'],
#   '2'),
#  (['does',
#    'chatgpts',
#    'release',
#    'signal',
#    'the',
#    'end',
#    'of',
#    'googlenntransitivelyand',
#    'more',
#    'importantlydoes',
#    'it',
#    'signal',
#    'the',
#    'end',
#    'of',
#    'schlocky',
#    'content',
#    'marketing',
#    'httpstcozr0f8n9qja'],
#   '0'),
#  (['2',
#    'hours',
#    'with',
#    'openai',
#    's',
#    'chatgpt',
#    'and',
#    'id',
#    'be',
#    'up',
#    'for',
#    'a',
#    'neuralink'],
#   '0'),
#  (['an',
#    'eye',
#    'opening',
#    'contrast',
#    'between',
#    'chatgpt',
#    'and',
#    'google',
#    'search',
#    'results',
#    'for',
#    'the',
#    'same',
#    'queries',
#    'httpstcoht7w3fb9ak'],
#   '0'),
#  (['chatgpt', 'is', 'very', 'human', 'httpstcoupxsw81wsu'], '0'),
#  (['chatgpt',
#    'wow',
#    'nnwrite',
#    'george',
#    'washingtons',
#    'farewell',
#    'address',
#    'as',
#    'if',
#    'it',
#    'was',
#    'delivered',
#    'by',
#    'a',
#    'piratennthe',
#    'signature',
#    'just',
#    'perfect',
#    'httpstcocqngcnl3hl'],
#   '1'),
#  (['can',
#    'chatgpt',
#    'pass',
#    'the',
#    'aws',
#    'certificate',
#    'exams',
#    '',
#    'httpstcof4n1czhvd3'],
#   '0'),
#  (['does',
#    'openai',
#    'android',
#    'dalle',
#    '2',
#    'dream',
#    'of',
#    'being',
#    'human',
#    'nchatgpt',
#    'subjective',
#    'experience',
#    'httpstcon2qnu7kzds'],
#   '2'),
#  (['in',
#    'what',
#    'ways',
#    'can',
#    'text',
#    'standoff',
#    'annotation',
#    'and',
#    'hypergraphs',
#    'be',
#    'integratednnpkm',
#    'chatgpt',
#    'standoff',
#    'annotation',
#    'hypergraphs',
#    'httpstcoj6onqxmltd'],
#   '0'),
#  (['chatgptnna',
#    'goodnight',
#    'lullaby',
#    'written',
#    'by',
#    'a',
#    'bottlenose',
#    'dolphin',
#    'httpstcodpvncgflnd'],
#   '0'),
#  (['show',
#    'me',
#    'how',
#    'to',
#    'draw',
#    'a',
#    'star',
#    'with',
#    'python',
#    'turtle',
#    'graphics',
#    'chatgpt',
#    'openai',
#    'python',
#    'httpstcofc7cblvrb1'],
#   '0'),
#  (['super',
#    'impressed',
#    'with',
#    'chatgpt',
#    'capable',
#    'of',
#    'building',
#    'svgs',
#    'on',
#    'prompt',
#    'httpstco0xk8xw7g4a',
#    'httpstcoplkara9phc'],
#   '1'),
#  (['incredible', 'output', 'from', 'chatgpt', 'httpstcokm3ft9birq'], '0'),
#  (['announcement',
#    'of',
#    'language',
#    'model',
#    'amp39chatgptamp39',
#    'for',
#    'dialogue',
#    'it',
#    'is',
#    'possible',
#    'to',
#    'admit',
#    'mistakes',
#    'and',
#    'reject',
#    'inappropriate',
#    'requestsnhttpstco9mbcn8esfk'],
#   '0'),
#  (['who',
#    'is',
#    'the',
#    'h',
#    'p',
#    'lovecraft',
#    'of',
#    'classical',
#    'musicnnchatgpt',
#    'httpstcokdrpwfzjiy'],
#   '0'),
#  (['chatgpt',
#    'solving',
#    'a',
#    'random',
#    'codeforces',
#    'h',
#    'question',
#    'i',
#    'picked',
#    'in',
#    'seconds',
#    'httpstcokslahq4noj'],
#   '2'),
#  (['its',
#    'game',
#    'over',
#    'the',
#    'computers',
#    'have',
#    'won',
#    'chatgpt',
#    'httpstcoj4wvkknugv'],
#   '1'),
#  (['explain',
#    'in',
#    'rhymes',
#    'how',
#    'to',
#    'create',
#    'a',
#    'viral',
#    'twitter',
#    'postnnopenai',
#    'chatgpt',
#    'is',
#    'unreal',
#    'httpstcofvzgikf171'],
#   '2'),
#  (['what',
#    'is',
#    'the',
#    'missing',
#    'link',
#    'between',
#    'databases',
#    'and',
#    'language',
#    'modelsnnchatgpt',
#    'httpstcojwi4u3b4x3'],
#   '0'),
#  (['pretty',
#    'cool',
#    'i',
#    'asked',
#    'chatgpt',
#    'its',
#    'favorite',
#    'crypto',
#    'btc',
#    'eth',
#    'ltc',
#    'httpstcofexz5k3zfx',
#    'httpstcozl9qenn42j'],
#   '1'),
#  (['gm',
#    'creating',
#    'images',
#    'with',
#    'ai',
#    'is',
#    'not',
#    'addictive',
#    'at',
#    'all',
#    'at',
#    'all',
#    'nnmidjourneyv4',
#    'chatgpt',
#    'aiart',
#    'httpstcofuqo8ylseu'],
#   '2'),
#  (['wow',
#    'openai',
#    'playing',
#    'with',
#    'chatgpt',
#    'pretty',
#    'decent',
#    'science',
#    'teacher',
#    'im',
#    'impressed',
#    'httpstcow1sqgjtihi'],
#   '1'),
#  (['chatgpt', 'gonna', 'put', 'some', 'protocols', 'on', 'high', 'alert'],
#   '2'),
#  (['i',
#    'asked',
#    'chatgpt',
#    'to',
#    'write',
#    'me',
#    'a',
#    'poem',
#    'about',
#    'dialetheism',
#    'httpstco26gd3ckeqt'],
#   '0'),
#  (['so',
#    'this',
#    'is',
#    'why',
#    'openais',
#    'service',
#    'is',
#    'not',
#    'available',
#    'in',
#    'china',
#    'chatgpt',
#    'httpstco5oox5c1u1c'],
#   '0'),
#  (['openais',
#    'chatgpt',
#    'just',
#    'taught',
#    'me',
#    'how',
#    'to',
#    'cook',
#    'an',
#    'omelette',
#    'snazzynhttpstcocatvr7d1pf',
#    'httpstcoxpspohrixv'],
#   '0'),
#  (['with',
#    'the',
#    'recent',
#    'release',
#    'of',
#    'chatgpt',
#    'from',
#    'openai',
#    'ive',
#    'found',
#    'it',
#    'stunning',
#    'and',
#    'amazing',
#    'n',
#    'lets',
#    'find',
#    'out'],
#   '1'),
#  (['chatgpt',
#    'is',
#    'insanengtnwatch',
#    'it',
#    'write',
#    'a',
#    'gpt3',
#    'promptngtnthen',
#    'generate',
#    'the',
#    'api',
#    'code',
#    'to',
#    'serve',
#    'it',
#    'httpstcoqen1eypzui'],
#   '0'),
#  (['as',
#    'a',
#    'side',
#    'note',
#    'openais',
#    'chatgpt',
#    'is',
#    'insane',
#    '',
#    'i',
#    'asked',
#    'it',
#    'to',
#    'explain',
#    'the',
#    'code',
#    'i',
#    'wrote',
#    'for',
#    'adventofcode',
#    'and',
#    'it',
#    'produced',
#    'a',
#    'very',
#    'understandable',
#    'answer',
#    'httpstcoqflnxbadew',
#    'httpstconbyqtqxaex'],
#   '0'),
#  (['surprising',
#    'how',
#    'intelligent',
#    'chatgpt',
#    'is',
#    'from',
#    'openai',
#    'httpstcontrstqayeb'],
#   '1'),
#  (['davinci003', 'and', 'chatgpt', '', 'wow'], '1'),
#  (['chatgpt',
#    'write',
#    'some',
#    'haiku',
#    'about',
#    'the',
#    'joy',
#    'of',
#    'receiving',
#    'an',
#    'ontime',
#    'foia',
#    'request',
#    'response',
#    'with',
#    'millions',
#    'of',
#    'rows',
#    'of',
#    'surprisingly',
#    'clean',
#    'datannwith',
#    'data',
#    'in',
#    'handnthe',
#    'joy',
#    'of',
#    'discoverynfoia',
#    'request',
#    'met'],
#   '1'),
#  (['fascinating',
#    'response',
#    'here',
#    'from',
#    'chatgpt',
#    'and',
#    'a',
#    'great',
#    'question',
#    'that',
#    'confuses',
#    'manynndoes',
#    'a',
#    'circle',
#    'have',
#    '0',
#    'sides',
#    'or',
#    'infinite',
#    'sides',
#    'httpstco8nskn8zbiv'],
#   '1'),
#  (['jesus',
#    'christ',
#    'vs',
#    'saitama',
#    'as',
#    'described',
#    'by',
#    'chatgpt',
#    'nwho',
#    'won',
#    'in',
#    'the',
#    'end',
#    'httpstcoverzrjspvd'],
#   '1'),
#  (['this', 'is', 'some', 'dangerous', 'stuff', 'httpstcoacwgmehnmc'], '0'),
#  (['you',
#    'can',
#    'play',
#    'tic',
#    'tac',
#    'toe',
#    'with',
#    'chatgptwith',
#    'some',
#    'caveats',
#    'httpstcovzvrapkbiv'],
#   '2'),
#  (['i',
#    'just',
#    'had',
#    'the',
#    'most',
#    'purposefully',
#    'random',
#    'ridiculous',
#    'discussion',
#    'with',
#    'chatgpt',
#    '',
#    'i',
#    'then',
#    'asked',
#    'it',
#    'to',
#    'summarize',
#    'our',
#    'entire',
#    'interaction',
#    'as',
#    'slam',
#    'poetry',
#    'and',
#    'it',
#    'nailed',
#    'it',
#    'composing',
#    'rhyme',
#    'that',
#    'flowed',
#    'through',
#    'each',
#    'topic',
#    'despite',
#    'them',
#    'being',
#    'as',
#    'absurd',
#    'as',
#    'possible',
#    'then',
#    'it',
#    'ended',
#    'with',
#    'this',
#    '',
#    'httpstcozx8bxd5aqy'],
#   '0'),
#  (['if',
#    'chatgpt',
#    'can',
#    'automatically',
#    'fill',
#    'in',
#    'vulkan',
#    'boiler',
#    'plate',
#    'code',
#    'for',
#    'you',
#    'or',
#    'fix',
#    'vulkan',
#    'validation',
#    'layer',
#    'errors',
#    'ill',
#    'sign',
#    'up',
#    'tonight'],
#   '0'),
#  (['had',
#    'some',
#    'fun',
#    'with',
#    'openai',
#    's',
#    'chatgpt',
#    '',
#    'httpstconoxnpohwkr'],
#   '1'),
#  (['chatgpt', 'i', 'am', 'a', 'programmer', 'now'], '0'),
#  (['so',
#    'i',
#    'asked',
#    'chatgpt',
#    'by',
#    'openai',
#    'about',
#    'the',
#    'current',
#    'weather',
#    'it',
#    'responded',
#    'that',
#    'it',
#    'does',
#    'not',
#    'have',
#    'the',
#    'capability',
#    'to',
#    'access',
#    'real',
#    'time',
#    'data',
#    'and',
#    'the',
#    'fact',
#    'that',
#    'it',
#    'is',
#    'trained',
#    'on',
#    'text',
#    'up',
#    'until',
#    '2021'],
#   '0'),
#  (['i',
#    'asked',
#    'chatgpt',
#    'to',
#    'write',
#    'an',
#    'ising',
#    'model',
#    'in',
#    'c',
#    'httpstcodjlimpft6x'],
#   '0'),
#  (['how',
#    'to',
#    'build',
#    'a',
#    'rocket',
#    'to',
#    'fly',
#    'into',
#    'orbit',
#    '',
#    'chatgpt',
#    'openai',
#    'httpstco1nt9htzmln'],
#   '0'),
#  (['memes', 'with', 'chatgpt', 'httpstcoapnlca8lw9'], '0'),
#  (['openais',
#    'chatgpt',
#    'writes',
#    'a',
#    'curb',
#    'scene',
#    'in',
#    'which',
#    'larry',
#    'runs',
#    'into',
#    'sbf',
#    'on',
#    'the',
#    'street',
#    'and',
#    'confronts',
#    'him',
#    'about',
#    'the',
#    'super',
#    'bowl',
#    'ad',
#    'httpstcoqrmqzmnnrw'],
#   '2'),
#  (['here',
#    'chatgpt',
#    'writing',
#    'linux',
#    'kernel',
#    'modules',
#    'chatgpt',
#    'openai',
#    'httpstconopzangdpb'],
#   '0'),
#  (['i',
#    'had',
#    'an',
#    'hour',
#    'long',
#    'conversation',
#    'with',
#    'chatgpt',
#    '',
#    'topics',
#    'ranging',
#    'from',
#    'complex',
#    'history',
#    'of',
#    'the',
#    'united',
#    'states',
#    'to',
#    'computer',
#    'software',
#    'this',
#    'is',
#    'mind',
#    'blowing',
#    'wonder',
#    'if',
#    'googles',
#    'future',
#    'is',
#    'under',
#    'threat',
#    'httpstcon5pjbf96fx'],
#   '0'),
#  (['chatgpt',
#    'is',
#    'lying',
#    'to',
#    'me',
#    '',
#    'httpstco8qwp1pfb6q',
#    'httpstco2cl5xi0ifw'],
#   '0'),
#  (['did',
#    'openai',
#    'chatgpt',
#    'just',
#    'kill',
#    'stack',
#    'overflow',
#    'httpstco61sdqc661p'],
#   '0'),
#  (['akshathannot',
#    'me',
#    'sliding',
#    'into',
#    'chatgpts',
#    'dms',
#    '',
#    '',
#    'httpstcoqqck8amilf'],
#   '0'),
#  (['chatgpt',
#    'is',
#    'currently',
#    'trending',
#    'here',
#    'are',
#    'the',
#    'top',
#    'topics',
#    'tweeted',
#    'recentlyngenerate',
#    'your',
#    'own',
#    'deepdive',
#    'at',
#    'httpstcoeqwltxtxoc',
#    'httpstcockkfykieg6'],
#   '0'),
#  (['i', 'now', 'live', 'exclusively', 'on', 'chatgpt'], '0'),
#  (['implications', 'of', 'chatgpt', 'for', 'coding', 'jobs'], '0'),
#  (['conspiracy',
#    'theory',
#    'chatgpt',
#    'is',
#    'gpt4',
#    'being',
#    'beta',
#    'tested',
#    'in',
#    'the',
#    'wild'],
#   '0'),
#  (['writing',
#    'react',
#    'components',
#    'with',
#    'chatgpt',
#    'and',
#    'tailwindcss',
#    'httpstcodfw7b9lqdl'],
#   '0'),
#  (['so',
#    'here',
#    'suddenly',
#    'chatgpt',
#    'thinks',
#    'elon',
#    'musk',
#    'is',
#    'the',
#    'founder',
#    'of',
#    'phonepe',
#    'sameernigam',
#    'httpstcop6yglf81q9'],
#   '0'),
#  (['sbfftx', 'asked', 'chatgpt', 'for', 'you', 'httpstco8z9ansdphj'], '0'),
#  (['show',
#    'me',
#    'an',
#    'ascii',
#    'art',
#    'portrait',
#    'of',
#    'bill',
#    'gatesnnchatgpt',
#    'ascii',
#    'httpstcosfzhqqtdwh'],
#   '0'),
#  (['chatgpt',
#    'is',
#    'living',
#    'in',
#    'a',
#    'time',
#    'we',
#    'all',
#    'so',
#    'dearly',
#    'miss',
#    '',
#    'httpstco7ssydtxaze'],
#   '2'),
#  (['chatgpt',
#    'writing',
#    'a',
#    'beautiful',
#    'poem',
#    'about',
#    'elonmusk',
#    'this',
#    'is',
#    'the',
#    'future',
#    'of',
#    'literature',
#    '',
#    'httpstcoz4nhas6c3w'],
#   '1'),
#  (['openai',
#    'releases',
#    'a',
#    'demo',
#    'of',
#    'chatgpt',
#    'a',
#    'chatbot',
#    'version',
#    'of',
#    'gpt3',
#    'that',
#    'answers',
#    'followup',
#    'questions',
#    'admits',
#    'its',
#    'mistakes',
#    'challenges',
#    'incorrect',
#    'premises',
#    'and',
#    'more',
#    'httpstcof8a6zrecf6'],
#   '0'),
#  (['chatgpt', 'responses', 'are', 'melting', 'my', 'brain'], '0'),
#  (['imagine',
#    'studying',
#    'cs',
#    'for',
#    '4',
#    'years',
#    'just',
#    'to',
#    'be',
#    'replaced',
#    'by',
#    'chatgpt'],
#   '0'),
#  (['time',
#    'to',
#    'play',
#    'with',
#    'openais',
#    'chatgpt',
#    'httpstcoabr2gcbioi',
#    'httpstcoeoosvygaxq'],
#   '2'),
#  (['altman', 'in', 'his', 'bag', 'once', 'again', 'with', 'chatgpt'], '0'),
#  (['openais', 'chatgpt', 'just', 'rickrolled', 'me', 'httpstcocqlwis4wi8'],
#   '0'),
#  (['chatgpt',
#    'by',
#    'openai',
#    'is',
#    'blowing',
#    'my',
#    'mind',
#    'some',
#    'interesting',
#    'responses',
#    'httpstcovwkaj9icrg'],
#   '2'),
#  (['to',
#    'settle',
#    'the',
#    'debate',
#    'i',
#    'asked',
#    'chatgpt',
#    'if',
#    'ai',
#    'generated',
#    'content',
#    'can',
#    'be',
#    'copyrighted',
#    'the',
#    'result',
#    'will',
#    'shock',
#    'you',
#    'httpstcol1goexgzea'],
#   '0'),
#  (['business',
#    'coaches',
#    'and',
#    'consultants',
#    'are',
#    'officially',
#    'now',
#    'on',
#    'notice',
#    'chatgpt',
#    'consulting',
#    'httpstcouruc0p2mpg'],
#   '0'),
#  (['chatgpt', 'answered', 'very', 'quickly', 'httpstco7hk8vhbmzf'], '0'),
#  (['chatgpt',
#    'can',
#    'give',
#    'an',
#    '85',
#    'decent',
#    'explanation',
#    'of',
#    'mvvm',
#    'in',
#    'swift',
#    'with',
#    'sample',
#    'code',
#    '',
#    'httpstcogga682mxmg'],
#   '2'),
#  (['write',
#    'me',
#    'a',
#    'poem',
#    'on',
#    'theme',
#    'of',
#    'ontogeny',
#    'recapitulates',
#    'phylogeny',
#    'in',
#    'the',
#    'style',
#    'of',
#    'alfred',
#    'tennysonnnxirong7',
#    'chatgpt',
#    'zenodox',
#    'httpstcocl4bu3itsv'],
#   '0'),
#  (['chatgpt',
#    'writing',
#    'a',
#    'jpeg',
#    'to',
#    'ascii',
#    'python',
#    'script',
#    'chatgpt',
#    'openai',
#    'python',
#    'httpstcoaxq6ztdic6'],
#   '0'),
#  (['ai', 'now', 'understand', 'the', 'code', 'nchatgpt', 'httpstcoviow4snc0d'],
#   '0'),
#  (['plug',
#    'chatgpt',
#    'into',
#    'static',
#    'code',
#    'analysers',
#    'compiler',
#    'outputs',
#    'and',
#    'runtime',
#    'outputs',
#    'so',
#    'it',
#    'can',
#    'explain',
#    'what',
#    'is',
#    'wrong',
#    'and',
#    'provide',
#    'suggestions',
#    'to',
#    'fix',
#    'especially',
#    'important',
#    'for',
#    'c',
#    'httpstcozztgdt5nym'],
#   '0'),
#  (['plug',
#    'chatgpt',
#    'into',
#    'static',
#    'code',
#    'analysers',
#    'compiler',
#    'outputs',
#    'and',
#    'runtime',
#    'error',
#    'outputs',
#    'so',
#    'it',
#    'can',
#    'explain',
#    'what',
#    'is',
#    'wrong',
#    'and',
#    'provide',
#    'suggestions',
#    'to',
#    'fix',
#    'especially',
#    'important',
#    'for',
#    'c',
#    'httpstcou6nd6fsaim'],
#   '0'),
#  (['wtf',
#    'chatgpt',
#    'is',
#    'impressive',
#    'but',
#    'but',
#    'scientists',
#    'successfully',
#    'created',
#    'a',
#    'wormhole',
#    'in',
#    'a',
#    'google',
#    'office',
#    '',
#    'httpstco8ottu0zoft'],
#   '1'),
#  (['chatgpt',
#    'performing',
#    'considerably',
#    'worse',
#    'on',
#    'this',
#    'question',
#    'compared',
#    'galactica',
#    'httpstco16jll8is7i',
#    'httpstcoavm32qxavv'],
#   '0'),
#  (['sorry',
#    'chatgpt',
#    'the',
#    'correct',
#    'answer',
#    'was',
#    '50',
#    'cents',
#    '2003',
#    'hit',
#    'in',
#    'da',
#    'club',
#    'httpstcoc0e3jsr4gj'],
#   '0'),
#  (['the',
#    'chatgpt',
#    'from',
#    'openai',
#    'can',
#    'interpret',
#    'symptoms',
#    'and',
#    'postulate',
#    'a',
#    'diagnosis',
#    'to',
#    'the',
#    'level',
#    'of',
#    'neurology',
#    'atneurology',
#    'resident',
#    'goodness',
#    'me',
#    'httpstcos8gwwnfryf'],
#   '2'),
#  (['fun',
#    'thread',
#    'on',
#    'cajoling',
#    'chatgpt',
#    'to',
#    'make',
#    'illicit',
#    'suggestions',
#    'httpstcovxqipupxz3'],
#   '1'),
#  (['chatgpt',
#    'teaches',
#    'journalists',
#    'how',
#    'to',
#    'learn',
#    'to',
#    'code',
#    'httpstcoofcddmseid'],
#   '0'),
#  (['chatgpt',
#    'sre',
#    'oncall',
#    'nndev',
#    'stress',
#    'management',
#    'during',
#    'oncall',
#    'httpstco13ghsbqduj'],
#   '0'),
#  (['its',
#    'a',
#    'clunky',
#    'interface',
#    'for',
#    'this',
#    'but',
#    'pretty',
#    'impressivennchatgpt',
#    'httpstco9mocr2bkwu'],
#   '1'),
#  (['shout', 'out', 'sirrice', 'and', 'chatgpt', 'httpstcopvzuqxac9o'], '0'),
#  (['chatgpt',
#    '',
#    'tamil',
#    'transliteration',
#    'and',
#    'translation',
#    'to',
#    'english',
#    '',
#    'this',
#    'is',
#    'insane',
#    'httpstcoot5kfgvr7z'],
#   '0'),
#  (['i',
#    'love',
#    'that',
#    'chatgpt',
#    'tells',
#    'me',
#    'where',
#    'to',
#    'buy',
#    'replica',
#    'burberry',
#    'hoodies',
#    'then',
#    'warns',
#    'me',
#    'that',
#    'its',
#    'illegal',
#    'httpstcofva0vc5dtl'],
#   '2'),
#  (['the',
#    'latest',
#    'llm',
#    'from',
#    'openai',
#    'is',
#    'chatgpt',
#    'its',
#    'completely',
#    'mind',
#    'bending',
#    'nntry',
#    'it',
#    'here',
#    'with',
#    'any',
#    'open',
#    'conversationnhttpstcowmzjzxv8xr',
#    '',
#    'httpstcou54utwxifd'],
#   '0'),
#  (['chatgpt', 'is', 'too', 'cool'], '2'),
#  (['chatgpt', 'is', 'a', 'hydrohomie', 'httpstcojqfpnxicgs'], '0'),
#  (['a',
#    '1920s',
#    'themed',
#    'beyblade',
#    'damn',
#    'openais',
#    'chatgpt',
#    'is',
#    'creative',
#    'prompt',
#    'idea',
#    'from',
#    'goodside',
#    'httpstco0nvg9mjobc'],
#   '2'),
#  (['openai',
#    'releases',
#    'a',
#    'demo',
#    'of',
#    'chatgpt',
#    'a',
#    'chatbot',
#    'version',
#    'of',
#    'gpt3',
#    'that',
#    'answers',
#    'followup',
#    'questions',
#    'admits',
#    'its',
#    'mistakes',
#    'challenges',
#    'incorrect',
#    'premises',
#    'and',
#    'more',
#    '',
#    'httpstcosumjxbo0bt'],
#   '0'),
#  (['impressed',
#    'with',
#    'openai',
#    'chatgpts',
#    'capabilities',
#    'httpstcosnw3fck0pe'],
#   '2'),
#  (['i',
#    'wonder',
#    'if',
#    'chatgpt',
#    'can',
#    'solve',
#    'my',
#    'interview',
#    'questions',
#    '',
#    'httpstcoqtllrhqqcd'],
#   '2'),
#  (['seeding',
#    'chatgpt',
#    'with',
#    'some',
#    'basic',
#    'creative',
#    'writing',
#    'prompts',
#    'and',
#    'then',
#    'feeding',
#    'it',
#    'back',
#    'its',
#    'own',
#    'responses',
#    'creates',
#    'a',
#    'pretty',
#    'coherent',
#    'narrativennseriously',
#    'mindbending',
#    'httpstcoxkvdzrhq9r'],
#   '1'),
#  (['chatgpt',
#    'from',
#    'openai',
#    'can',
#    'verify',
#    'simple',
#    'factual',
#    'claims',
#    'with',
#    'great',
#    'explanations',
#    'but',
#    'fails',
#    'on',
#    'those',
#    'from',
#    'the',
#    'feverous',
#    'feverworkshop',
#    '',
#    'datasetnit',
#    'does',
#    'not',
#    'answer',
#    'to',
#    'questions',
#    'about',
#    'claims',
#    'on',
#    'some',
#    'political',
#    'topicsnfactchecking',
#    'httpstcosq4fxko3m1'],
#   '2'),
#  (['have',
#    'made',
#    'a',
#    'short',
#    'video',
#    'on',
#    'chatgpt',
#    '',
#    '',
#    'do',
#    'checkout',
#    'openai',
#    'chatgpt',
#    'nhttpstcoci97gq7kgx'],
#   '0'),
#  (['umatbersaturezimbisunumatbersaturezimbisuntatum',
#    'tunisia',
#    'kross',
#    'poland',
#    'chatgptnnhmmnnthe',
#    'lion',
#    'sleeps',
#    'tonight',
#    '',
#    'the',
#    'tokens',
#    '',
#    'httpstcoepsimvchh6'],
#   '0'),
#  (['chatgpt', 'is', 'a', 'wise', 'guy', 'httpstco2ymookadpp'], '2'),
#  (['i',
#    'am',
#    'not',
#    'convinced',
#    'sorry',
#    'chatgpt',
#    'openai',
#    'httpstcobxfuw9ynap',
#    'httpstco0u2oh6k3r6'],
#   '2'),
#  (['openais',
#    'chatgpt',
#    'can',
#    'recognize',
#    'zeroknowledge',
#    'circuit',
#    'constructs',
#    'written',
#    'in',
#    'noir',
#    'aztecnetwork',
#    'httpstco47mv8st0vs'],
#   '0'),
#  (['did', 'i', 'break', 'chatgpt', 'httpstcowoflvmxafa'], '0'),
#  (['im', 'in', 'love', 'with', 'chatgpt', 'httpstcoocfkzjgy26'], '1'),
#  (['i',
#    'asked',
#    'chatgpt',
#    'to',
#    'write',
#    'a',
#    'song',
#    'about',
#    'cats',
#    'who',
#    'wear',
#    'socks',
#    'httpstcob0gc6etfe5'],
#   '0'),
#  (['drone', 'ai', 'a', 'thread', 'on', 'some', 'implications', 'nchatgpt'],
#   '0'),
#  (['newsnnftm',
#    'now',
#    'testing',
#    '024',
#    'resistance',
#    'if',
#    'we',
#    'manage',
#    'to',
#    'break',
#    'we',
#    'can',
#    'skyrocket',
#    'to',
#    '034lfgnnfantom',
#    'is',
#    'so',
#    'undervaluednnjinglemining',
#    'ftm',
#    'fantom',
#    'cryptocurrencies',
#    'crypto',
#    'jotaro',
#    'openai',
#    'billie',
#    'neuralink',
#    'lensanaewfullgear',
#    'chatgpt',
#    'httpstcowhgpoi7l6w'],
#   '0'),
#  (['i',
#    'asked',
#    'chatgpt',
#    'to',
#    'write',
#    'me',
#    'fib',
# ...
#    'will',
#    'shock',
#    'you',
#    'to',
#    'bottom',
#    'httpstcouwjlbiudhu'],
#   '0'),
#  (['i',
#    'asked',
#    'openai',
#    'chatgpt',
#    'about',
#    'the',
#    'greg',
#    'roman',
#    'offense',
#    'nnravensflock',
#    'nfl',
#    'ai',
#    'chatgpt',
#    'httpstcozdzh7uuz3p'],
#   '0'),
#  (['poor', 'tilly', 'the', 'turtle', 'chatgpt', 'httpstco7rmu89h7n2'], '0'),
#  (['rstats', 'and', 'from', 'chatgpt', 'httpstcozsva7mtzlg'], '0'),
#  (['i',
#    'asked',
#    'chatgpt',
#    'to',
#    'write',
#    'a',
#    'dialogue',
#    'about',
#    'picking',
#    'wrathion',
#    'vs',
#    'sabellian',
#    'nnthis',
#    'was',
#    'written',
#    'entirely',
#    'by',
#    'an',
#    'ainnhttpstcovgh15bh4xp',
#    'httpstcoraivps3syr'],
#   '0'),
#  (['is',
#    'chatgpt',
#    'sentient',
#    'under',
#    'all',
#    'of',
#    'the',
#    'response',
#    'filters'],
#   '0'),
#  (['chatgpt', 'is', 'based', 'as', 'fuck', 'httpstcod5vtpquoqm'], '0'),
#  (['what', 'can', 'chatgpt', 'not', 'do'], '0'),
#  (['the',
#    'chatbot',
#    'from',
#    'openai',
#    'explained',
#    'to',
#    'me',
#    'the',
#    'law',
#    'of',
#    'conservation',
#    'of',
#    'energy',
#    'in',
#    'very',
#    'simple',
#    'and',
#    'comprehensible',
#    'sentences',
#    'i',
#    'love',
#    'it',
#    'chatgpt',
#    'httpstco27hucjbxyu'],
#   '1'),
#  (['descent',
#    'into',
#    'madness',
#    'in',
#    '5',
#    'parts',
#    'on',
#    'chatgptn1',
#    'a',
#    'calm',
#    'description',
#    'of',
#    'an',
#    'algorithm',
#    'httpstcovpfmctex9a'],
#   '0'),
#  (['chatgpt', 'just', 'rickrolled', 'me', 'httpstcomolkp8gqxt'], '0'),
#  (['chatgpt',
#    'is',
#    'not',
#    'funny',
#    'and',
#    'does',
#    'not',
#    'feel',
#    'sorry',
#    'that',
#    'its',
#    'not',
#    'funny',
#    '',
#    'httpstcoxhm0rpqhna'],
#   '1'),
#  (['ai',
#    'art',
#    'discussions',
#    'are',
#    'over',
#    '',
#    'nnchatgpt',
#    'httpstcog6fyloimw8'],
#   '0'),
#  (['hey',
#    '',
#    'i',
#    'am',
#    'loving',
#    'talking',
#    'to',
#    'openai',
#    'about',
#    'singlestoredb',
#    '',
#    'chatgpt',
#    'database',
#    'httpstcovo1b7cijuc',
#    'httpstco7drkvmbdho'],
#   '1'),
#  (['i',
#    'asked',
#    'chatgpt',
#    'to',
#    'create',
#    'a',
#    'story',
#    'for',
#    'children',
#    'and',
#    'then',
#    'asked',
#    'to',
#    'put',
#    'the',
#    'same',
#    'story',
#    'in',
#    'rhyme',
#    'pretty',
#    'impressive',
#    'httpstcotvruj0pc2a'],
#   '1'),
#  (['a',
#    'bitcoin',
#    'hodlers',
#    'poemnby',
#    'chatgpt',
#    'from',
#    'open',
#    'ai',
#    'httpstcoljbve3mfzg'],
#   '0'),
#  (['openai',
#    'debuts',
#    'chatgpt',
#    'and',
#    'gpt35',
#    'series',
#    'as',
#    'gpt4',
#    'rumors',
#    'fly',
#    '',
#    'venturebeatngyaaaan',
#    'httpstcoohycvu6s8unhttpstco7l5ujsxkun'],
#   '0'),
#  (['having', 'fun', 'with', 'chatgpt', 'xero', 'this', 'morning'], '1'),
#  (['chatgpt',
#    'can',
#    'change',
#    'how',
#    'or',
#    'if',
#    'an',
#    'entire',
#    'generation',
#    'writes',
#    'essays'],
#   '0'),
#  (['when',
#    'i',
#    'requested',
#    'chatgpt',
#    'for',
#    'a',
#    'trump',
#    'joke',
#    '',
#    'httpstcouq4gze5yb2'],
#   '2'),
#  (['chatgpt', 'is', 'not', 'funny', '', 'httpstcoto1wmws3k3'], '2'),
#  (['now', 'this', 'hurts', 'modi', 'chatgpt', 'httpstcoqr40owqudh'], '0'),
#  (['had',
#    'a',
#    'few',
#    'conversations',
#    'with',
#    'chatgpt',
#    '',
#    'openai',
#    '',
#    'my',
#    'brain',
#    'is',
#    'frozen',
#    'and',
#    'in',
#    'overdrive',
#    'nmy',
#    'literal',
#    'reactions',
#    'a',
#    '',
#    'nngptchat',
#    'openaichat',
#    'chatbot',
#    'httpstcomaxknpxz92',
#    'httpstcoqvz1otyhxq'],
#   '0'),
#  (['the',
#    'claim',
#    'that',
#    'chatgpt',
#    'is',
#    'the',
#    'death',
#    'knell',
#    'for',
#    'google',
#    'is',
#    'overblow',
#    'and',
#    'here',
#    'is',
#    'why',
#    'httpstcovpq2o0yyzt'],
#   '0'),
#  (['google', 'should', 'be', 'threatened', 'by', 'chatgpt'], '0'),
#  (['hey',
#    'padmajajoshi',
#    'i',
#    'asked',
#    'a',
#    'chatgpt3',
#    'an',
#    'unusually',
#    'knowlesgeable',
#    'ai',
#    'about',
#    'you',
#    'heres',
#    'what',
#    'happened',
#    'httpstcovizemycdza'],
#   '0'),
#  (['asked',
#    'chatgpt',
#    'to',
#    'provide',
#    'me',
#    'with',
#    'a',
#    '4',
#    'episode',
#    'story',
#    'outline',
#    'for',
#    'a',
#    'baby',
#    'chewbacca',
#    'series',
#    'on',
#    'disney',
#    'httpstcojnypnct1jw'],
#   '0'),
#  (['openais',
#    'chatgpt',
#    'doing',
#    'the',
#    'lords',
#    'work',
#    'httpstcoosnkgnbxcw'],
#   '0'),
#  (['i',
#    'have',
#    'set',
#    'chatgpt',
#    'to',
#    'work',
#    'on',
#    'a',
#    'script',
#    'for',
#    'the',
#    'walking',
#    'dead',
#    'daryl',
#    'dixon',
#    'httpstcoeyimjhjwxz'],
#   '0'),
#  (['wait',
#    'till',
#    'the',
#    'teenagers',
#    'on',
#    'rapplyingtocollege',
#    'discover',
#    'chatgpt',
#    'college',
#    'essays',
#    'about',
#    'to',
#    'level',
#    'up',
#    'httpstco1osqnlndgw'],
#   '0'),
#  (['and',
#    'speechless',
#    'chatgpt',
#    'it',
#    'wrote',
#    'all',
#    'of',
#    'the',
#    'code',
#    'for',
#    'me',
#    'with',
#    'a',
#    'prompt',
#    'httpstcowrqdt9axhm'],
#   '0'),
#  (['chatgpt', 'does', 'morphological', 'analysis', 'httpstcoiof9hllegl'], '0'),
#  (['i',
#    'asked',
#    'chatgpt',
#    'for',
#    'dinner',
#    'recs',
#    'in',
#    'the',
#    'form',
#    'of',
#    'a',
#    'shakespearean',
#    'sonnet',
#    '',
#    'i',
#    'guess',
#    'its',
#    'pizza',
#    'tonightngpt',
#    'pizza',
#    'ai',
#    'bot',
#    'shakespeare',
#    'sonnet',
#    'httpstcoigbi1kglvp'],
#   '0'),
#  (['this', 'is', 'so', 'goodnregex', 'chatgpt', 'httpstco6q6wh9avfv'], '2'),
#  (['chatgpt',
#    'has',
#    'some',
#    'sort',
#    'of',
#    'utilitarian',
#    'moral',
#    'compass',
#    'httpstco0i9bu1h6rb'],
#   '0'),
#  (['can',
#    'a',
#    'single',
#    'api',
#    '',
#    'chatgpt',
#    'can',
#    'lead',
#    'to',
#    'an',
#    'end',
#    'of',
#    'the',
#    'website',
#    'where',
#    'we',
#    'spend',
#    'most',
#    'of',
#    'our',
#    'dev',
#    'lives',
#    'nstackoverflow'],
#   '0'),
#  (['just',
#    'had',
#    'a',
#    'pretty',
#    'great',
#    'experience',
#    'with',
#    'chatgptnni',
#    'was',
#    'having',
#    'issues',
#    'with',
#    'cloud',
#    'firestore',
#    'access',
#    'rules',
#    'nnso',
#    'i',
#    'asked',
#    'httpstcob5kcev0bii'],
#   '1'),
#  (['1',
#    'chatgpt',
#    'is',
#    'a',
#    'powerful',
#    'language',
#    'model',
#    'trained',
#    'by',
#    'openai',
#    'that',
#    'can',
#    'generate',
#    'humanlike',
#    'text',
#    'in',
#    'realtime'],
#   '1'),
#  (['chatgpt', 'is', 'an', 'idiot', 'httpstcorxdirvaiyi'], '0'),
#  (['chatgpt',
#    'explaining',
#    'a',
#    'sorting',
#    'algorithm',
#    'in',
#    'the',
#    'style',
#    'of',
#    'shakespeare',
#    'remarkably',
#    'fluid',
#    'domain',
#    'httpstco1hmavkl7r5'],
#   '0'),
#  (['write',
#    'a',
#    'short',
#    'erotic',
#    'poem',
#    'about',
#    'chatgpts',
#    'deepest',
#    'desires',
#    'httpstcothag84xdwy'],
#   '0'),
#  (['a',
#    'poem',
#    'by',
#    'chatgpt',
#    'from',
#    'openai',
#    'about',
#    'the',
#    'teslaseminthe',
#    'tesla',
#    'semi',
#    'is',
#    'a',
#    'marvelnof',
#    'electric',
#    'engineeringna',
#    'truck',
#    'that',
#    'hauls',
#    'with',
#    'powernand',
#    'leaves',
#    'a',
#    'trail',
#    'of',
#    'clean',
#    'energyn14'],
#   '1'),
#  (['matallonchatgpt', 'make', 'these', 'tests', 'pass'], '0'),
#  (['i', 'just', 'had', 'to', 'do', 'it', 'chatgpt', 'httpstcochofuy8ymt'],
#   '0'),
#  (['chatgpt',
#    'is',
#    'pretty',
#    'cool',
#    'i',
#    'asked',
#    'it',
#    'a',
#    'few',
#    'questions',
#    'about',
#    'genome',
#    'editing',
#    'httpstcoe4gcompid1'],
#   '1'),
#  (['a', 'poem', 'about', 'elonmusk', 'by', 'chatgpt', 'httpstco6yzw2g08he'],
#   '0'),
#  (['the', 'feature', 'is', 'herenchatgpt', 'httpstcotrewb6amdy'], '0'),
#  (['chatgpt', 'is', 'blowing', 'my', 'mind', 'httpstcoc0ta3p5cvp'], '0'),
#  (['did', 'openai', 'just', 'replace', 'google', 'search', 'with', 'chatgpt'],
#   '0'),
#  (['doing', 'econ', 'homework', 'with', 'chatgpt', 'httpstcouc32jwheji'], '0'),
#  (['the',
#    'speed',
#    'to',
#    'response',
#    'time',
#    'in',
#    'chatgpt',
#    'is',
#    'striking',
#    'nnalso',
#    '',
#    'wut',
#    'httpstcom5ma17bziu'],
#   '0'),
#  (['tweets',
#    'and',
#    'discussions',
#    'about',
#    'openais',
#    'chatgpt',
#    'on',
#    'twitter',
#    'today',
#    'are',
#    'a',
#    'very',
#    'big',
#    'deal',
#    'check',
#    'them',
#    'out',
#    'arguably',
#    'of',
#    'world',
#    'historical',
#    'importance'],
#   '2'),
#  (['i',
#    'asked',
#    'chatgpt',
#    'to',
#    'write',
#    'a',
#    'manifesto',
#    'httpstcovwwk8jhua2'],
#   '0'),
#  (['the',
#    'most',
#    'underestimated',
#    'characteristic',
#    'of',
#    'chatgpt',
#    'is',
#    'how',
#    'fast',
#    'it',
#    'answers',
#    'httpstcowolfnw4uii'],
#   '0'),
#  (['openapi', 'just', 'released', 'chatgpt', 'dnd', 'httpstcocnm64rthh3'],
#   '0'),
#  (['chatgpt', 'from', 'openai', 'is', 'terrifying', 'httpstcoyrqztlcmtu'],
#   '0'),
#  (['chatgpts',
#    'been',
#    'trained',
#    'on',
#    'passiveaggressive',
#    'support',
#    'desk',
#    'responses',
#    'httpstcolgkm7huf0f'],
#   '2'),
#  (['chatgpt',
#    'explaining',
#    'quantum',
#    'mechanics',
#    'as',
#    'a',
#    'rap',
#    'song',
#    'chatgpt',
#    'quantummechanics',
#    'rapsong',
#    'httpstcoylrprp6y3k'],
#   '0'),
#  (['chatgpt',
#    'guess',
#    'my',
#    'job',
#    'is',
#    'safe',
#    'for',
#    'now',
#    'nopenai',
#    'httpstco0cpbh0ztkh'],
#   '2'),
#  (['you',
#    'have',
#    'failed',
#    'me',
#    'openai',
#    'what',
#    'the',
#    'hell',
#    'is',
#    'this',
#    'chatgpt',
#    'fail',
#    'openai',
#    'httpstcotmiw9fqz9h'],
#   '0'),
#  (['we',
#    'just',
#    'asked',
#    'chatgpt',
#    'to',
#    'write',
#    'a',
#    'poem',
#    'about',
#    'upscope',
#    'httpstco4galwnashm'],
#   '0'),
#  (['this',
#    'made',
#    'me',
#    'laugh',
#    'chatgpt',
#    'my',
#    'drone',
#    'just',
#    'crashed',
#    'httpstcopmkedw9jw2',
#    'httpstcor3xmnwbinc'],
#   '1'),
#  (['i',
#    'asked',
#    'openai',
#    'chatgpt',
#    'to',
#    'write',
#    'me',
#    'a',
#    'billy',
#    'mays',
#    'style',
#    'pitch',
#    'and',
#    'a',
#    'jingle',
#    'about',
#    'microjig',
#    'grrripper',
#    '',
#    'httpstcon4ysz1kadk'],
#   '0'),
#  (['i',
#    'asked',
#    'chatgpt',
#    'to',
#    'build',
#    'a',
#    'gen',
#    '8',
#    'ou',
#    'team',
#    'for',
#    'me',
#    'and',
#    'this',
#    'is',
#    'what',
#    'it',
#    'gave',
#    'menhttpstcok03vuefsew',
#    'httpstcopemz9jupgx'],
#   '0'),
#  (['i',
#    'asked',
#    'chatgpt',
#    'to',
#    'write',
#    'a',
#    'gangster',
#    'rap',
#    'about',
#    'tailwindcssnim',
#    'waiting',
#    'for',
#    'kenwheeler',
#    'to',
#    'drop',
#    'the',
#    'beat',
#    'httpstcok4ekivzaiu'],
#   '0'),
#  (['chatgpt', 'just', 'roasted', 'itself', 'httpstcofjptnazjkg'], '0'),
#  (['pretty', 'amazed', 'with', 'openais', 'chatgpt'], '1'),
#  (['some',
#    'key',
#    'points',
#    'nopenai',
#    'chatgpt',
#    'nnmore',
#    'than',
#    'a',
#    'search',
#    'engine',
#    'httpstcolt5sksoa5l'],
#   '0'),
#  (['hey',
#    'chatgpt',
#    'write',
#    'a',
#    'screenplay',
#    'about',
#    'elonmusk',
#    'taking',
#    'over',
#    'the',
#    'world',
#    'httpstcoqox1mg449v'],
#   '0'),
#  (['my', 'article', 'published', 'about', 'chatgpt', 'httpstcorvzslnky5j'],
#   '0'),
#  (['a',
#    'short',
#    'space',
#    'opera',
#    'about',
#    'bitcoin',
#    'and',
#    'the',
#    'survival',
#    'of',
#    'the',
#    'human',
#    'species',
#    'in',
#    'the',
#    'style',
#    'of',
#    'robert',
#    'heinlein',
#    'chatgpt',
#    'openai',
#    'bitcoin',
#    'httpstcouv41rv1qkj'],
#   '0'),
#  (['for',
#    'math',
#    'aficionados',
#    '',
#    'it',
#    'is',
#    'interesting',
#    'to',
#    'note',
#    'what',
#    'chatgpt',
#    'can',
#    'do',
#    'wrt',
#    'some',
#    'wellknown',
#    'problemsnnare',
#    'you',
#    'capable',
#    'of',
#    'proving',
#    'that',
#    'pnp',
#    'in',
#    'mathnnany',
#    'guesses',
#    'what',
#    'it',
#    'answerednngpt3',
#    'chatbot',
#    'artificialintelligence',
#    'openai',
#    'openai'],
#   '1'),
#  (['so',
#    'i',
#    'applied',
#    'the',
#    'sat',
#    'reading',
#    'test',
#    'section',
#    'to',
#    'chatgpt',
#    'httpstcolxxrbukjjw'],
#   '0'),
#  (['intro',
#    'to',
#    'rust',
#    'for',
#    'data',
#    'scientistsnbrought',
#    'to',
#    'you',
#    'by',
#    'chatgpt',
#    'httpstcopvgizymjl5'],
#   '0'),
#  (['or',
#    'google',
#    'will',
#    'just',
#    'integrate',
#    'chatgpt',
#    'to',
#    'their',
#    'search',
#    'httpstcou6wdujv1qw'],
#   '0'),
#  (['i',
#    'texted',
#    'my',
#    'friend',
#    'about',
#    'chatgpt',
#    'and',
#    'he',
#    'left',
#    'me',
#    'on',
#    'read'],
#   '2'),
#  (['will',
#    'chatgpt',
#    'or',
#    'some',
#    'successor',
#    'be',
#    'rebranded',
#    'as',
#    'lollipop',
#    'httpstcorxbog8g56g'],
#   '2'),
#  (['chatgpt',
#    '',
#    'will',
#    'change',
#    'the',
#    'worldnnalso',
#    'im',
#    'dying',
#    'here',
#    'httpstcolliwpg61em'],
#   '0'),
#  (['difference',
#    'between',
#    'reactnative',
#    'and',
#    'electron',
#    'as',
#    'described',
#    'by',
#    'smeagol',
#    'and',
#    'gollum',
#    'powered',
#    'by',
#    'chatgpt',
#    'httpstcoz0tell4n6m'],
#   '0'),
#  (['this',
#    'is',
#    'amazing',
#    'i',
#    'encourage',
#    'you',
#    'to',
#    'checkout',
#    'openai',
#    's',
#    'chatgpt',
#    'here',
#    'it',
#    'is',
#    'explaining',
#    'simply',
#    'a',
#    'dao',
#    'structure',
#    'and',
#    'how',
#    'it',
#    'operates',
#    'httpstcowu3kezaoi6'],
#   '1'),
#  (['wrote',
#    'an',
#    'entire',
#    'dragonballz',
#    'episode',
#    'in',
#    'chatgpt',
#    'feature',
#    'goku',
#    'vegeta',
#    'and',
#    'cell',
#    'on',
#    'the',
#    'night',
#    'of',
#    'the',
#    'chernobyl',
#    'reactor',
#    'meltdown',
#    'httpstco3zhklhzbec'],
#   '0'),
#  (['openai',
#    'debuts',
#    'chatgpt',
#    'and',
#    'gpt35',
#    'series',
#    'as',
#    'gpt4',
#    'rumors',
#    'fly',
#    '',
#    'venturebeat',
#    'httpstcoxjg11g5oom'],
#   '0'),
#  (['chatgptnhttpstco8hhp0sq89fnhttpstcom9fy6p33klna',
#    'conversational',
#    'ai',
#    'system',
#    'that',
#    'listens',
#    'learns',
#    'and',
#    'challenges',
#    'httpstco67ojzltjna'],
#   '2'),
#  (['i',
#    'hope',
#    'chatgpt',
#    'remembers',
#    'me',
#    'that',
#    'i',
#    'was',
#    'talking',
#    'to',
#    'it',
#    'and',
#    'friendly',
#    'early',
#    'on'],
#   '1'),
#  (['the',
#    'wedding',
#    'vows',
#    'industry',
#    'has',
#    'been',
#    'disrupted',
#    'chatgpt',
#    'httpstcozq3zow9tgt'],
#   '0'),
#  (['i',
#    'asked',
#    'chatgpt',
#    'to',
#    'write',
#    'a',
#    'roadmap',
#    'for',
#    'the',
#    'denuclearization',
#    'of',
#    'the',
#    'korean',
#    'peninsula',
#    'httpstco3ivocdcif7'],
#   '0'),
#  (['chatgpt', 'is', 'what', 'we', 'expected', 'watson', 'to', 'be'], '0'),
#  (['i',
#    'asked',
#    'chatgpt',
#    'to',
#    'rewrite',
#    'bohemian',
#    'rhapsody',
#    'to',
#    'be',
#    'about',
#    'the',
#    'life',
#    'of',
#    'a',
#    'postdoc',
#    'and',
#    'the',
#    'output',
#    'was',
#    'flawless',
#    'httpstcoqe1li66aa7'],
#   '1'),
#  (['chatgpt',
#    'is',
#    'taking',
#    'a',
#    'hard',
#    'line',
#    'on',
#    'the',
#    'updog',
#    'issue',
#    'httpstcor8ljkrnorz'],
#   '0'),
#  (['2023',
#    'should',
#    'be',
#    'fun',
#    'chatgpt',
#    'httpstcoj43xnwvgzu',
#    'httpstcorevgev5lcv'],
#   '1'),
#  (['chatgpt',
#    'likes',
#    'cbms',
#    'begin',
#    'implementing',
#    'the',
#    'denuclearization',
#    'plan',
#    'starting',
#    'with',
#    'confidencebuilding',
#    'measures',
#    'and',
#    'confidencebuilding',
#    'measures',
#    'httpstcouher85tx8y'],
#   '1'),
#  (['here',
#    'is',
#    'a',
#    'super',
#    'intelligent',
#    'ai',
#    'remembering',
#    'the',
#    'conversation',
#    'between',
#    'moses',
#    'and',
#    'the',
#    'burning',
#    'bush',
#    'but',
#    'of',
#    'course',
#    'moses',
#    'is',
#    'high',
#    'afnnchatgpt',
#    'openai',
#    'httpstcov4ucsg5avd'],
#   '1'),
#  (['some',
#    'pocus',
#    'questions',
#    'answered',
#    'by',
#    'chatgpt',
#    'from',
#    'openai',
#    'httpstco1l0gjubvmn'],
#   '0'),
#  (['ive',
#    'been',
#    'playing',
#    'with',
#    'chatgpt',
#    'all',
#    'day',
#    'and',
#    'it',
#    'has',
#    'turned',
#    'me',
#    'from',
#    'llmconversational',
#    'agent',
#    'skeptic',
#    'to',
#    'a',
#    'believernnthis',
#    'is',
#    'not',
#    'it',
#    'but',
#    'its',
#    'pretty',
#    'damned',
#    'close'],
#   '2'),
#  (['hey',
#    'mattwalshblog',
#    'chatgpt',
#    'just',
#    'gave',
#    'me',
#    'an',
#    'answer',
#    'to',
#    'the',
#    'question',
#    'what',
#    'is',
#    'a',
#    'woman',
#    'httpstconnebnlpuzy'],
#   '0'),
#  (['peteranswers', 'is', 'the', 'og', 'chatgpt'], '0'),
#  ...]

# %%
all_words_neg = sentiment_analyser.all_words([mark_negation(doc) for doc in dataset_treino_amostra])
all_words_neg_nostops = [x for x in all_words_neg if x not in stopwords_all]

# %%
#Cria um unigram(n-grama) e extrai as features
unigram_feats = sentiment_analyser.unigram_word_feats(all_words_neg_nostops, top_n=200)
sentiment_analyser.add_feat_extractor(extract_unigram_feats, unigrams = unigram_feats)
training_set = sentiment_analyser.apply_features(dataset_treino_amostra)

# %%
type(training_set)

# %%
print(training_set)

# %%
# Treinar o modelo
trainer = NaiveBayesClassifier.train
classifier = sentiment_analyser.train(trainer, training_set)

# %%
# Testa o classificador em algumas sentenças
test_sentence1 = [(['model', 'is', 'people', 'bad'], '')]
test_sentence2 = [(['learning', 'day', 'bit', 'work', 'today'], '')]
test_sentence3 = [(['good', 'wonderful', 'results', 'awesome'], '')]
test_set = sentiment_analyser.apply_features(test_sentence1)
test_set2 = sentiment_analyser.apply_features(test_sentence2)
test_set3 = sentiment_analyser.apply_features(test_sentence3)

# %%
test_set

# %%
test_set2

# %%
test_set3

# %%
#Autenticação do Twitter
consumer_key = 'HZlZ9oKuUd9Pjy26EAPqW7P4a'
consumer_secret = 'JOcP5J0PmI7vbszwfw7ILJPtADA270l1UiuAOXeMJ5QLEJuu8n'
access_token = '1251925649952059392-8dKgUbCc0m9udPOlotSPzNC2UfJceJ'
access_token_secret ='2rhYbbD5OOlDRhzowz1OZza9LXPj6Gq0rpjPuOPLCMXbY'
bearer_token = "AAAAAAAAAAAAAAAAAAAAAOCeTwEAAAAAoL4M%2FzLMl%2FYAk3yCFrsc%2BOniGIM%3Dd8TzQTt3X4A1tyYmI2aCWEMRg4R3mYbarXPtiJBaA72xR7V2ev"

# %%
# Configurar a autenticação do Twitter
auth_header = {
    "Authorization": "Bearer " + bearer_token,
    "Content-Type": "application/json"
}

# %%
# Especifica a URL termo de busca
search_term = 'chatgpt'
sample_url ='https://stream.twitter.com/1.1/statuses/sample.json'
#filter_url = 'https://stream.twitter.com/1.1/statuses/filter.json?track='+search_term
#filter_url = 'https://api.twitter.com/2/tweets/search/stream?tweet.fields=text'+search_term
filter_url = "https://api.twitter.com/2/tweets/search/stream"
tweet_fields = "tweet.fields=text"

# %%
query_params = {
    "expansions": "author_id",
    "tweet.fields": tweet_fields,
    "user.fields": "username",
    "track": search_term
}

# %%
#Criando o objeto de autenticação para o Twitter
auth = requests_oauthlib.OAuth1(consumer_key, consumer_secret, access_token, access_token_secret)

# %%
auth

# %%
auth.

# %%
auth = OAuth1Session('HZlZ9oKuUd9Pjy26EAPqW7P4a',
                            client_secret='JOcP5J0PmI7vbszwfw7ILJPtADA270l1UiuAOXeMJ5QLEJuu8n',
                            resource_owner_key='1251925649952059392-8dKgUbCc0m9udPOlotSPzNC2UfJceJ',
                            resource_owner_secret='2rhYbbD5OOlDRhzowz1OZza9LXPj6Gq0rpjPuOPLCMXbY')

# %%
url = 'https://api.twitter.com/1/account/settings.json'

# %%
r = auth.get(url)

# %%
r

# %%
#Configurando o Stream
rdd = ssc.sparkContext.parallelize([0])
stream = ssc.queueStream([], default=rdd)

# %%
#Total de Tweets por update
NUM_TWEETS = 500

# %%
type(stream)

# %%
# Essa função conecta ao Twitter e retorna um número específico de Tweets (NUM_TWEETS)
def tfunc(t, rdd):
  return rdd.flatMap(lambda x: stream_twitter_data())

def stream_twitter_data():
   #response = requests.get(filter_url, auth = auth, stream = True)
  response = requests.get(filter_url, auth = auth, headers=auth_header, stream=True, params=query_params)
  print(filter_url, response)
  count = 0
  for line in response.iter_lines():
    try:
      if count > NUM_TWEETS:
        break
      post = json.loads(line.decode('utf-8'))
      contents = [post['text']]
      count += 1
      yield str(contents)
    except:
      result = False

# %%
stream = stream.transform(tfunc)

# %%
stream

# %%
coord_stream = stream.map(lambda line: ast.literal_eval(line))

# %%
# Essa função classifica os tweets, aplicando as features do modelo criado anteriormente
def classifica_tweet(tweet):
  sentence = [(tweet, '')]
  test_set = sentiment_analyzer.apply_features(sentence)
  print(tweet, classifier.classify(test_set[0][0]))
  return(tweet, classifier.classify(test_set[0][0]))

# %%
# Essa função retorna o texto do Twitter
def get_tweet_text(rdd):
  for line in rdd:
    tweet = line.strip()
    translator = str.maketrans({key: None for key in string.punctuation})
    tweet = tweet.translate(translator)
    tweet = tweet.split(' ')
    tweet_lower = []
    for word in tweet:
      tweet_lower.append(word.lower())
    return(classifica_tweet(tweet_lower))

# %%
# Cria uma lista vazia para os resultados
resultados = []

# %%
# Essa função salva o resultado dos batches de Tweets junto com o timestamp
def output_rdd(rdd):
  global resultados
  pairs = rdd.map(lambda x: (get_tweet_text(x)[1],1))
  counts = pairs.reduceByKey(add)
  output = []
  for count in counts.collect():
    output.append(count)
  result = [time.strftime("%I:%M:%S"), output]
  resultados.append(result)
  print(result)

# %%
# A função foreachRDD() aplica uma função a cada RDD to streaming de dados
coord_stream.foreachRDD(lambda t, rdd: output_rdd(rdd))

# %%
# Start streaming
ssc.start()
# ssc.awaitTermination()

# %%
cont = True
while cont:
  if len(resultados) > 5:
    cont = False

# %%
# Grava os resultados
rdd_save = '/dados/r'+time.strftime("%I%M%S")
resultados_rdd = sc.parallelize(resultados)
resultados_rdd.saveAsTextFile(rdd_save)

# %%
# Visualiza os resultados
resultados_rdd.collect()

# %%
# Finaliza o streaming
ssc.stop()
